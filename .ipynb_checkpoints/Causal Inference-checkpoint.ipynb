# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
import datetime as dt
import math
from sklearn.preprocessing import StandardScaler
import helper
from helper import *

# %%
df = load_and_preprocess()
df = df.reset_index(drop = True)

# %%
df.shape
# Out:
# (45252, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45252 entries, 0 to 45251
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   datetime        45252 non-null  object
#  1   Description     45252 non-null  object
#  2   Humidity        45252 non-null  float64
#  3   Wind Direction  45252 non-null  float64
#  4   Temperature     45252 non-null  float64
#  5   Pressure        45252 non-null  float64
#  6   Wind Speed      45252 non-null  float64
#  7   clouds          45252 non-null  int64
#  8   rain            45252 non-null  int64
#  9   mist            45252 non-null  int64
#  10  snow            45252 non-null  int64
#  11  shower          45252 non-null  int64
#  12  thunderstorm    45252 non-null  int64
#  13  fog             45252 non-null  int64
#  14  other           45252 non-null  int64
#  15  Intensity       45252 non-null  float64
# dtypes: float64(6), int64(8), object(2)
# memory usage: 5.5+ MB

# %%
df['datetime']= pd.to_datetime(df['datetime'])

# %% [markdown]
# #### Just Using Date/Previous Hour Temp.

# %%
df.head()
# Out:
#              datetime   Description  Humidity  Wind Direction  Temperature  \
# 0 2012-10-01 13:00:00  heavy clouds      93.0          1001.0   285.830000
# 1 2012-10-01 14:00:00  sky is clear      91.0           986.0   285.834650
# 2 2012-10-01 15:00:00  sky is clear      87.0           945.0   285.847790
# 3 2012-10-01 16:00:00  sky is clear      84.0           904.0   285.860929
# 4 2012-10-01 17:00:00  sky is clear      80.0           863.0   285.874069
#
#    Pressure  Wind Speed  clouds  rain  mist  snow  shower  thunderstorm  fog  \
# 0     230.0         4.0       1     0     0     0       0             0    0
# 1     230.0         4.0       0     0     0     0       0             0    0
# 2     231.0         4.0       0     0     0     0       0             0    0
# 3     233.0         4.0       0     0     0     0       0             0    0
# 4     234.0         3.0       0     0     0     0       0             0    0
#
#    other  Intensity
# 0      0        3.0
# 1      0        0.0
# 2      0        0.0
# 3      0        0.0
# 4      0        0.0

# %%
df['day'] = df['datetime'].dt.day
df['month'] = df['datetime'].dt.month
df['year'] = df['datetime'].dt.year

#lag features from Duncan
df['lag1'] = df['Temperature'].shift(periods = 1, fill_value = 0)
df['lag2'] = df['Temperature'].shift(periods = 2, fill_value = 0)
df['lag12'] = df['Temperature'].shift(periods = 12, fill_value = 0)
df['lag30'] = df['Temperature'].shift(periods = 30, fill_value = 0)

df['avg_Temperature'] = 0 
for i in range(1, len(df)):
    df['avg_Temperature'][i] = df['lag1'][:i+1].mean()
    

df.drop('Description', axis = 1, inplace = True)
df = df.set_index('datetime')

#we have to eliminate all those with 0s
df = df[df['lag30'] != 0]
df
# Out:
# C:\Users\Steven\anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
#                       Humidity  Wind Direction  Temperature  Pressure  \
# datetime
# 2012-10-02 19:00:00  71.861538     1016.424953       288.94     282.0
# 2012-10-02 20:00:00  71.861538     1016.424953       288.69     239.0
# 2012-10-02 21:00:00  77.000000     1007.000000       288.55     260.0
# 2012-10-02 22:00:00  71.861538     1016.424953       288.22     284.0
# 2012-10-02 23:00:00  71.861538     1016.424953       287.92     267.0
# ...                        ...             ...          ...       ...
# 2017-11-29 20:00:00  64.000000     1021.000000       275.13     300.0
# 2017-11-29 21:00:00  59.000000     1023.000000       274.13     300.0
# 2017-11-29 22:00:00  66.000000     1024.000000       273.48     290.0
# 2017-11-29 23:00:00  58.000000     1026.000000       272.48     290.0
# 2017-11-30 00:00:00  58.000000     1027.000000       271.80     300.0
#
#                      Wind Speed  clouds  rain  mist  snow  shower  ...  other  \
# datetime                                                           ...
# 2012-10-02 19:00:00         2.0       0     0     0     0       0  ...      0
# 2012-10-02 20:00:00         5.0       0     0     0     0       0  ...      0
# 2012-10-02 21:00:00         7.0       1     0     0     0       0  ...      0
# 2012-10-02 22:00:00         0.0       0     0     0     0       0  ...      0
# 2012-10-02 23:00:00         0.0       0     0     0     0       0  ...      0
# ...                         ...     ...   ...   ...   ...     ...  ...    ...
# 2017-11-29 20:00:00        10.0       1     0     0     0       0  ...      0
# 2017-11-29 21:00:00         7.0       1     0     0     0       0  ...      0
# 2017-11-29 22:00:00         7.0       1     0     0     0       0  ...      0
# 2017-11-29 23:00:00         4.0       1     0     0     0       0  ...      0
# 2017-11-30 00:00:00         4.0       1     0     0     0       0  ...      0
#
#                      Intensity  day  month  year    lag1    lag2       lag12  \
# datetime
# 2012-10-02 19:00:00        0.0    2     10  2012  288.94  288.69  286.058023
# 2012-10-02 20:00:00        0.0    2     10  2012  288.94  288.94  286.071162
# 2012-10-02 21:00:00        3.0    2     10  2012  288.69  288.94  286.084302
# 2012-10-02 22:00:00        0.0    2     10  2012  288.55  288.69  286.097442
# 2012-10-02 23:00:00        0.0    2     10  2012  288.22  288.55  286.110581
# ...                        ...  ...    ...   ...     ...     ...         ...
# 2017-11-29 20:00:00        2.0   29     11  2017  276.45  276.15  275.380000
# 2017-11-29 21:00:00        2.0   29     11  2017  275.13  276.45  277.450000
# 2017-11-29 22:00:00        1.0   29     11  2017  274.13  275.13  278.770000
# 2017-11-29 23:00:00        1.0   29     11  2017  273.48  274.13  278.480000
# 2017-11-30 00:00:00        1.0   30     11  2017  272.48  273.48  277.450000
#
#                           lag30  avg_Temperature
# datetime
# 2012-10-02 19:00:00  285.830000              277
# 2012-10-02 20:00:00  285.834650              277
# 2012-10-02 21:00:00  285.847790              277
# 2012-10-02 22:00:00  285.860929              278
# 2012-10-02 23:00:00  285.874069              278
# ...                         ...              ...
# 2017-11-29 20:00:00  265.120000              280
# 2017-11-29 21:00:00  266.120000              280
# 2017-11-29 22:00:00  268.100000              280
# 2017-11-29 23:00:00  269.770000              280
# 2017-11-30 00:00:00  271.770000              280
#
# [45222 rows x 22 columns]

# %% [markdown]
# # Causal Inference

# %%
import dowhy
from dowhy import CausalModel

# %%
features = df.drop('Temperature', axis=1)
cols = list(features.columns)
cols
# Out:
# ['Humidity',
#  'Wind Direction',
#  'Pressure',
#  'Wind Speed',
#  'clouds',
#  'rain',
#  'mist',
#  'snow',
#  'shower',
#  'thunderstorm',
#  'fog',
#  'other',
#  'Intensity',
#  'day',
#  'month',
#  'year',
#  'lag1',
#  'lag2',
#  'lag12',
#  'lag30',
#  'avg_Temperature']

# %%
X = df[cols]
effects = dict()
test = dict()

for i in X:
    model = CausalModel(data = df,
                        treatment = i,
                        outcome = 'Temperature',
                        common_causes = list(X.drop(i, axis = 'columns').columns))
    
    identified_estimand = model.identify_effect(proceed_when_unidentifiable=True)

    estimate = model.estimate_effect(identified_estimand,
                                     method_name="backdoor.linear_regression",
                                    test_significance = True)
    
    effects[i] = estimate.value
    test[i] = estimate
# Out:
# WARNING:dowhy.causal_model:Causal Graph not provided. DoWhy will construct a graph based on data inputs.
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['Humidity'] on outcome ['Temperature']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# INFO:dowhy.causal_identifier:Continuing by ignoring these unobserved confounders because proceed_when_unidentifiable flag is True.
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:[]
# INFO:dowhy.causal_identifier:Frontdoor variables for treatment and outcome:[]
# INFO:dowhy.causal_estimator:b: Temperature~Humidity+Wind Speed+lag2+shower+lag1+lag30+fog+thunderstorm+day+other+lag12+rain+month+Pressure+snow+clouds+Intensity+Wind Direction+avg_Temperature+mist+year
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# WARNING:dowhy.causal_model:Causal Graph not provided. DoWhy will construct a graph based on data inputs.
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['Wind Direction'] on outcome ['Temperature']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# INFO:dowhy.causal_identifier:Continuing by ignoring these unobserved confounders because proceed_when_unidentifiable flag is True.
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:[]
# INFO:dowhy.causal_identifier:Frontdoor variables for treatment and outcome:[]
# INFO:dowhy.causal_estimator:b: Temperature~Wind Direction+Wind Speed+lag2+shower+lag1+lag30+fog+thunderstorm+day+other+lag12+rain+month+Pressure+snow+clouds+Intensity+avg_Temperature+Humidity+mist+year
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# WARNING:dowhy.causal_model:Causal Graph not provided. DoWhy will construct a graph based on data inputs.
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['Pressure'] on outcome ['Temperature']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# INFO:dowhy.causal_identifier:Continuing by ignoring these unobserved confounders because proceed_when_unidentifiable flag is True.
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:[]
# INFO:dowhy.causal_identifier:Frontdoor variables for treatment and outcome:[]
# INFO:dowhy.causal_estimator:b: Temperature~Pressure+Wind Speed+lag2+shower+lag1+lag30+fog+thunderstorm+day+other+lag12+rain+month+snow+clouds+Intensity+Wind Direction+Humidity+avg_Temperature+mist+year
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# WARNING:dowhy.causal_model:Causal Graph not provided. DoWhy will construct a graph based on data inputs.
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['Wind Speed'] on outcome ['Temperature']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# INFO:dowhy.causal_identifier:Continuing by ignoring these unobserved confounders because proceed_when_unidentifiable flag is True.
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:[]
# INFO:dowhy.causal_identifier:Frontdoor variables for treatment and outcome:[]
# INFO:dowhy.causal_estimator:b: Temperature~Wind Speed+lag2+shower+lag1+lag30+fog+thunderstorm+day+other+lag12+rain+month+Pressure+snow+clouds+Intensity+Wind Direction+Humidity+avg_Temperature+mist+year
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# WARNING:dowhy.causal_model:Causal Graph not provided. DoWhy will construct a graph based on data inputs.
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['clouds'] on outcome ['Temperature']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# INFO:dowhy.causal_identifier:Continuing by ignoring these unobserved confounders because proceed_when_unidentifiable flag is True.
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:[]
# INFO:dowhy.causal_identifier:Frontdoor variables for treatment and outcome:[]
# INFO:dowhy.causal_estimator:b: Temperature~clouds+Wind Speed+lag2+shower+lag1+lag30+fog+thunderstorm+day+other+lag12+rain+month+Pressure+snow+Intensity+Wind Direction+Humidity+avg_Temperature+mist+year
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# WARNING:dowhy.causal_model:Causal Graph not provided. DoWhy will construct a graph based on data inputs.
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['rain'] on outcome ['Temperature']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# INFO:dowhy.causal_identifier:Continuing by ignoring these unobserved confounders because proceed_when_unidentifiable flag is True.
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:[]
# INFO:dowhy.causal_identifier:Frontdoor variables for treatment and outcome:[]
# INFO:dowhy.causal_estimator:b: Temperature~rain+Wind Speed+lag2+shower+lag1+lag30+fog+thunderstorm+day+other+lag12+month+Pressure+snow+clouds+Intensity+Wind Direction+Humidity+avg_Temperature+mist+year
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# WARNING:dowhy.causal_model:Causal Graph not provided. DoWhy will construct a graph based on data inputs.
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['mist'] on outcome ['Temperature']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# INFO:dowhy.causal_identifier:Continuing by ignoring these unobserved confounders because proceed_when_unidentifiable flag is True.
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:[]
# INFO:dowhy.causal_identifier:Frontdoor variables for treatment and outcome:[]
# INFO:dowhy.causal_estimator:b: Temperature~mist+Wind Speed+lag2+shower+lag1+lag30+fog+thunderstorm+day+other+lag12+rain+month+Pressure+snow+clouds+Intensity+Wind Direction+Humidity+avg_Temperature+year
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# WARNING:dowhy.causal_model:Causal Graph not provided. DoWhy will construct a graph based on data inputs.
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['snow'] on outcome ['Temperature']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# INFO:dowhy.causal_identifier:Continuing by ignoring these unobserved confounders because proceed_when_unidentifiable flag is True.
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:[]
# INFO:dowhy.causal_identifier:Frontdoor variables for treatment and outcome:[]
# INFO:dowhy.causal_estimator:b: Temperature~snow+Wind Speed+lag2+shower+lag1+lag30+fog+thunderstorm+day+other+lag12+rain+month+Pressure+clouds+Intensity+Wind Direction+Humidity+avg_Temperature+mist+year
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# WARNING:dowhy.causal_model:Causal Graph not provided. DoWhy will construct a graph based on data inputs.
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['shower'] on outcome ['Temperature']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# INFO:dowhy.causal_identifier:Continuing by ignoring these unobserved confounders because proceed_when_unidentifiable flag is True.
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:[]
# INFO:dowhy.causal_identifier:Frontdoor variables for treatment and outcome:[]
# INFO:dowhy.causal_estimator:b: Temperature~shower+Wind Speed+lag2+lag1+lag30+fog+thunderstorm+day+other+lag12+rain+month+Pressure+snow+clouds+Intensity+Wind Direction+Humidity+avg_Temperature+mist+year
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# WARNING:dowhy.causal_model:Causal Graph not provided. DoWhy will construct a graph based on data inputs.
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['thunderstorm'] on outcome ['Temperature']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# INFO:dowhy.causal_identifier:Continuing by ignoring these unobserved confounders because proceed_when_unidentifiable flag is True.
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:[]
# INFO:dowhy.causal_identifier:Frontdoor variables for treatment and outcome:[]
# INFO:dowhy.causal_estimator:b: Temperature~thunderstorm+Wind Speed+lag2+shower+lag1+lag30+fog+day+other+lag12+rain+month+Pressure+snow+clouds+Intensity+Wind Direction+Humidity+avg_Temperature+mist+year
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# WARNING:dowhy.causal_model:Causal Graph not provided. DoWhy will construct a graph based on data inputs.
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['fog'] on outcome ['Temperature']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# INFO:dowhy.causal_identifier:Continuing by ignoring these unobserved confounders because proceed_when_unidentifiable flag is True.
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:[]
# INFO:dowhy.causal_identifier:Frontdoor variables for treatment and outcome:[]
# INFO:dowhy.causal_estimator:b: Temperature~fog+Wind Speed+lag2+shower+lag1+lag30+thunderstorm+day+other+lag12+rain+month+Pressure+snow+clouds+Intensity+Wind Direction+Humidity+avg_Temperature+mist+year
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# WARNING:dowhy.causal_model:Causal Graph not provided. DoWhy will construct a graph based on data inputs.
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['other'] on outcome ['Temperature']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# INFO:dowhy.causal_identifier:Continuing by ignoring these unobserved confounders because proceed_when_unidentifiable flag is True.
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:[]
# INFO:dowhy.causal_identifier:Frontdoor variables for treatment and outcome:[]
# INFO:dowhy.causal_estimator:b: Temperature~other+Wind Speed+lag2+shower+lag1+lag30+fog+thunderstorm+day+lag12+rain+month+Pressure+snow+clouds+Intensity+Wind Direction+Humidity+avg_Temperature+mist+year
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# WARNING:dowhy.causal_model:Causal Graph not provided. DoWhy will construct a graph based on data inputs.
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['Intensity'] on outcome ['Temperature']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# INFO:dowhy.causal_identifier:Continuing by ignoring these unobserved confounders because proceed_when_unidentifiable flag is True.
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:[]
# INFO:dowhy.causal_identifier:Frontdoor variables for treatment and outcome:[]
# INFO:dowhy.causal_estimator:b: Temperature~Intensity+Wind Speed+lag2+shower+lag1+lag30+fog+thunderstorm+day+other+lag12+rain+month+Pressure+snow+clouds+Wind Direction+Humidity+avg_Temperature+mist+year
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# WARNING:dowhy.causal_model:Causal Graph not provided. DoWhy will construct a graph based on data inputs.
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['day'] on outcome ['Temperature']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# INFO:dowhy.causal_identifier:Continuing by ignoring these unobserved confounders because proceed_when_unidentifiable flag is True.
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:[]
# INFO:dowhy.causal_identifier:Frontdoor variables for treatment and outcome:[]
# INFO:dowhy.causal_estimator:b: Temperature~day+Wind Speed+lag2+shower+lag1+lag30+fog+thunderstorm+other+lag12+rain+month+Pressure+snow+clouds+Intensity+Wind Direction+Humidity+avg_Temperature+mist+year
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# WARNING:dowhy.causal_model:Causal Graph not provided. DoWhy will construct a graph based on data inputs.
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['month'] on outcome ['Temperature']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# INFO:dowhy.causal_identifier:Continuing by ignoring these unobserved confounders because proceed_when_unidentifiable flag is True.
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:[]
# INFO:dowhy.causal_identifier:Frontdoor variables for treatment and outcome:[]
# INFO:dowhy.causal_estimator:b: Temperature~month+Wind Speed+lag2+shower+lag1+lag30+fog+thunderstorm+day+other+lag12+rain+Pressure+snow+clouds+Intensity+Wind Direction+Humidity+avg_Temperature+mist+year
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# WARNING:dowhy.causal_model:Causal Graph not provided. DoWhy will construct a graph based on data inputs.
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['year'] on outcome ['Temperature']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# INFO:dowhy.causal_identifier:Continuing by ignoring these unobserved confounders because proceed_when_unidentifiable flag is True.
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:[]
# INFO:dowhy.causal_identifier:Frontdoor variables for treatment and outcome:[]
# INFO:dowhy.causal_estimator:b: Temperature~year+Wind Speed+lag2+shower+lag1+lag30+fog+thunderstorm+day+other+lag12+rain+month+Pressure+snow+clouds+Intensity+Wind Direction+Humidity+avg_Temperature+mist
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# WARNING:dowhy.causal_model:Causal Graph not provided. DoWhy will construct a graph based on data inputs.
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['lag1'] on outcome ['Temperature']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# INFO:dowhy.causal_identifier:Continuing by ignoring these unobserved confounders because proceed_when_unidentifiable flag is True.
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:[]
# INFO:dowhy.causal_identifier:Frontdoor variables for treatment and outcome:[]
# INFO:dowhy.causal_estimator:b: Temperature~lag1+Wind Speed+lag2+shower+lag30+fog+thunderstorm+day+other+lag12+rain+month+Pressure+snow+clouds+Intensity+Wind Direction+Humidity+avg_Temperature+mist+year
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# WARNING:dowhy.causal_model:Causal Graph not provided. DoWhy will construct a graph based on data inputs.
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['lag2'] on outcome ['Temperature']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# INFO:dowhy.causal_identifier:Continuing by ignoring these unobserved confounders because proceed_when_unidentifiable flag is True.
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:[]
# INFO:dowhy.causal_identifier:Frontdoor variables for treatment and outcome:[]
# INFO:dowhy.causal_estimator:b: Temperature~lag2+Wind Speed+shower+lag1+lag30+fog+thunderstorm+day+other+lag12+rain+month+Pressure+snow+clouds+Intensity+Wind Direction+Humidity+avg_Temperature+mist+year
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# WARNING:dowhy.causal_model:Causal Graph not provided. DoWhy will construct a graph based on data inputs.
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['lag12'] on outcome ['Temperature']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# INFO:dowhy.causal_identifier:Continuing by ignoring these unobserved confounders because proceed_when_unidentifiable flag is True.
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:[]
# INFO:dowhy.causal_identifier:Frontdoor variables for treatment and outcome:[]
# INFO:dowhy.causal_estimator:b: Temperature~lag12+Wind Speed+lag2+shower+lag1+lag30+fog+thunderstorm+day+other+rain+month+Pressure+snow+clouds+Intensity+Wind Direction+Humidity+avg_Temperature+mist+year
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# WARNING:dowhy.causal_model:Causal Graph not provided. DoWhy will construct a graph based on data inputs.
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['lag30'] on outcome ['Temperature']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# INFO:dowhy.causal_identifier:Continuing by ignoring these unobserved confounders because proceed_when_unidentifiable flag is True.
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:[]
# INFO:dowhy.causal_identifier:Frontdoor variables for treatment and outcome:[]
# INFO:dowhy.causal_estimator:b: Temperature~lag30+Wind Speed+lag2+shower+lag1+fog+thunderstorm+day+other+lag12+rain+month+Pressure+snow+clouds+Intensity+Wind Direction+Humidity+avg_Temperature+mist+year
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# WARNING:dowhy.causal_model:Causal Graph not provided. DoWhy will construct a graph based on data inputs.
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['avg_Temperature'] on outcome ['Temperature']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# INFO:dowhy.causal_identifier:Continuing by ignoring these unobserved confounders because proceed_when_unidentifiable flag is True.
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:[]
# INFO:dowhy.causal_identifier:Frontdoor variables for treatment and outcome:[]
# INFO:dowhy.causal_estimator:b: Temperature~avg_Temperature+Wind Speed+lag2+shower+lag1+lag30+fog+thunderstorm+day+other+lag12+rain+month+Pressure+snow+clouds+Intensity+Wind Direction+Humidity+mist+year
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator

# %% [markdown]
# ## Final Output Preprocessing

# %%
#piecing together the dataframes and also processing out the p-values (brute force)
estimates = pd.DataFrame(effects.items(),columns=['Feature', 'Estimate'])
tests = pd.DataFrame(test.items(), columns=['Feature', 'P-Values'])
tests = tests.astype(str)
tests['P-Values'] = tests['P-Values'].str.split('p-value: ').str[-1]
tests['P-Values'] = tests['P-Values'].str.replace(r'[', '')
tests['P-Values'] = tests['P-Values'].str.replace(r']\n', '')
tests = tests.astype({"P-Values": float})
tests['Estimate'] = estimates['Estimate']
finaldf = tests.round(3).sort_values('Estimate')
# Out:
# C:\Users\Steven\anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#
# C:\Users\Steven\anaconda3\lib\site-packages\ipykernel_launcher.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   import sys

# %%
finaldf
# Out:
#             Feature  P-Values  Estimate
# 9      thunderstorm     0.000    -0.510
# 17             lag2     0.000    -0.262
# 8            shower     0.046    -0.062
# 19            lag30     0.000    -0.031
# 3        Wind Speed     0.005    -0.007
# 0          Humidity     0.000    -0.003
# 2          Pressure     0.000    -0.001
# 13              day     0.883     0.000
# 1    Wind Direction     0.038     0.001
# 20  avg_Temperature     0.601     0.002
# 15             year     0.500     0.003
# 14            month     0.000     0.008
# 12        Intensity     0.268     0.010
# 10              fog     0.664     0.026
# 18            lag12     0.000     0.035
# 7              snow     0.044     0.061
# 5              rain     0.000     0.111
# 11            other     0.641     0.119
# 6              mist     0.000     0.124
# 4            clouds     0.000     0.137
# 16             lag1     0.000     1.250

# %%
#features with high causal inference
high_evd = finaldf[finaldf['P-Values'] <= 0.05]
high_evd
# Out:
#            Feature  P-Values  Estimate
# 9     thunderstorm     0.000    -0.510
# 17            lag2     0.000    -0.262
# 8           shower     0.046    -0.062
# 19           lag30     0.000    -0.031
# 3       Wind Speed     0.005    -0.007
# 0         Humidity     0.000    -0.003
# 2         Pressure     0.000    -0.001
# 1   Wind Direction     0.038     0.001
# 14           month     0.000     0.008
# 18           lag12     0.000     0.035
# 7             snow     0.044     0.061
# 5             rain     0.000     0.111
# 6             mist     0.000     0.124
# 4           clouds     0.000     0.137
# 16            lag1     0.000     1.250

# %%
#features with low causal inference
low_evd = finaldf[finaldf['P-Values'] >= 0.05]
low_evd
# Out:
#             Feature  P-Values  Estimate
# 13              day     0.883     0.000
# 20  avg_Temperature     0.601     0.002
# 15             year     0.500     0.003
# 12        Intensity     0.268     0.010
# 10              fog     0.664     0.026
# 11            other     0.641     0.119

# %%
#reference for a helper function

def causal_inf_output(): 
    estimates = pd.DataFrame(effects.items(),columns=['Feature', 'Estimate'])
    tests = pd.DataFrame(test.items(), columns=['Feature', 'P-Values'])
    tests = tests.astype(str)
    tests['P-Values'] = tests['P-Values'].str.split('p-value: ').str[-1]
    tests['P-Values'] = tests['P-Values'].str.replace(r'[', '')
    tests['P-Values'] = tests['P-Values'].str.replace(r']\n', '')
    tests = tests.astype({"P-Values": float})
    tests['Estimate'] = estimates['Estimate']
    finaldf = tests.round(3).sort_values('Estimate')
    return finaldf

# %% [markdown]
# # Causal Inference Version 2

# %%
df = load_and_preprocess()
df = df.reset_index(drop = True)
df['Temperature'] = df['Temperature'] -273.15
df
# Out:
#                   datetime       Description  Humidity  Wind Direction  \
# 0      2012-10-01 13:00:00      heavy clouds     93.00         1001.00
# 1      2012-10-01 14:00:00      sky is clear     91.00          986.00
# 2      2012-10-01 15:00:00      sky is clear     87.00          945.00
# 3      2012-10-01 16:00:00      sky is clear     84.00          904.00
# 4      2012-10-01 17:00:00      sky is clear     80.00          863.00
# ...                    ...               ...       ...             ...
# 45247  2017-11-29 20:00:00  moderate  clouds     64.00         1021.00
# 45248  2017-11-29 21:00:00  moderate  clouds     59.00         1023.00
# 45249  2017-11-29 22:00:00     light  clouds     66.00         1024.00
# 45250  2017-11-29 23:00:00     light  clouds     58.00         1026.00
# 45251  2017-11-30 00:00:00     light  clouds     58.00         1027.00
#
#        Temperature  Pressure  Wind Speed  clouds  rain  mist  snow  shower  \
# 0            12.68    230.00        4.00       1     0     0     0       0
# 1            12.68    230.00        4.00       0     0     0     0       0
# 2            12.70    231.00        4.00       0     0     0     0       0
# 3            12.71    233.00        4.00       0     0     0     0       0
# 4            12.72    234.00        3.00       0     0     0     0       0
# ...            ...       ...         ...     ...   ...   ...   ...     ...
# 45247         1.98    300.00       10.00       1     0     0     0       0
# 45248         0.98    300.00        7.00       1     0     0     0       0
# 45249         0.33    290.00        7.00       1     0     0     0       0
# 45250        -0.67    290.00        4.00       1     0     0     0       0
# 45251        -1.35    300.00        4.00       1     0     0     0       0
#
#        thunderstorm  fog  other  Intensity
# 0                 0    0      0       3.00
# 1                 0    0      0       0.00
# 2                 0    0      0       0.00
# 3                 0    0      0       0.00
# 4                 0    0      0       0.00
# ...             ...  ...    ...        ...
# 45247             0    0      0       2.00
# 45248             0    0      0       2.00
# 45249             0    0      0       1.00
# 45250             0    0      0       1.00
# 45251             0    0      0       1.00
#
# [45252 rows x 16 columns]

# %%
print(df['Wind Speed'].value_counts())
df['Wind Speed'][100:400].plot()
# Out:
# 3.00     7808
# 2.00     7307
# 4.00     6594
# 1.00     6310
# 5.00     5127
# 6.00     4118
# 7.00     2477
# 0.00     1726
# 8.00     1681
# 9.00      936
# 10.00     526
# 11.00     304
# 12.00     143
# 13.00      93
# 14.00      44
# 15.00      21
# 17.00      18
# 19.00       5
# 16.00       4
# 18.00       4
# 20.00       3
# 21.00       2
# 24.00       1
# Name: Wind Speed, dtype: int64
# <AxesSubplot:>

# %%
df['datetime']= pd.to_datetime(df['datetime'])
df['season'] = (df['datetime'].dt.month%12 + 3)//3

seasons = {
             1: 'Winter',
             2: 'Spring',
             3: 'Summer',
             4: 'Autumn'
}

df['season_name'] = df['season'].map(seasons)
df
# Out:
#                  datetime       Description  Humidity  Wind Direction  \
# 0     2012-10-01 13:00:00      heavy clouds     93.00         1001.00
# 1     2012-10-01 14:00:00      sky is clear     91.00          986.00
# 2     2012-10-01 15:00:00      sky is clear     87.00          945.00
# 3     2012-10-01 16:00:00      sky is clear     84.00          904.00
# 4     2012-10-01 17:00:00      sky is clear     80.00          863.00
# ...                   ...               ...       ...             ...
# 45247 2017-11-29 20:00:00  moderate  clouds     64.00         1021.00
# 45248 2017-11-29 21:00:00  moderate  clouds     59.00         1023.00
# 45249 2017-11-29 22:00:00     light  clouds     66.00         1024.00
# 45250 2017-11-29 23:00:00     light  clouds     58.00         1026.00
# 45251 2017-11-30 00:00:00     light  clouds     58.00         1027.00
#
#        Temperature  Pressure  Wind Speed  clouds  rain  mist  snow  shower  \
# 0            12.68    230.00        4.00       1     0     0     0       0
# 1            12.68    230.00        4.00       0     0     0     0       0
# 2            12.70    231.00        4.00       0     0     0     0       0
# 3            12.71    233.00        4.00       0     0     0     0       0
# 4            12.72    234.00        3.00       0     0     0     0       0
# ...            ...       ...         ...     ...   ...   ...   ...     ...
# 45247         1.98    300.00       10.00       1     0     0     0       0
# 45248         0.98    300.00        7.00       1     0     0     0       0
# 45249         0.33    290.00        7.00       1     0     0     0       0
# 45250        -0.67    290.00        4.00       1     0     0     0       0
# 45251        -1.35    300.00        4.00       1     0     0     0       0
#
#        thunderstorm  fog  other  Intensity  season season_name
# 0                 0    0      0       3.00       4      Autumn
# 1                 0    0      0       0.00       4      Autumn
# 2                 0    0      0       0.00       4      Autumn
# 3                 0    0      0       0.00       4      Autumn
# 4                 0    0      0       0.00       4      Autumn
# ...             ...  ...    ...        ...     ...         ...
# 45247             0    0      0       2.00       4      Autumn
# 45248             0    0      0       2.00       4      Autumn
# 45249             0    0      0       1.00       4      Autumn
# 45250             0    0      0       1.00       4      Autumn
# 45251             0    0      0       1.00       4      Autumn
#
# [45252 rows x 18 columns]

# %%
#a function that turns continuous variables into categories, for easier interpreation in causal inference
def cont_into_cat(column):
    labels = ['low', 'medium', 'high']
    df[column+' Quantiles'] = pd.qcut(df[column],
                                              q=3,
                                              labels=labels,
                                              precision=0)

df.sample(5)
# Out:
#                  datetime       Description  Humidity  Wind Direction  \
# 24491 2015-07-19 00:00:00  moderate  clouds     69.00         1009.00
# 33163 2016-07-14 08:00:00     light  clouds     78.00         1015.00
# 44294 2017-10-21 03:00:00      sky is clear     62.00         1020.00
# 44364 2017-10-24 01:00:00  moderate  clouds     72.00         1016.00
# 31093 2016-04-19 02:00:00              mist     93.00         1022.00
#
#        Temperature  Pressure  Wind Speed  clouds  rain  mist  snow  shower  \
# 24491        24.10    290.00        2.00       1     0     0     0       0
# 33163        23.81    220.00        4.00       1     0     0     0       0
# 44294        11.63    250.00        4.00       0     0     0     0       0
# 44364        17.98    160.00        6.00       1     0     0     0       0
# 31093         4.82     30.00        4.00       0     0     1     0       0
#
#        thunderstorm  fog  other  Intensity  season season_name
# 24491             0    0      0       2.00       3      Summer
# 33163             0    0      0       1.00       3      Summer
# 44294             0    0      0       0.00       4      Autumn
# 44364             0    0      0       2.00       4      Autumn
# 31093             0    0      0       2.00       2      Spring

# %%
#test = ['Humidity Quantiles','Wind Speed Quantiles','Pressure Quantiles']
#df.drop(test, axis = 1, inplace = True)
#df.sample(5)

# %%
cont_into_cat('Wind Speed')
cont_into_cat('Humidity')
cont_into_cat('Pressure')

df.sample(5)
# Out:
#                  datetime       Description  Humidity  Wind Direction  \
# 2320  2013-01-06 05:00:00        heavy snow     86.00         1005.00
# 33916 2016-08-14 17:00:00        light rain     84.00         1004.00
# 10153 2013-11-28 14:00:00  moderate  clouds     72.00         1017.00
# 15285 2014-06-30 10:00:00      heavy clouds     73.00         1013.00
# 15693 2014-07-17 10:00:00     light  clouds     87.00         1013.00
#
#        Temperature  Pressure  Wind Speed  clouds  rain  mist  ...  shower  \
# 2320         -1.16    240.00       12.00       0     0     0  ...       0
# 33916        18.62    255.00        6.00       0     1     0  ...       0
# 10153        -8.52    250.00        8.00       1     0     0  ...       0
# 15285        22.31    160.00        4.00       1     0     0  ...       0
# 15693        14.15    240.00        3.00       1     0     0  ...       0
#
#        thunderstorm  fog  other  Intensity  season  season_name  \
# 2320              0    0      0       3.00       1       Winter
# 33916             0    0      0       1.00       3       Summer
# 10153             0    0      0       2.00       4       Autumn
# 15285             0    0      0       3.00       3       Summer
# 15693             0    0      0       1.00       3       Summer
#
#       Wind Speed Quantiles Humidity Quantiles Pressure Quantiles
# 2320                  high               high             medium
# 33916                 high               high               high
# 10153                 high             medium             medium
# 15285               medium             medium             medium
# 15693               medium               high             medium
#
# [5 rows x 21 columns]

# %%
#dummify new categorical variables
import pandas as pd
import numpy as np
df = pd.get_dummies(df, columns = ['Wind Speed Quantiles'])
df = pd.get_dummies(df, columns = ['Humidity Quantiles'])
df = pd.get_dummies(df, columns = ['Pressure Quantiles'])
df = pd.get_dummies(df, columns = ['season_name'])

df.sample(5)
# Out:
#                  datetime       Description  Humidity  Wind Direction  \
# 32456 2016-06-14 21:00:00  moderate  clouds     38.00         1009.00
# 27413 2015-11-17 18:00:00  moderate  clouds     51.00         1035.00
# 148   2012-10-07 17:00:00  moderate  clouds     71.86         1016.42
# 29780 2016-02-24 09:00:00        light snow     92.00         1024.00
# 15914 2014-07-26 15:00:00  moderate  clouds     68.00         1011.00
#
#        Temperature  Pressure  Wind Speed  clouds  rain  mist  ...  \
# 32456        20.70      0.00        1.00       1     0     0  ...
# 27413         3.45     19.00        2.00       1     0     0  ...
# 148          10.36    240.00        5.00       1     0     0  ...
# 29780        -5.31     30.00        3.00       0     0     0  ...
# 15914        22.65    210.00        6.00       1     0     0  ...
#
#        Humidity Quantiles_low  Humidity Quantiles_medium  \
# 32456                       1                          0
# 27413                       1                          0
# 148                         0                          1
# 29780                       0                          0
# 15914                       0                          1
#
#        Humidity Quantiles_high  Pressure Quantiles_low  \
# 32456                        0                       1
# 27413                        0                       1
# 148                          0                       0
# 29780                        1                       1
# 15914                        0                       0
#
#        Pressure Quantiles_medium  Pressure Quantiles_high  season_name_Autumn  \
# 32456                          0                        0                   0
# 27413                          0                        0                   1
# 148                            1                        0                   1
# 29780                          0                        0                   0
# 15914                          1                        0                   0
#
#        season_name_Spring  season_name_Summer  season_name_Winter
# 32456                   0                   1                   0
# 27413                   0                   0                   0
# 148                     0                   0                   0
# 29780                   0                   0                   1
# 15914                   0                   1                   0
#
# [5 rows x 30 columns]

# %%
#cols_drop = ['Temperature', 'Description', 'datetime', 'Humidity', 'Wind Direction','Pressure','Wind Speed','Intensity',]
cols_drop = ['Temperature', 'Description', 'datetime', 'Wind Direction','Intensity','Wind Speed Quantiles_medium',
             'Humidity Quantiles_medium','Pressure Quantiles_medium', 'season','other','shower']

features = df.drop(cols_drop, axis=1)
cols = list(features.columns)
cols
# Out:
# ['Humidity',
#  'Pressure',
#  'Wind Speed',
#  'clouds',
#  'rain',
#  'mist',
#  'snow',
#  'thunderstorm',
#  'fog',
#  'Wind Speed Quantiles_low',
#  'Wind Speed Quantiles_high',
#  'Humidity Quantiles_low',
#  'Humidity Quantiles_high',
#  'Pressure Quantiles_low',
#  'Pressure Quantiles_high',
#  'season_name_Autumn',
#  'season_name_Spring',
#  'season_name_Summer',
#  'season_name_Winter']

# %%
import dowhy
from dowhy import CausalModel

X = df[cols]
effects = dict()
test = dict()

for i in X:
    model = CausalModel(data = df,
                        treatment = i,
                        outcome = 'Temperature',
                        common_causes = list(X.drop(i, axis = 'columns').columns))
    
    identified_estimand = model.identify_effect(proceed_when_unidentifiable=True)

    estimate = model.estimate_effect(identified_estimand,
                                     method_name="backdoor.linear_regression",
                                    test_significance = True)
    
    effects[i] = estimate.value
    test[i] = estimate
# Out:
# WARNING:dowhy.causal_model:Causal Graph not provided. DoWhy will construct a graph based on data inputs.
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['Humidity'] on outcome ['Temperature']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# INFO:dowhy.causal_identifier:Continuing by ignoring these unobserved confounders because proceed_when_unidentifiable flag is True.
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:[]
# INFO:dowhy.causal_identifier:Frontdoor variables for treatment and outcome:[]
# INFO:dowhy.causal_estimator:b: Temperature~Humidity+Wind Speed+rain+season_name_Winter+Humidity Quantiles_high+Wind Speed Quantiles_low+Pressure Quantiles_high+season_name_Spring+season_name_Summer+fog+mist+Pressure+season_name_Autumn+clouds+Pressure Quantiles_low+snow+Wind Speed Quantiles_high+Humidity Quantiles_low+thunderstorm
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# WARNING:dowhy.causal_model:Causal Graph not provided. DoWhy will construct a graph based on data inputs.
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['Pressure'] on outcome ['Temperature']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# INFO:dowhy.causal_identifier:Continuing by ignoring these unobserved confounders because proceed_when_unidentifiable flag is True.
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:[]
# INFO:dowhy.causal_identifier:Frontdoor variables for treatment and outcome:[]
# INFO:dowhy.causal_estimator:b: Temperature~Pressure+Wind Speed+rain+season_name_Winter+Humidity Quantiles_high+Wind Speed Quantiles_low+Pressure Quantiles_high+season_name_Spring+season_name_Summer+fog+mist+season_name_Autumn+clouds+Pressure Quantiles_low+Humidity+snow+Wind Speed Quantiles_high+Humidity Quantiles_low+thunderstorm
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# WARNING:dowhy.causal_model:Causal Graph not provided. DoWhy will construct a graph based on data inputs.
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['Wind Speed'] on outcome ['Temperature']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# INFO:dowhy.causal_identifier:Continuing by ignoring these unobserved confounders because proceed_when_unidentifiable flag is True.
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:[]
# INFO:dowhy.causal_identifier:Frontdoor variables for treatment and outcome:[]
# INFO:dowhy.causal_estimator:b: Temperature~Wind Speed+rain+season_name_Winter+Humidity Quantiles_high+Wind Speed Quantiles_low+Pressure Quantiles_high+season_name_Spring+season_name_Summer+fog+mist+Pressure+season_name_Autumn+clouds+Pressure Quantiles_low+Humidity+snow+Wind Speed Quantiles_high+Humidity Quantiles_low+thunderstorm
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# WARNING:dowhy.causal_model:Causal Graph not provided. DoWhy will construct a graph based on data inputs.
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['clouds'] on outcome ['Temperature']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# INFO:dowhy.causal_identifier:Continuing by ignoring these unobserved confounders because proceed_when_unidentifiable flag is True.
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:[]
# INFO:dowhy.causal_identifier:Frontdoor variables for treatment and outcome:[]
# INFO:dowhy.causal_estimator:b: Temperature~clouds+Wind Speed+rain+season_name_Winter+Humidity Quantiles_high+Wind Speed Quantiles_low+Pressure Quantiles_high+season_name_Spring+season_name_Summer+fog+mist+Pressure+season_name_Autumn+Pressure Quantiles_low+Humidity+snow+Wind Speed Quantiles_high+Humidity Quantiles_low+thunderstorm
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# WARNING:dowhy.causal_model:Causal Graph not provided. DoWhy will construct a graph based on data inputs.
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['rain'] on outcome ['Temperature']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# INFO:dowhy.causal_identifier:Continuing by ignoring these unobserved confounders because proceed_when_unidentifiable flag is True.
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:[]
# INFO:dowhy.causal_identifier:Frontdoor variables for treatment and outcome:[]
# INFO:dowhy.causal_estimator:b: Temperature~rain+Wind Speed+season_name_Winter+Humidity Quantiles_high+Wind Speed Quantiles_low+Pressure Quantiles_high+season_name_Spring+season_name_Summer+fog+mist+Pressure+season_name_Autumn+clouds+Pressure Quantiles_low+Humidity+snow+Wind Speed Quantiles_high+Humidity Quantiles_low+thunderstorm
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# WARNING:dowhy.causal_model:Causal Graph not provided. DoWhy will construct a graph based on data inputs.
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['mist'] on outcome ['Temperature']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# INFO:dowhy.causal_identifier:Continuing by ignoring these unobserved confounders because proceed_when_unidentifiable flag is True.
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:[]
# INFO:dowhy.causal_identifier:Frontdoor variables for treatment and outcome:[]
# INFO:dowhy.causal_estimator:b: Temperature~mist+Wind Speed+rain+season_name_Winter+Humidity Quantiles_high+Wind Speed Quantiles_low+Pressure Quantiles_high+season_name_Spring+season_name_Summer+fog+Pressure+season_name_Autumn+clouds+Pressure Quantiles_low+Humidity+snow+Wind Speed Quantiles_high+Humidity Quantiles_low+thunderstorm
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# WARNING:dowhy.causal_model:Causal Graph not provided. DoWhy will construct a graph based on data inputs.
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['snow'] on outcome ['Temperature']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# INFO:dowhy.causal_identifier:Continuing by ignoring these unobserved confounders because proceed_when_unidentifiable flag is True.
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:[]
# INFO:dowhy.causal_identifier:Frontdoor variables for treatment and outcome:[]
# INFO:dowhy.causal_estimator:b: Temperature~snow+Wind Speed+rain+season_name_Winter+Humidity Quantiles_high+Wind Speed Quantiles_low+Pressure Quantiles_high+season_name_Spring+season_name_Summer+fog+mist+Pressure+season_name_Autumn+clouds+Pressure Quantiles_low+Humidity+Wind Speed Quantiles_high+Humidity Quantiles_low+thunderstorm
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# WARNING:dowhy.causal_model:Causal Graph not provided. DoWhy will construct a graph based on data inputs.
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['thunderstorm'] on outcome ['Temperature']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# INFO:dowhy.causal_identifier:Continuing by ignoring these unobserved confounders because proceed_when_unidentifiable flag is True.
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:[]
# INFO:dowhy.causal_identifier:Frontdoor variables for treatment and outcome:[]
# INFO:dowhy.causal_estimator:b: Temperature~thunderstorm+Wind Speed+rain+season_name_Winter+Humidity Quantiles_high+Wind Speed Quantiles_low+Pressure Quantiles_high+season_name_Spring+season_name_Summer+fog+mist+Pressure+season_name_Autumn+clouds+Pressure Quantiles_low+Humidity+snow+Wind Speed Quantiles_high+Humidity Quantiles_low
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# WARNING:dowhy.causal_model:Causal Graph not provided. DoWhy will construct a graph based on data inputs.
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['fog'] on outcome ['Temperature']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# INFO:dowhy.causal_identifier:Continuing by ignoring these unobserved confounders because proceed_when_unidentifiable flag is True.
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:[]
# INFO:dowhy.causal_identifier:Frontdoor variables for treatment and outcome:[]
# INFO:dowhy.causal_estimator:b: Temperature~fog+Wind Speed+rain+season_name_Winter+Humidity Quantiles_high+Wind Speed Quantiles_low+Pressure Quantiles_high+season_name_Spring+season_name_Summer+mist+Pressure+season_name_Autumn+clouds+Pressure Quantiles_low+Humidity+snow+Wind Speed Quantiles_high+Humidity Quantiles_low+thunderstorm
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# WARNING:dowhy.causal_model:Causal Graph not provided. DoWhy will construct a graph based on data inputs.
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['Wind Speed Quantiles_low'] on outcome ['Temperature']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# INFO:dowhy.causal_identifier:Continuing by ignoring these unobserved confounders because proceed_when_unidentifiable flag is True.
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:[]
# INFO:dowhy.causal_identifier:Frontdoor variables for treatment and outcome:[]
# INFO:dowhy.causal_estimator:b: Temperature~Wind Speed Quantiles_low+Wind Speed+rain+season_name_Winter+Humidity Quantiles_high+Pressure Quantiles_high+season_name_Spring+season_name_Summer+fog+mist+Pressure+season_name_Autumn+clouds+Pressure Quantiles_low+Humidity+snow+Wind Speed Quantiles_high+Humidity Quantiles_low+thunderstorm
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# WARNING:dowhy.causal_model:Causal Graph not provided. DoWhy will construct a graph based on data inputs.
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['Wind Speed Quantiles_high'] on outcome ['Temperature']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# INFO:dowhy.causal_identifier:Continuing by ignoring these unobserved confounders because proceed_when_unidentifiable flag is True.
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:[]
# INFO:dowhy.causal_identifier:Frontdoor variables for treatment and outcome:[]
# INFO:dowhy.causal_estimator:b: Temperature~Wind Speed Quantiles_high+Wind Speed+rain+season_name_Winter+Humidity Quantiles_high+Wind Speed Quantiles_low+Pressure Quantiles_high+season_name_Spring+season_name_Summer+mist+Pressure+season_name_Autumn+clouds+Pressure Quantiles_low+Humidity+snow+fog+Humidity Quantiles_low+thunderstorm
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# WARNING:dowhy.causal_model:Causal Graph not provided. DoWhy will construct a graph based on data inputs.
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['Humidity Quantiles_low'] on outcome ['Temperature']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# INFO:dowhy.causal_identifier:Continuing by ignoring these unobserved confounders because proceed_when_unidentifiable flag is True.
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:[]
# INFO:dowhy.causal_identifier:Frontdoor variables for treatment and outcome:[]
# INFO:dowhy.causal_estimator:b: Temperature~Humidity Quantiles_low+Wind Speed+rain+season_name_Winter+Humidity Quantiles_high+Wind Speed Quantiles_low+Pressure Quantiles_high+season_name_Spring+season_name_Summer+fog+mist+Pressure+season_name_Autumn+clouds+Pressure Quantiles_low+Humidity+snow+Wind Speed Quantiles_high+thunderstorm
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# WARNING:dowhy.causal_model:Causal Graph not provided. DoWhy will construct a graph based on data inputs.
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['Humidity Quantiles_high'] on outcome ['Temperature']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# INFO:dowhy.causal_identifier:Continuing by ignoring these unobserved confounders because proceed_when_unidentifiable flag is True.
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:[]
# INFO:dowhy.causal_identifier:Frontdoor variables for treatment and outcome:[]
# INFO:dowhy.causal_estimator:b: Temperature~Humidity Quantiles_high+Wind Speed+rain+season_name_Winter+Wind Speed Quantiles_low+Pressure Quantiles_high+season_name_Spring+season_name_Summer+fog+mist+Pressure+season_name_Autumn+clouds+Pressure Quantiles_low+Humidity+snow+Wind Speed Quantiles_high+Humidity Quantiles_low+thunderstorm
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# WARNING:dowhy.causal_model:Causal Graph not provided. DoWhy will construct a graph based on data inputs.
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['Pressure Quantiles_low'] on outcome ['Temperature']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# INFO:dowhy.causal_identifier:Continuing by ignoring these unobserved confounders because proceed_when_unidentifiable flag is True.
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:[]
# INFO:dowhy.causal_identifier:Frontdoor variables for treatment and outcome:[]
# INFO:dowhy.causal_estimator:b: Temperature~Pressure Quantiles_low+Wind Speed+rain+season_name_Winter+Humidity Quantiles_high+Wind Speed Quantiles_low+Pressure Quantiles_high+season_name_Spring+season_name_Summer+fog+mist+Pressure+season_name_Autumn+clouds+Humidity+snow+Wind Speed Quantiles_high+Humidity Quantiles_low+thunderstorm
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# WARNING:dowhy.causal_model:Causal Graph not provided. DoWhy will construct a graph based on data inputs.
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['Pressure Quantiles_high'] on outcome ['Temperature']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# INFO:dowhy.causal_identifier:Continuing by ignoring these unobserved confounders because proceed_when_unidentifiable flag is True.
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:[]
# INFO:dowhy.causal_identifier:Frontdoor variables for treatment and outcome:[]
# INFO:dowhy.causal_estimator:b: Temperature~Pressure Quantiles_high+Wind Speed+rain+season_name_Winter+Humidity Quantiles_high+Wind Speed Quantiles_low+season_name_Spring+season_name_Summer+fog+mist+Pressure+season_name_Autumn+clouds+Pressure Quantiles_low+Humidity+snow+Wind Speed Quantiles_high+Humidity Quantiles_low+thunderstorm
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# WARNING:dowhy.causal_model:Causal Graph not provided. DoWhy will construct a graph based on data inputs.
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['season_name_Autumn'] on outcome ['Temperature']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# INFO:dowhy.causal_identifier:Continuing by ignoring these unobserved confounders because proceed_when_unidentifiable flag is True.
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:[]
# INFO:dowhy.causal_identifier:Frontdoor variables for treatment and outcome:[]
# INFO:dowhy.causal_estimator:b: Temperature~season_name_Autumn+Wind Speed+rain+season_name_Winter+Humidity Quantiles_high+Wind Speed Quantiles_low+Pressure Quantiles_high+season_name_Spring+season_name_Summer+fog+mist+Pressure+clouds+Pressure Quantiles_low+Humidity+snow+Wind Speed Quantiles_high+Humidity Quantiles_low+thunderstorm
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# WARNING:dowhy.causal_model:Causal Graph not provided. DoWhy will construct a graph based on data inputs.
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['season_name_Spring'] on outcome ['Temperature']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# INFO:dowhy.causal_identifier:Continuing by ignoring these unobserved confounders because proceed_when_unidentifiable flag is True.
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:[]
# INFO:dowhy.causal_identifier:Frontdoor variables for treatment and outcome:[]
# INFO:dowhy.causal_estimator:b: Temperature~season_name_Spring+Wind Speed+rain+season_name_Winter+Humidity Quantiles_high+Wind Speed Quantiles_low+Pressure Quantiles_high+season_name_Summer+fog+mist+Pressure+season_name_Autumn+clouds+Pressure Quantiles_low+Humidity+snow+Wind Speed Quantiles_high+Humidity Quantiles_low+thunderstorm
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# WARNING:dowhy.causal_model:Causal Graph not provided. DoWhy will construct a graph based on data inputs.
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['season_name_Summer'] on outcome ['Temperature']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# INFO:dowhy.causal_identifier:Continuing by ignoring these unobserved confounders because proceed_when_unidentifiable flag is True.
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:[]
# INFO:dowhy.causal_identifier:Frontdoor variables for treatment and outcome:[]
# INFO:dowhy.causal_estimator:b: Temperature~season_name_Summer+Wind Speed+rain+season_name_Winter+Humidity Quantiles_high+Wind Speed Quantiles_low+Pressure Quantiles_high+season_name_Spring+fog+mist+Pressure+season_name_Autumn+clouds+Pressure Quantiles_low+Humidity+snow+Wind Speed Quantiles_high+Humidity Quantiles_low+thunderstorm
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator
# WARNING:dowhy.causal_model:Causal Graph not provided. DoWhy will construct a graph based on data inputs.
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['season_name_Winter'] on outcome ['Temperature']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# INFO:dowhy.causal_identifier:Continuing by ignoring these unobserved confounders because proceed_when_unidentifiable flag is True.
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:[]
# INFO:dowhy.causal_identifier:Frontdoor variables for treatment and outcome:[]
# INFO:dowhy.causal_estimator:b: Temperature~season_name_Winter+Wind Speed+rain+Humidity Quantiles_high+Wind Speed Quantiles_low+Pressure Quantiles_high+season_name_Spring+season_name_Summer+fog+mist+Pressure+season_name_Autumn+clouds+Pressure Quantiles_low+Humidity+snow+Wind Speed Quantiles_high+Humidity Quantiles_low+thunderstorm
# INFO:dowhy.causal_estimator:INFO: Using Linear Regression Estimator

# %%
pd.options.display.float_format = '{:.2f}'.format
#pd.reset_option('^display.', silent=True)
causal_inf_output()
# Out:
# C:\Users\Steven\anaconda3\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#
# C:\Users\Steven\anaconda3\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   if __name__ == '__main__':
#                       Feature  P-Values  Estimate
# 18         season_name_Winter      0.00    -10.23
# 14    Pressure Quantiles_high      0.00     -4.08
# 6                        snow      0.00     -1.55
# 11     Humidity Quantiles_low      0.00     -0.97
# 13     Pressure Quantiles_low      0.00     -0.78
# 9    Wind Speed Quantiles_low      0.00     -0.69
# 10  Wind Speed Quantiles_high      0.00     -0.57
# 0                    Humidity      0.00     -0.11
# 1                    Pressure      0.00      0.01
# 2                  Wind Speed      0.00      0.20
# 16         season_name_Spring      0.00      0.92
# 3                      clouds      0.00      1.34
# 12    Humidity Quantiles_high      0.00      1.82
# 4                        rain      0.00      2.81
# 5                        mist      0.00      3.46
# 8                         fog      0.00      3.56
# 7                thunderstorm      0.00      4.30
# 15         season_name_Autumn      0.00      5.07
# 17         season_name_Summer      0.00     15.03
