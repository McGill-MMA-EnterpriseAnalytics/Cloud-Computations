# %% [markdown]
# # INSY 695 - AutoML using Ludwig

# %%
import pandas as pd
import numpy as np
import os
import platform as pf
from IPython.display import display # Display data
pd.options.mode.chained_assignment = None  # default='warn'

#comment
#packages for time series
import warnings
import itertools    
import statsmodels.api as sm

#Richard was here
from datetime import timedelta
from dateutil.relativedelta import relativedelta
import matplotlib.pyplot as plt
import math
from scipy import stats

plt.style.use('fivethirtyeight')

# %% [markdown]
# ## Import Data

# %%
#import helper file 
import helper
from helper import *

# %%
df = load_and_preprocess()

# %%
df
# Out:
#                   datetime       Description  Humidity  Wind Direction  \
# 1      2012-10-01 13:00:00      heavy clouds      93.0          1001.0
# 2      2012-10-01 14:00:00      sky is clear      91.0           986.0
# 3      2012-10-01 15:00:00      sky is clear      87.0           945.0
# 4      2012-10-01 16:00:00      sky is clear      84.0           904.0
# 5      2012-10-01 17:00:00      sky is clear      80.0           863.0
# ...                    ...               ...       ...             ...
# 45248  2017-11-29 20:00:00  moderate  clouds      64.0          1021.0
# 45249  2017-11-29 21:00:00  moderate  clouds      59.0          1023.0
# 45250  2017-11-29 22:00:00     light  clouds      66.0          1024.0
# 45251  2017-11-29 23:00:00     light  clouds      58.0          1026.0
# 45252  2017-11-30 00:00:00     light  clouds      58.0          1027.0
#
#        Temperature  Pressure  Wind Speed  clouds  rain  mist  snow  shower  \
# 1       285.830000     230.0         4.0       1     0     0     0       0
# 2       285.834650     230.0         4.0       0     0     0     0       0
# 3       285.847790     231.0         4.0       0     0     0     0       0
# 4       285.860929     233.0         4.0       0     0     0     0       0
# 5       285.874069     234.0         3.0       0     0     0     0       0
# ...            ...       ...         ...     ...   ...   ...   ...     ...
# 45248   275.130000     300.0        10.0       1     0     0     0       0
# 45249   274.130000     300.0         7.0       1     0     0     0       0
# 45250   273.480000     290.0         7.0       1     0     0     0       0
# 45251   272.480000     290.0         4.0       1     0     0     0       0
# 45252   271.800000     300.0         4.0       1     0     0     0       0
#
#        thunderstorm  fog  other  Intensity
# 1                 0    0      0        3.0
# 2                 0    0      0        0.0
# 3                 0    0      0        0.0
# 4                 0    0      0        0.0
# 5                 0    0      0        0.0
# ...             ...  ...    ...        ...
# 45248             0    0      0        2.0
# 45249             0    0      0        2.0
# 45250             0    0      0        1.0
# 45251             0    0      0        1.0
# 45252             0    0      0        1.0
#
# [45252 rows x 16 columns]

# %%
weather_df = df[['datetime', 'Temperature']].set_index('datetime')
weather_df = weather_df.reset_index()
weather_df['Temperature'] = weather_df['Temperature'] - 273.15
weather_df.resample('D').mean()
# Out:
#                   datetime  Temperature
# 0      2012-10-01 13:00:00    12.680000
# 1      2012-10-01 14:00:00    12.684650
# 2      2012-10-01 15:00:00    12.697790
# 3      2012-10-01 16:00:00    12.710929
# 4      2012-10-01 17:00:00    12.724069
# ...                    ...          ...
# 45247  2017-11-29 20:00:00     1.980000
# 45248  2017-11-29 21:00:00     0.980000
# 45249  2017-11-29 22:00:00     0.330000
# 45250  2017-11-29 23:00:00    -0.670000
# 45251  2017-11-30 00:00:00    -1.350000
#
# [45252 rows x 2 columns]

# %% [markdown]
# ## Format into Train and Test sets
#
# Format data for time-series prediction by specifying train, validation, and tests sets and generate a new csv to store the formatted data in.

# %%
import pandas as pd
from ludwig.utils.data_utils import add_sequence_feature_column

ludwig_df = (weather_df[['Temperature']]
).rename(
    columns={"Temperature": "temperature"}
).fillna(method='backfill').fillna(method='ffill')

# normalize
#ludwig_df.temperature = ((ludwig_df.temperature-ludwig_df.temperature.mean()) /
                  #ludwig_df.temperature.std())

train_size = int(0.6 * len(ludwig_df))
vali_size = int(0.2 * len(ludwig_df))

# train, validation, test split
ludwig_df['split'] = 0
ludwig_df.loc[
    (
        (df.index.values >= train_size) &
        (df.index.values < train_size + vali_size)
    ),
    ('split')
] = 1
ludwig_df.loc[
    df.index.values >= train_size + vali_size,
    ('split')
] = 2

# prepare timeseries input feature colum
# (here we are using 20 preceding values to predict the target)
add_sequence_feature_column(ludwig_df, 'temperature', 20)
ludwig_df.to_csv('temperature_ludwig.csv')

# %%
ludwig_df
# Out:
#        temperature  split                                temperature_feature
# 0        12.680000      0  12.680000000000007 12.684649953000019 12.69778...
# 1        12.684650      0  12.680000000000007 12.684649953000019 12.69778...
# 2        12.697790      0  12.680000000000007 12.684649953000019 12.69778...
# 3        12.710929      0  12.680000000000007 12.684649953000019 12.69778...
# 4        12.724069      0  12.680000000000007 12.684649953000019 12.69778...
# ...            ...    ...                                                ...
# 45247     1.980000      2  1.580000000000041 1.8799999999999955 1.2000000...
# 45248     0.980000      2  1.8799999999999955 1.2000000000000455 1.850000...
# 45249     0.330000      2  1.2000000000000455 1.8500000000000227 2.550000...
# 45250    -0.670000      2  1.8500000000000227 2.5500000000000114 3.230000...
# 45251    -1.350000      2  2.5500000000000114 3.230000000000018 2.5700000...
#
# [45252 rows x 3 columns]

# %% [markdown]
# ## Time Series Forecast using Ludwig

# %%
! pip install pyyaml
# Out:
# Requirement already satisfied: pyyaml in /opt/anaconda3/lib/python3.7/site-packages (5.3.1)

# %% [markdown]
# **Generate YAML config file**
#
# First, we create a YAML file which stores the configurations neeeded to run the time-series data. We specify the inputs and outputs, and run an RNN analysis using Ludwig.

# %%
import yaml

with open('config.yaml') as file:
    # The FullLoader parameter handles the conversion from YAML
    # scalar values to Python the dictionary format
    config = yaml.load(file, Loader=yaml.FullLoader)

    print(config)
# Out:
# {'input_features': [{'name': 'temperature_feature', 'type': 'timeseries', 'encoder': 'rnn', 'embedding_size': 32, 'state_size': 32}], 'output_features': [{'name': 'temperature', 'type': 'numerical'}]}

# %% [markdown]
# **Run Ludwig experiment in command line**
#
# Specify the formatted time series dataframe as input as well as the config.yaml file to run the analysis. The train, validation, and test losses are recorded at each epoch. Early stopping of the training occurs due to lack of validation improvement once there has been 5 epochs since the last validation improvement, and the losses and R^2 score are recorded.
#
# The logs are stored which can be visualized.

# %%
# !ludwig experiment \
--dataset temperature_ludwig.csv \
--config_file config.yaml
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/typeguard/__init__.py:917: UserWarning: no type annotations present -- not typechecking tensorflow_addons.layers.max_unpooling_2d.MaxUnpooling2D.__init__
#   warn('no type annotations present -- not typechecking {}'.format(function_name(func)))
# ███████████████████████
# █ █ █ █  ▜█ █ █ █ █   █
# █ █ █ █ █ █ █ █ █ █ ███
# █ █   █ █ █ █ █ █ █ ▌ █
# █ █████ █ █ █ █ █ █ █ █
# █     █  ▟█     █ █   █
# ███████████████████████
# ludwig v0.3.3 - Experiment
#
# 2021-04-08 23:01:57.035638: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# Experiment name: experiment
# Model name: run
# Output directory: results/experiment_run
#
#
# ludwig_version: '0.3.3'
# command: ('/opt/anaconda3/bin/ludwig experiment --dataset temperature_ludwig.csv '
#  '--config_file config.yaml')
# commit_hash: 'e3ca13aaa2d9'
# random_seed: 42
# dataset: 'temperature_ludwig.csv'
# data_format: 'csv'
# config: {   'combiner': {'type': 'concat'},
#     'input_features': [   {   'column': 'temperature_feature',
#                               'embedding_size': 32,
#                               'encoder': 'rnn',
#                               'name': 'temperature_feature',
#                               'proc_column': 'temperature_feature_mZFLky',
#                               'state_size': 32,
#                               'tied': None,
#                               'type': 'timeseries'}],
#     'output_features': [   {   'clip': None,
#                                'column': 'temperature',
#                                'dependencies': [],
#                                'loss': {   'type': 'mean_squared_error',
#                                            'weight': 1},
#                                'name': 'temperature',
#                                'proc_column': 'temperature_mZFLky',
#                                'reduce_dependencies': 'sum',
#                                'reduce_input': 'sum',
#                                'type': 'numerical'}],
#     'preprocessing': {   'audio': {   'audio_feature': {'type': 'raw'},
#                                       'audio_file_length_limit_in_s': 7.5,
#                                       'in_memory': True,
#                                       'missing_value_strategy': 'backfill',
#                                       'norm': None,
#                                       'padding_value': 0},
#                          'bag': {   'fill_value': '<UNK>',
#                                     'lowercase': False,
#                                     'missing_value_strategy': 'fill_with_const',
#                                     'most_common': 10000,
#                                     'tokenizer': 'space'},
#                          'binary': {   'fill_value': 0,
#                                        'missing_value_strategy': 'fill_with_const'},
#                          'category': {   'fill_value': '<UNK>',
#                                          'lowercase': False,
#                                          'missing_value_strategy': 'fill_with_const',
#                                          'most_common': 10000},
#                          'date': {   'datetime_format': None,
#                                      'fill_value': '',
#                                      'missing_value_strategy': 'fill_with_const'},
#                          'force_split': False,
#                          'h3': {   'fill_value': 576495936675512319,
#                                    'missing_value_strategy': 'fill_with_const'},
#                          'image': {   'in_memory': True,
#                                       'missing_value_strategy': 'backfill',
#                                       'num_processes': 1,
#                                       'resize_method': 'interpolate',
#                                       'scaling': 'pixel_normalization'},
#                          'numerical': {   'fill_value': 0,
#                                           'missing_value_strategy': 'fill_with_const',
#                                           'normalization': None},
#                          'sequence': {   'fill_value': '<UNK>',
#                                          'lowercase': False,
#                                          'missing_value_strategy': 'fill_with_const',
#                                          'most_common': 20000,
#                                          'padding': 'right',
#                                          'padding_symbol': '<PAD>',
#                                          'sequence_length_limit': 256,
#                                          'tokenizer': 'space',
#                                          'unknown_symbol': '<UNK>',
#                                          'vocab_file': None},
#                          'set': {   'fill_value': '<UNK>',
#                                     'lowercase': False,
#                                     'missing_value_strategy': 'fill_with_const',
#                                     'most_common': 10000,
#                                     'tokenizer': 'space'},
#                          'split_probabilities': (0.7, 0.1, 0.2),
#                          'stratify': None,
#                          'text': {   'char_most_common': 70,
#                                      'char_sequence_length_limit': 1024,
#                                      'char_tokenizer': 'characters',
#                                      'char_vocab_file': None,
#                                      'fill_value': '<UNK>',
#                                      'lowercase': True,
#                                      'missing_value_strategy': 'fill_with_const',
#                                      'padding': 'right',
#                                      'padding_symbol': '<PAD>',
#                                      'pretrained_model_name_or_path': None,
#                                      'unknown_symbol': '<UNK>',
#                                      'word_most_common': 20000,
#                                      'word_sequence_length_limit': 256,
#                                      'word_tokenizer': 'space_punct',
#                                      'word_vocab_file': None},
#                          'timeseries': {   'fill_value': '',
#                                            'missing_value_strategy': 'fill_with_const',
#                                            'padding': 'right',
#                                            'padding_value': 0,
#                                            'timeseries_length_limit': 256,
#                                            'tokenizer': 'space'},
#                          'vector': {   'fill_value': '',
#                                        'missing_value_strategy': 'fill_with_const'}},
#     'training': {   'batch_size': 128,
#                     'bucketing_field': None,
#                     'decay': False,
#                     'decay_rate': 0.96,
#                     'decay_steps': 10000,
#                     'early_stop': 5,
#                     'epochs': 100,
#                     'eval_batch_size': 0,
#                     'gradient_clipping': None,
#                     'increase_batch_size_on_plateau': 0,
#                     'increase_batch_size_on_plateau_max': 512,
#                     'increase_batch_size_on_plateau_patience': 5,
#                     'increase_batch_size_on_plateau_rate': 2,
#                     'learning_rate': 0.001,
#                     'learning_rate_warmup_epochs': 1,
#                     'optimizer': {   'beta_1': 0.9,
#                                      'beta_2': 0.999,
#                                      'epsilon': 1e-08,
#                                      'type': 'adam'},
#                     'reduce_learning_rate_on_plateau': 0,
#                     'reduce_learning_rate_on_plateau_patience': 5,
#                     'reduce_learning_rate_on_plateau_rate': 0.5,
#                     'regularization_lambda': 0,
#                     'regularizer': 'l2',
#                     'staircase': False,
#                     'validation_field': 'combined',
#                     'validation_metric': 'loss'}}
# tf_version: '2.4.1'
#
#
# Using full raw csv, no hdf5 and json file with the same name have been found
# Building dataset (it may take a while)
# Writing preprocessed dataset cache
# Writing train set metadata
# Training set: 27150
# Validation set: 9050
# Test set: 9052
# 2021-04-08 23:02:00.079358: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
#
# ╒══════════╕
# │ TRAINING │
# ╘══════════╛
#
#
# Epoch   1
# Training:   0%|                                         | 0/213 [00:00<?, ?it/s]2021-04-08 23:02:02.261615: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# Training: 100%|███████████████████████████████| 213/213 [00:03<00:00, 61.97it/s]
# Evaluation train: 100%|██████████████████████| 213/213 [00:01<00:00, 153.44it/s]
# Evaluation vali : 100%|████████████████████████| 71/71 [00:00<00:00, 268.67it/s]
# Evaluation test : 100%|████████████████████████| 71/71 [00:00<00:00, 258.28it/s]
# Took 5.4415s
# ╒═══════════════╤═════════╤═════════╤══════════════════════╤═══════════════════════╤════════╕
# │ temperature   │    loss │   error │   mean_squared_error │   mean_absolute_error │     r2 │
# ╞═══════════════╪═════════╪═════════╪══════════════════════╪═══════════════════════╪════════╡
# │ train         │ 79.2602 │  4.1106 │              79.2601 │                6.5995 │ 0.4838 │
# ├───────────────┼─────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ vali          │ 74.6898 │  4.5644 │              74.6898 │                6.0423 │ 0.3941 │
# ├───────────────┼─────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ test          │ 69.7010 │  4.4027 │              69.7010 │                6.0196 │ 0.4544 │
# ╘═══════════════╧═════════╧═════════╧══════════════════════╧═══════════════════════╧════════╛
# ╒════════════╤═════════╕
# │ combined   │    loss │
# ╞════════════╪═════════╡
# │ train      │ 58.8158 │
# ├────────────┼─────────┤
# │ vali       │ 36.1113 │
# ├────────────┼─────────┤
# │ test       │ 37.1938 │
# ╘════════════╧═════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch   2
# Training: 100%|██████████████████████████████| 213/213 [00:00<00:00, 247.40it/s]
# Evaluation train: 100%|██████████████████████| 213/213 [00:00<00:00, 731.70it/s]
# Evaluation vali : 100%|████████████████████████| 71/71 [00:00<00:00, 659.23it/s]
# Evaluation test : 100%|████████████████████████| 71/71 [00:00<00:00, 722.78it/s]
# Took 1.3789s
# ╒═══════════════╤═════════╤═════════╤══════════════════════╤═══════════════════════╤════════╕
# │ temperature   │    loss │   error │   mean_squared_error │   mean_absolute_error │     r2 │
# ╞═══════════════╪═════════╪═════════╪══════════════════════╪═══════════════════════╪════════╡
# │ train         │ 11.4655 │  1.1357 │              11.4655 │                2.0085 │ 0.9252 │
# ├───────────────┼─────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ vali          │ 11.3252 │  1.2822 │              11.3252 │                1.9805 │ 0.9081 │
# ├───────────────┼─────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ test          │  8.7015 │  1.1067 │               8.7015 │                1.7356 │ 0.9319 │
# ╘═══════════════╧═════════╧═════════╧══════════════════════╧═══════════════════════╧════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 8.4043 │
# ├────────────┼────────┤
# │ vali       │ 5.4808 │
# ├────────────┼────────┤
# │ test       │ 4.5359 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch   3
# Training: 100%|██████████████████████████████| 213/213 [00:00<00:00, 268.41it/s]
# Evaluation train: 100%|██████████████████████| 213/213 [00:00<00:00, 709.33it/s]
# Evaluation vali : 100%|████████████████████████| 71/71 [00:00<00:00, 755.69it/s]
# Evaluation test : 100%|████████████████████████| 71/71 [00:00<00:00, 743.70it/s]
# Took 1.3045s
# ╒═══════════════╤════════╤═════════╤══════════════════════╤═══════════════════════╤════════╕
# │ temperature   │   loss │   error │   mean_squared_error │   mean_absolute_error │     r2 │
# ╞═══════════════╪════════╪═════════╪══════════════════════╪═══════════════════════╪════════╡
# │ train         │ 2.6773 │  0.1606 │               2.6773 │                0.9050 │ 0.9825 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ vali          │ 2.1956 │  0.2089 │               2.1956 │                0.8968 │ 0.9822 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ test          │ 1.4712 │  0.1233 │               1.4712 │                0.7501 │ 0.9885 │
# ╘═══════════════╧════════╧═════════╧══════════════════════╧═══════════════════════╧════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 2.2958 │
# ├────────────┼────────┤
# │ vali       │ 1.3434 │
# ├────────────┼────────┤
# │ test       │ 0.9398 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch   4
# Training: 100%|██████████████████████████████| 213/213 [00:00<00:00, 227.98it/s]
# Evaluation train: 100%|██████████████████████| 213/213 [00:00<00:00, 795.83it/s]
# Evaluation vali : 100%|████████████████████████| 71/71 [00:00<00:00, 662.10it/s]
# Evaluation test : 100%|████████████████████████| 71/71 [00:00<00:00, 735.04it/s]
# Took 1.4263s
# ╒═══════════════╤════════╤═════════╤══════════════════════╤═══════════════════════╤════════╕
# │ temperature   │   loss │   error │   mean_squared_error │   mean_absolute_error │     r2 │
# ╞═══════════════╪════════╪═════════╪══════════════════════╪═══════════════════════╪════════╡
# │ train         │ 1.8550 │  0.0709 │               1.8550 │                0.7506 │ 0.9879 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ vali          │ 1.3026 │  0.0987 │               1.3026 │                0.7256 │ 0.9895 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ test          │ 0.8840 │  0.0662 │               0.8840 │                0.6220 │ 0.9931 │
# ╘═══════════════╧════════╧═════════╧══════════════════════╧═══════════════════════╧════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 1.7140 │
# ├────────────┼────────┤
# │ vali       │ 0.9305 │
# ├────────────┼────────┤
# │ test       │ 0.6670 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch   5
# Training: 100%|██████████████████████████████| 213/213 [00:00<00:00, 254.15it/s]
# Evaluation train: 100%|██████████████████████| 213/213 [00:00<00:00, 747.11it/s]
# Evaluation vali : 100%|████████████████████████| 71/71 [00:00<00:00, 796.88it/s]
# Evaluation test : 100%|████████████████████████| 71/71 [00:00<00:00, 761.47it/s]
# Took 1.3265s
# ╒═══════════════╤════════╤═════════╤══════════════════════╤═══════════════════════╤════════╕
# │ temperature   │   loss │   error │   mean_squared_error │   mean_absolute_error │     r2 │
# ╞═══════════════╪════════╪═════════╪══════════════════════╪═══════════════════════╪════════╡
# │ train         │ 1.6934 │  0.1141 │               1.6934 │                0.7266 │ 0.9890 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ vali          │ 1.1426 │  0.1546 │               1.1426 │                0.6997 │ 0.9907 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ test          │ 0.7878 │  0.1135 │               0.7878 │                0.6046 │ 0.9939 │
# ╘═══════════════╧════════╧═════════╧══════════════════════╧═══════════════════════╧════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 1.6091 │
# ├────────────┼────────┤
# │ vali       │ 0.8373 │
# ├────────────┼────────┤
# │ test       │ 0.6203 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch   6
# Training: 100%|██████████████████████████████| 213/213 [00:00<00:00, 267.87it/s]
# Evaluation train: 100%|██████████████████████| 213/213 [00:00<00:00, 762.27it/s]
# Evaluation vali : 100%|████████████████████████| 71/71 [00:00<00:00, 762.23it/s]
# Evaluation test : 100%|████████████████████████| 71/71 [00:00<00:00, 803.68it/s]
# Took 1.2768s
# ╒═══════════════╤════════╤═════════╤══════════════════════╤═══════════════════════╤════════╕
# │ temperature   │   loss │   error │   mean_squared_error │   mean_absolute_error │     r2 │
# ╞═══════════════╪════════╪═════════╪══════════════════════╪═══════════════════════╪════════╡
# │ train         │ 1.6025 │ -0.0333 │               1.6025 │                0.7001 │ 0.9896 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ vali          │ 1.0628 │ -0.0308 │               1.0628 │                0.6726 │ 0.9914 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ test          │ 0.7482 │ -0.0390 │               0.7482 │                0.5926 │ 0.9942 │
# ╘═══════════════╧════════╧═════════╧══════════════════════╧═══════════════════════╧════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 1.5515 │
# ├────────────┼────────┤
# │ vali       │ 0.8246 │
# ├────────────┼────────┤
# │ test       │ 0.6205 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch   7
# Training: 100%|██████████████████████████████| 213/213 [00:00<00:00, 261.78it/s]
# Evaluation train: 100%|██████████████████████| 213/213 [00:00<00:00, 620.59it/s]
# Evaluation vali : 100%|████████████████████████| 71/71 [00:00<00:00, 543.56it/s]
# Evaluation test : 100%|████████████████████████| 71/71 [00:00<00:00, 663.40it/s]
# Took 1.4188s
# ╒═══════════════╤════════╤═════════╤══════════════════════╤═══════════════════════╤════════╕
# │ temperature   │   loss │   error │   mean_squared_error │   mean_absolute_error │     r2 │
# ╞═══════════════╪════════╪═════════╪══════════════════════╪═══════════════════════╪════════╡
# │ train         │ 1.5423 │  0.0255 │               1.5423 │                0.6829 │ 0.9899 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ vali          │ 1.0189 │  0.0385 │               1.0189 │                0.6593 │ 0.9918 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ test          │ 0.7095 │  0.0248 │               0.7095 │                0.5779 │ 0.9945 │
# ╘═══════════════╧════════╧═════════╧══════════════════════╧═══════════════════════╧════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 1.4939 │
# ├────────────┼────────┤
# │ vali       │ 0.7971 │
# ├────────────┼────────┤
# │ test       │ 0.5927 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch   8
# Training: 100%|██████████████████████████████| 213/213 [00:00<00:00, 255.50it/s]
# Evaluation train: 100%|██████████████████████| 213/213 [00:00<00:00, 758.79it/s]
# Evaluation vali : 100%|████████████████████████| 71/71 [00:00<00:00, 736.29it/s]
# Evaluation test : 100%|████████████████████████| 71/71 [00:00<00:00, 772.29it/s]
# Took 1.3240s
# ╒═══════════════╤════════╤═════════╤══════════════════════╤═══════════════════════╤════════╕
# │ temperature   │   loss │   error │   mean_squared_error │   mean_absolute_error │     r2 │
# ╞═══════════════╪════════╪═════════╪══════════════════════╪═══════════════════════╪════════╡
# │ train         │ 1.5139 │ -0.0156 │               1.5139 │                0.6738 │ 0.9901 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ vali          │ 0.9975 │  0.0062 │               0.9975 │                0.6463 │ 0.9919 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ test          │ 0.7031 │ -0.0127 │               0.7031 │                0.5704 │ 0.9945 │
# ╘═══════════════╧════════╧═════════╧══════════════════════╧═══════════════════════╧════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 1.4702 │
# ├────────────┼────────┤
# │ vali       │ 0.7733 │
# ├────────────┼────────┤
# │ test       │ 0.5833 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch   9
# Training: 100%|██████████████████████████████| 213/213 [00:00<00:00, 255.91it/s]
# Evaluation train: 100%|██████████████████████| 213/213 [00:00<00:00, 710.10it/s]
# Evaluation vali : 100%|████████████████████████| 71/71 [00:00<00:00, 658.58it/s]
# Evaluation test : 100%|████████████████████████| 71/71 [00:00<00:00, 542.53it/s]
# Took 1.3967s
# ╒═══════════════╤════════╤═════════╤══════════════════════╤═══════════════════════╤════════╕
# │ temperature   │   loss │   error │   mean_squared_error │   mean_absolute_error │     r2 │
# ╞═══════════════╪════════╪═════════╪══════════════════════╪═══════════════════════╪════════╡
# │ train         │ 1.4952 │  0.0182 │               1.4952 │                0.6727 │ 0.9903 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ vali          │ 0.9882 │  0.0223 │               0.9882 │                0.6479 │ 0.9920 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ test          │ 0.6990 │  0.0176 │               0.6990 │                0.5729 │ 0.9946 │
# ╘═══════════════╧════════╧═════════╧══════════════════════╧═══════════════════════╧════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 1.4565 │
# ├────────────┼────────┤
# │ vali       │ 0.7851 │
# ├────────────┼────────┤
# │ test       │ 0.5891 │
# ╘════════════╧════════╛
# Last improvement of combined validation loss happened 1 epoch ago
#
#
# Epoch  10
# Training: 100%|██████████████████████████████| 213/213 [00:00<00:00, 217.47it/s]
# Evaluation train: 100%|██████████████████████| 213/213 [00:00<00:00, 701.30it/s]
# Evaluation vali : 100%|████████████████████████| 71/71 [00:00<00:00, 610.81it/s]
# Evaluation test : 100%|████████████████████████| 71/71 [00:00<00:00, 460.87it/s]
# Took 1.5863s
# ╒═══════════════╤════════╤═════════╤══════════════════════╤═══════════════════════╤════════╕
# │ temperature   │   loss │   error │   mean_squared_error │   mean_absolute_error │     r2 │
# ╞═══════════════╪════════╪═════════╪══════════════════════╪═══════════════════════╪════════╡
# │ train         │ 1.4989 │  0.0910 │               1.4989 │                0.6778 │ 0.9902 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ vali          │ 0.9905 │  0.1189 │               0.9905 │                0.6482 │ 0.9920 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ test          │ 0.7049 │  0.1018 │               0.7049 │                0.5776 │ 0.9945 │
# ╘═══════════════╧════════╧═════════╧══════════════════════╧═══════════════════════╧════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 1.4621 │
# ├────────────┼────────┤
# │ vali       │ 0.7747 │
# ├────────────┼────────┤
# │ test       │ 0.5900 │
# ╘════════════╧════════╛
# Last improvement of combined validation loss happened 2 epochs ago
#
#
# Epoch  11
# Training: 100%|██████████████████████████████| 213/213 [00:01<00:00, 209.87it/s]
# Evaluation train: 100%|██████████████████████| 213/213 [00:00<00:00, 795.32it/s]
# Evaluation vali : 100%|████████████████████████| 71/71 [00:00<00:00, 736.96it/s]
# Evaluation test : 100%|████████████████████████| 71/71 [00:00<00:00, 713.67it/s]
# Took 1.5003s
# ╒═══════════════╤════════╤═════════╤══════════════════════╤═══════════════════════╤════════╕
# │ temperature   │   loss │   error │   mean_squared_error │   mean_absolute_error │     r2 │
# ╞═══════════════╪════════╪═════════╪══════════════════════╪═══════════════════════╪════════╡
# │ train         │ 1.4740 │  0.0369 │               1.4740 │                0.6601 │ 0.9904 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ vali          │ 0.9623 │  0.0575 │               0.9623 │                0.6321 │ 0.9922 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ test          │ 0.6763 │  0.0390 │               0.6763 │                0.5577 │ 0.9947 │
# ╘═══════════════╧════════╧═════════╧══════════════════════╧═══════════════════════╧════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 1.4368 │
# ├────────────┼────────┤
# │ vali       │ 0.7502 │
# ├────────────┼────────┤
# │ test       │ 0.5599 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  12
# Training: 100%|██████████████████████████████| 213/213 [00:00<00:00, 270.99it/s]
# Evaluation train: 100%|██████████████████████| 213/213 [00:00<00:00, 787.58it/s]
# Evaluation vali : 100%|████████████████████████| 71/71 [00:00<00:00, 659.63it/s]
# Evaluation test : 100%|████████████████████████| 71/71 [00:00<00:00, 624.44it/s]
# Took 1.3017s
# ╒═══════════════╤════════╤═════════╤══════════════════════╤═══════════════════════╤════════╕
# │ temperature   │   loss │   error │   mean_squared_error │   mean_absolute_error │     r2 │
# ╞═══════════════╪════════╪═════════╪══════════════════════╪═══════════════════════╪════════╡
# │ train         │ 1.4558 │  0.0430 │               1.4558 │                0.6641 │ 0.9905 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ vali          │ 0.9579 │  0.0673 │               0.9579 │                0.6325 │ 0.9922 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ test          │ 0.6844 │  0.0500 │               0.6844 │                0.5643 │ 0.9947 │
# ╘═══════════════╧════════╧═════════╧══════════════════════╧═══════════════════════╧════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 1.4178 │
# ├────────────┼────────┤
# │ vali       │ 0.7476 │
# ├────────────┼────────┤
# │ test       │ 0.5726 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  13
# Training: 100%|██████████████████████████████| 213/213 [00:00<00:00, 244.68it/s]
# Evaluation train: 100%|██████████████████████| 213/213 [00:00<00:00, 724.71it/s]
# Evaluation vali : 100%|████████████████████████| 71/71 [00:00<00:00, 812.31it/s]
# Evaluation test : 100%|████████████████████████| 71/71 [00:00<00:00, 794.19it/s]
# Took 1.3618s
# ╒═══════════════╤════════╤═════════╤══════════════════════╤═══════════════════════╤════════╕
# │ temperature   │   loss │   error │   mean_squared_error │   mean_absolute_error │     r2 │
# ╞═══════════════╪════════╪═════════╪══════════════════════╪═══════════════════════╪════════╡
# │ train         │ 1.4468 │ -0.0102 │               1.4468 │                0.6565 │ 0.9906 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ vali          │ 0.9463 │  0.0044 │               0.9463 │                0.6233 │ 0.9923 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ test          │ 0.6738 │ -0.0030 │               0.6738 │                0.5570 │ 0.9948 │
# ╘═══════════════╧════════╧═════════╧══════════════════════╧═══════════════════════╧════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 1.4159 │
# ├────────────┼────────┤
# │ vali       │ 0.7478 │
# ├────────────┼────────┤
# │ test       │ 0.5669 │
# ╘════════════╧════════╛
# Last improvement of combined validation loss happened 1 epoch ago
#
#
# Epoch  14
# Training: 100%|██████████████████████████████| 213/213 [00:00<00:00, 290.38it/s]
# Evaluation train: 100%|██████████████████████| 213/213 [00:00<00:00, 835.14it/s]
# Evaluation vali : 100%|████████████████████████| 71/71 [00:00<00:00, 814.21it/s]
# Evaluation test : 100%|████████████████████████| 71/71 [00:00<00:00, 815.59it/s]
# Took 1.1843s
# ╒═══════════════╤════════╤═════════╤══════════════════════╤═══════════════════════╤════════╕
# │ temperature   │   loss │   error │   mean_squared_error │   mean_absolute_error │     r2 │
# ╞═══════════════╪════════╪═════════╪══════════════════════╪═══════════════════════╪════════╡
# │ train         │ 1.4642 │  0.0104 │               1.4642 │                0.6672 │ 0.9905 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ vali          │ 0.9635 │  0.0328 │               0.9635 │                0.6419 │ 0.9922 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ test          │ 0.6813 │  0.0127 │               0.6813 │                0.5646 │ 0.9947 │
# ╘═══════════════╧════════╧═════════╧══════════════════════╧═══════════════════════╧════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 1.4361 │
# ├────────────┼────────┤
# │ vali       │ 0.7577 │
# ├────────────┼────────┤
# │ test       │ 0.5685 │
# ╘════════════╧════════╛
# Last improvement of combined validation loss happened 2 epochs ago
#
#
# Epoch  15
# Training: 100%|██████████████████████████████| 213/213 [00:00<00:00, 292.87it/s]
# Evaluation train: 100%|██████████████████████| 213/213 [00:00<00:00, 817.88it/s]
# Evaluation vali : 100%|████████████████████████| 71/71 [00:00<00:00, 799.48it/s]
# Evaluation test : 100%|████████████████████████| 71/71 [00:00<00:00, 817.99it/s]
# Took 1.1841s
# ╒═══════════════╤════════╤═════════╤══════════════════════╤═══════════════════════╤════════╕
# │ temperature   │   loss │   error │   mean_squared_error │   mean_absolute_error │     r2 │
# ╞═══════════════╪════════╪═════════╪══════════════════════╪═══════════════════════╪════════╡
# │ train         │ 1.4303 │ -0.0320 │               1.4303 │                0.6624 │ 0.9907 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ vali          │ 0.9549 │ -0.0245 │               0.9549 │                0.6379 │ 0.9923 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ test          │ 0.6850 │ -0.0343 │               0.6850 │                0.5672 │ 0.9947 │
# ╘═══════════════╧════════╧═════════╧══════════════════════╧═══════════════════════╧════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 1.4022 │
# ├────────────┼────────┤
# │ vali       │ 0.7730 │
# ├────────────┼────────┤
# │ test       │ 0.5786 │
# ╘════════════╧════════╛
# Last improvement of combined validation loss happened 3 epochs ago
#
#
# Epoch  16
# Training: 100%|██████████████████████████████| 213/213 [00:00<00:00, 290.11it/s]
# Evaluation train: 100%|██████████████████████| 213/213 [00:00<00:00, 824.01it/s]
# Evaluation vali : 100%|████████████████████████| 71/71 [00:00<00:00, 721.69it/s]
# Evaluation test : 100%|████████████████████████| 71/71 [00:00<00:00, 636.01it/s]
# Took 1.2249s
# ╒═══════════════╤════════╤═════════╤══════════════════════╤═══════════════════════╤════════╕
# │ temperature   │   loss │   error │   mean_squared_error │   mean_absolute_error │     r2 │
# ╞═══════════════╪════════╪═════════╪══════════════════════╪═══════════════════════╪════════╡
# │ train         │ 1.4430 │ -0.0714 │               1.4430 │                0.6611 │ 0.9906 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ vali          │ 0.9681 │ -0.0622 │               0.9681 │                0.6340 │ 0.9922 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ test          │ 0.6980 │ -0.0722 │               0.6980 │                0.5658 │ 0.9946 │
# ╘═══════════════╧════════╧═════════╧══════════════════════╧═══════════════════════╧════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 1.4063 │
# ├────────────┼────────┤
# │ vali       │ 0.7642 │
# ├────────────┼────────┤
# │ test       │ 0.5752 │
# ╘════════════╧════════╛
# Last improvement of combined validation loss happened 4 epochs ago
#
#
# Epoch  17
# Training: 100%|██████████████████████████████| 213/213 [00:00<00:00, 278.98it/s]
# Evaluation train: 100%|██████████████████████| 213/213 [00:00<00:00, 785.78it/s]
# Evaluation vali : 100%|████████████████████████| 71/71 [00:00<00:00, 802.45it/s]
# Evaluation test : 100%|████████████████████████| 71/71 [00:00<00:00, 814.57it/s]
# Took 1.2313s
# ╒═══════════════╤════════╤═════════╤══════════════════════╤═══════════════════════╤════════╕
# │ temperature   │   loss │   error │   mean_squared_error │   mean_absolute_error │     r2 │
# ╞═══════════════╪════════╪═════════╪══════════════════════╪═══════════════════════╪════════╡
# │ train         │ 1.4357 │ -0.0291 │               1.4357 │                0.6555 │ 0.9906 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ vali          │ 0.9410 │ -0.0085 │               0.9410 │                0.6264 │ 0.9924 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ test          │ 0.6740 │ -0.0307 │               0.6740 │                0.5565 │ 0.9948 │
# ╘═══════════════╧════════╧═════════╧══════════════════════╧═══════════════════════╧════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 1.4092 │
# ├────────────┼────────┤
# │ vali       │ 0.7422 │
# ├────────────┼────────┤
# │ test       │ 0.5627 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  18
# Training: 100%|██████████████████████████████| 213/213 [00:00<00:00, 286.46it/s]
# Evaluation train: 100%|██████████████████████| 213/213 [00:00<00:00, 837.73it/s]
# Evaluation vali : 100%|████████████████████████| 71/71 [00:00<00:00, 710.99it/s]
# Evaluation test : 100%|████████████████████████| 71/71 [00:00<00:00, 804.38it/s]
# Took 1.2062s
# ╒═══════════════╤════════╤═════════╤══════════════════════╤═══════════════════════╤════════╕
# │ temperature   │   loss │   error │   mean_squared_error │   mean_absolute_error │     r2 │
# ╞═══════════════╪════════╪═════════╪══════════════════════╪═══════════════════════╪════════╡
# │ train         │ 1.4316 │  0.0347 │               1.4316 │                0.6618 │ 0.9907 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ vali          │ 0.9464 │  0.0582 │               0.9464 │                0.6284 │ 0.9923 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ test          │ 0.6810 │  0.0386 │               0.6810 │                0.5614 │ 0.9947 │
# ╘═══════════════╧════════╧═════════╧══════════════════════╧═══════════════════════╧════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 1.3976 │
# ├────────────┼────────┤
# │ vali       │ 0.7481 │
# ├────────────┼────────┤
# │ test       │ 0.5722 │
# ╘════════════╧════════╛
# Last improvement of combined validation loss happened 1 epoch ago
#
#
# Epoch  19
# Training: 100%|██████████████████████████████| 213/213 [00:00<00:00, 290.91it/s]
# Evaluation train: 100%|██████████████████████| 213/213 [00:00<00:00, 851.21it/s]
# Evaluation vali : 100%|████████████████████████| 71/71 [00:00<00:00, 743.90it/s]
# Evaluation test : 100%|████████████████████████| 71/71 [00:00<00:00, 619.60it/s]
# Took 1.2133s
# ╒═══════════════╤════════╤═════════╤══════════════════════╤═══════════════════════╤════════╕
# │ temperature   │   loss │   error │   mean_squared_error │   mean_absolute_error │     r2 │
# ╞═══════════════╪════════╪═════════╪══════════════════════╪═══════════════════════╪════════╡
# │ train         │ 1.4116 │  0.0255 │               1.4116 │                0.6572 │ 0.9908 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ vali          │ 0.9338 │  0.0412 │               0.9338 │                0.6253 │ 0.9924 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ test          │ 0.6727 │  0.0312 │               0.6727 │                0.5585 │ 0.9948 │
# ╘═══════════════╧════════╧═════════╧══════════════════════╧═══════════════════════╧════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 1.3760 │
# ├────────────┼────────┤
# │ vali       │ 0.7351 │
# ├────────────┼────────┤
# │ test       │ 0.5635 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  20
# Training: 100%|██████████████████████████████| 213/213 [00:00<00:00, 284.11it/s]
# Evaluation train: 100%|██████████████████████| 213/213 [00:00<00:00, 806.13it/s]
# Evaluation vali : 100%|████████████████████████| 71/71 [00:00<00:00, 763.55it/s]
# Evaluation test : 100%|████████████████████████| 71/71 [00:00<00:00, 745.88it/s]
# Took 1.2249s
# ╒═══════════════╤════════╤═════════╤══════════════════════╤═══════════════════════╤════════╕
# │ temperature   │   loss │   error │   mean_squared_error │   mean_absolute_error │     r2 │
# ╞═══════════════╪════════╪═════════╪══════════════════════╪═══════════════════════╪════════╡
# │ train         │ 1.4133 │  0.0274 │               1.4133 │                0.6532 │ 0.9908 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ vali          │ 0.9306 │  0.0519 │               0.9306 │                0.6245 │ 0.9925 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ test          │ 0.6715 │  0.0323 │               0.6715 │                0.5581 │ 0.9948 │
# ╘═══════════════╧════════╧═════════╧══════════════════════╧═══════════════════════╧════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 1.3779 │
# ├────────────┼────────┤
# │ vali       │ 0.7368 │
# ├────────────┼────────┤
# │ test       │ 0.5668 │
# ╘════════════╧════════╛
# Last improvement of combined validation loss happened 1 epoch ago
#
#
# Epoch  21
# Training: 100%|██████████████████████████████| 213/213 [00:00<00:00, 295.92it/s]
# Evaluation train: 100%|██████████████████████| 213/213 [00:00<00:00, 788.55it/s]
# Evaluation vali : 100%|████████████████████████| 71/71 [00:00<00:00, 800.52it/s]
# Evaluation test : 100%|████████████████████████| 71/71 [00:00<00:00, 775.76it/s]
# Took 1.1919s
# ╒═══════════════╤════════╤═════════╤══════════════════════╤═══════════════════════╤════════╕
# │ temperature   │   loss │   error │   mean_squared_error │   mean_absolute_error │     r2 │
# ╞═══════════════╪════════╪═════════╪══════════════════════╪═══════════════════════╪════════╡
# │ train         │ 1.4087 │  0.0403 │               1.4087 │                0.6583 │ 0.9908 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ vali          │ 0.9399 │  0.0628 │               0.9399 │                0.6300 │ 0.9924 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ test          │ 0.6736 │  0.0440 │               0.6736 │                0.5577 │ 0.9948 │
# ╘═══════════════╧════════╧═════════╧══════════════════════╧═══════════════════════╧════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 1.3741 │
# ├────────────┼────────┤
# │ vali       │ 0.7386 │
# ├────────────┼────────┤
# │ test       │ 0.5688 │
# ╘════════════╧════════╛
# Last improvement of combined validation loss happened 2 epochs ago
#
#
# Epoch  22
# Training: 100%|██████████████████████████████| 213/213 [00:00<00:00, 285.76it/s]
# Evaluation train: 100%|██████████████████████| 213/213 [00:00<00:00, 781.30it/s]
# Evaluation vali : 100%|████████████████████████| 71/71 [00:00<00:00, 806.30it/s]
# Evaluation test : 100%|████████████████████████| 71/71 [00:00<00:00, 710.55it/s]
# Took 1.2271s
# ╒═══════════════╤════════╤═════════╤══════════════════════╤═══════════════════════╤════════╕
# │ temperature   │   loss │   error │   mean_squared_error │   mean_absolute_error │     r2 │
# ╞═══════════════╪════════╪═════════╪══════════════════════╪═══════════════════════╪════════╡
# │ train         │ 1.3987 │ -0.0091 │               1.3987 │                0.6507 │ 0.9909 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ vali          │ 0.9376 │  0.0027 │               0.9376 │                0.6239 │ 0.9924 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ test          │ 0.6737 │ -0.0094 │               0.6737 │                0.5561 │ 0.9948 │
# ╘═══════════════╧════════╧═════════╧══════════════════════╧═══════════════════════╧════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 1.3689 │
# ├────────────┼────────┤
# │ vali       │ 0.7410 │
# ├────────────┼────────┤
# │ test       │ 0.5664 │
# ╘════════════╧════════╛
# Last improvement of combined validation loss happened 3 epochs ago
#
#
# Epoch  23
# Training: 100%|██████████████████████████████| 213/213 [00:00<00:00, 288.75it/s]
# Evaluation train: 100%|██████████████████████| 213/213 [00:00<00:00, 820.85it/s]
# Evaluation vali : 100%|████████████████████████| 71/71 [00:00<00:00, 780.81it/s]
# Evaluation test : 100%|████████████████████████| 71/71 [00:00<00:00, 797.82it/s]
# Took 1.1979s
# ╒═══════════════╤════════╤═════════╤══════════════════════╤═══════════════════════╤════════╕
# │ temperature   │   loss │   error │   mean_squared_error │   mean_absolute_error │     r2 │
# ╞═══════════════╪════════╪═════════╪══════════════════════╪═══════════════════════╪════════╡
# │ train         │ 1.4064 │  0.0565 │               1.4064 │                0.6625 │ 0.9908 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ vali          │ 0.9439 │  0.0859 │               0.9439 │                0.6312 │ 0.9924 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ test          │ 0.6787 │  0.0628 │               0.6787 │                0.5619 │ 0.9947 │
# ╘═══════════════╧════════╧═════════╧══════════════════════╧═══════════════════════╧════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 1.3682 │
# ├────────────┼────────┤
# │ vali       │ 0.7336 │
# ├────────────┼────────┤
# │ test       │ 0.5690 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  24
# Training: 100%|██████████████████████████████| 213/213 [00:00<00:00, 287.40it/s]
# Evaluation train: 100%|██████████████████████| 213/213 [00:00<00:00, 807.77it/s]
# Evaluation vali : 100%|████████████████████████| 71/71 [00:00<00:00, 738.07it/s]
# Evaluation test : 100%|████████████████████████| 71/71 [00:00<00:00, 757.60it/s]
# Took 1.2158s
# ╒═══════════════╤════════╤═════════╤══════════════════════╤═══════════════════════╤════════╕
# │ temperature   │   loss │   error │   mean_squared_error │   mean_absolute_error │     r2 │
# ╞═══════════════╪════════╪═════════╪══════════════════════╪═══════════════════════╪════════╡
# │ train         │ 1.3808 │  0.0019 │               1.3808 │                0.6501 │ 0.9910 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ vali          │ 0.9264 │  0.0184 │               0.9264 │                0.6209 │ 0.9925 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ test          │ 0.6714 │  0.0075 │               0.6714 │                0.5570 │ 0.9948 │
# ╘═══════════════╧════════╧═════════╧══════════════════════╧═══════════════════════╧════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 1.3487 │
# ├────────────┼────────┤
# │ vali       │ 0.7336 │
# ├────────────┼────────┤
# │ test       │ 0.5690 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  25
# Training: 100%|██████████████████████████████| 213/213 [00:00<00:00, 291.88it/s]
# Evaluation train: 100%|██████████████████████| 213/213 [00:00<00:00, 785.03it/s]
# Evaluation vali : 100%|████████████████████████| 71/71 [00:00<00:00, 796.08it/s]
# Evaluation test : 100%|████████████████████████| 71/71 [00:00<00:00, 605.50it/s]
# Took 1.2287s
# ╒═══════════════╤════════╤═════════╤══════════════════════╤═══════════════════════╤════════╕
# │ temperature   │   loss │   error │   mean_squared_error │   mean_absolute_error │     r2 │
# ╞═══════════════╪════════╪═════════╪══════════════════════╪═══════════════════════╪════════╡
# │ train         │ 1.3826 │ -0.0139 │               1.3826 │                0.6516 │ 0.9910 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ vali          │ 0.9289 │ -0.0003 │               0.9289 │                0.6196 │ 0.9925 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ test          │ 0.6796 │ -0.0134 │               0.6796 │                0.5602 │ 0.9947 │
# ╘═══════════════╧════════╧═════════╧══════════════════════╧═══════════════════════╧════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 1.3548 │
# ├────────────┼────────┤
# │ vali       │ 0.7349 │
# ├────────────┼────────┤
# │ test       │ 0.5752 │
# ╘════════════╧════════╛
# Last improvement of combined validation loss happened 1 epoch ago
#
#
# Epoch  26
# Training: 100%|██████████████████████████████| 213/213 [00:00<00:00, 279.80it/s]
# Evaluation train: 100%|██████████████████████| 213/213 [00:00<00:00, 827.54it/s]
# Evaluation vali : 100%|████████████████████████| 71/71 [00:00<00:00, 719.14it/s]
# Evaluation test : 100%|████████████████████████| 71/71 [00:00<00:00, 725.01it/s]
# Took 1.2368s
# ╒═══════════════╤════════╤═════════╤══════════════════════╤═══════════════════════╤════════╕
# │ temperature   │   loss │   error │   mean_squared_error │   mean_absolute_error │     r2 │
# ╞═══════════════╪════════╪═════════╪══════════════════════╪═══════════════════════╪════════╡
# │ train         │ 1.3813 │ -0.0042 │               1.3813 │                0.6474 │ 0.9910 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ vali          │ 0.9245 │  0.0117 │               0.9245 │                0.6169 │ 0.9925 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ test          │ 0.6743 │  0.0005 │               0.6743 │                0.5572 │ 0.9947 │
# ╘═══════════════╧════════╧═════════╧══════════════════════╧═══════════════════════╧════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 1.3504 │
# ├────────────┼────────┤
# │ vali       │ 0.7319 │
# ├────────────┼────────┤
# │ test       │ 0.5678 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  27
# Training: 100%|██████████████████████████████| 213/213 [00:00<00:00, 292.12it/s]
# Evaluation train: 100%|██████████████████████| 213/213 [00:00<00:00, 834.41it/s]
# Evaluation vali : 100%|████████████████████████| 71/71 [00:00<00:00, 735.49it/s]
# Evaluation test : 100%|████████████████████████| 71/71 [00:00<00:00, 764.01it/s]
# Took 1.1947s
# ╒═══════════════╤════════╤═════════╤══════════════════════╤═══════════════════════╤════════╕
# │ temperature   │   loss │   error │   mean_squared_error │   mean_absolute_error │     r2 │
# ╞═══════════════╪════════╪═════════╪══════════════════════╪═══════════════════════╪════════╡
# │ train         │ 1.3802 │ -0.0113 │               1.3802 │                0.6526 │ 0.9910 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ vali          │ 0.9297 │ -0.0004 │               0.9297 │                0.6272 │ 0.9925 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ test          │ 0.6661 │ -0.0077 │               0.6661 │                0.5578 │ 0.9948 │
# ╘═══════════════╧════════╧═════════╧══════════════════════╧═══════════════════════╧════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 1.3504 │
# ├────────────┼────────┤
# │ vali       │ 0.7459 │
# ├────────────┼────────┤
# │ test       │ 0.5707 │
# ╘════════════╧════════╛
# Last improvement of combined validation loss happened 1 epoch ago
#
#
# Epoch  28
# Training: 100%|██████████████████████████████| 213/213 [00:00<00:00, 280.85it/s]
# Evaluation train: 100%|██████████████████████| 213/213 [00:00<00:00, 825.67it/s]
# Evaluation vali : 100%|████████████████████████| 71/71 [00:00<00:00, 790.72it/s]
# Evaluation test : 100%|████████████████████████| 71/71 [00:00<00:00, 624.32it/s]
# Took 1.2409s
# ╒═══════════════╤════════╤═════════╤══════════════════════╤═══════════════════════╤════════╕
# │ temperature   │   loss │   error │   mean_squared_error │   mean_absolute_error │     r2 │
# ╞═══════════════╪════════╪═════════╪══════════════════════╪═══════════════════════╪════════╡
# │ train         │ 1.3733 │  0.0330 │               1.3733 │                0.6520 │ 0.9911 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ vali          │ 0.9307 │  0.0574 │               0.9307 │                0.6239 │ 0.9925 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ test          │ 0.6705 │  0.0392 │               0.6705 │                0.5556 │ 0.9948 │
# ╘═══════════════╧════════╧═════════╧══════════════════════╧═══════════════════════╧════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 1.3411 │
# ├────────────┼────────┤
# │ vali       │ 0.7400 │
# ├────────────┼────────┤
# │ test       │ 0.5641 │
# ╘════════════╧════════╛
# Last improvement of combined validation loss happened 2 epochs ago
#
#
# Epoch  29
# Training: 100%|██████████████████████████████| 213/213 [00:00<00:00, 287.11it/s]
# Evaluation train: 100%|██████████████████████| 213/213 [00:00<00:00, 822.01it/s]
# Evaluation vali : 100%|████████████████████████| 71/71 [00:00<00:00, 778.63it/s]
# Evaluation test : 100%|████████████████████████| 71/71 [00:00<00:00, 797.87it/s]
# Took 1.2031s
# ╒═══════════════╤════════╤═════════╤══════════════════════╤═══════════════════════╤════════╕
# │ temperature   │   loss │   error │   mean_squared_error │   mean_absolute_error │     r2 │
# ╞═══════════════╪════════╪═════════╪══════════════════════╪═══════════════════════╪════════╡
# │ train         │ 1.3909 │ -0.0541 │               1.3909 │                0.6664 │ 0.9909 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ vali          │ 0.9475 │ -0.0595 │               0.9475 │                0.6419 │ 0.9923 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ test          │ 0.6973 │ -0.0542 │               0.6973 │                0.5792 │ 0.9946 │
# ╘═══════════════╧════════╧═════════╧══════════════════════╧═══════════════════════╧════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 1.3672 │
# ├────────────┼────────┤
# │ vali       │ 0.7737 │
# ├────────────┼────────┤
# │ test       │ 0.6120 │
# ╘════════════╧════════╛
# Last improvement of combined validation loss happened 3 epochs ago
#
#
# Epoch  30
# Training: 100%|██████████████████████████████| 213/213 [00:00<00:00, 286.44it/s]
# Evaluation train: 100%|██████████████████████| 213/213 [00:00<00:00, 799.32it/s]
# Evaluation vali : 100%|████████████████████████| 71/71 [00:00<00:00, 795.79it/s]
# Evaluation test : 100%|████████████████████████| 71/71 [00:00<00:00, 757.65it/s]
# Took 1.2143s
# ╒═══════════════╤════════╤═════════╤══════════════════════╤═══════════════════════╤════════╕
# │ temperature   │   loss │   error │   mean_squared_error │   mean_absolute_error │     r2 │
# ╞═══════════════╪════════╪═════════╪══════════════════════╪═══════════════════════╪════════╡
# │ train         │ 1.3793 │ -0.0303 │               1.3793 │                0.6503 │ 0.9910 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ vali          │ 0.9236 │ -0.0248 │               0.9236 │                0.6217 │ 0.9925 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ test          │ 0.6680 │ -0.0291 │               0.6680 │                0.5573 │ 0.9948 │
# ╘═══════════════╧════════╧═════════╧══════════════════════╧═══════════════════════╧════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 1.3508 │
# ├────────────┼────────┤
# │ vali       │ 0.7409 │
# ├────────────┼────────┤
# │ test       │ 0.5760 │
# ╘════════════╧════════╛
# Last improvement of combined validation loss happened 4 epochs ago
#
#
# Epoch  31
# Training: 100%|██████████████████████████████| 213/213 [00:00<00:00, 287.27it/s]
# Evaluation train: 100%|██████████████████████| 213/213 [00:00<00:00, 821.42it/s]
# Evaluation vali : 100%|████████████████████████| 71/71 [00:00<00:00, 711.99it/s]
# Evaluation test : 100%|████████████████████████| 71/71 [00:00<00:00, 731.18it/s]
# Took 1.2201s
# ╒═══════════════╤════════╤═════════╤══════════════════════╤═══════════════════════╤════════╕
# │ temperature   │   loss │   error │   mean_squared_error │   mean_absolute_error │     r2 │
# ╞═══════════════╪════════╪═════════╪══════════════════════╪═══════════════════════╪════════╡
# │ train         │ 1.3608 │ -0.0133 │               1.3608 │                0.6496 │ 0.9911 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ vali          │ 0.9235 │ -0.0012 │               0.9235 │                0.6219 │ 0.9925 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ test          │ 0.6659 │ -0.0095 │               0.6659 │                0.5569 │ 0.9948 │
# ╘═══════════════╧════════╧═════════╧══════════════════════╧═══════════════════════╧════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 1.3340 │
# ├────────────┼────────┤
# │ vali       │ 0.7454 │
# ├────────────┼────────┤
# │ test       │ 0.5689 │
# ╘════════════╧════════╛
# Last improvement of combined validation loss happened 5 epochs ago
#
# EARLY STOPPING due to lack of validation improvement, it has been 5 epochs since last validation improvement
#
# Best validation model epoch: 26
# Best validation model loss on validation set combined: 0.7319207787513733
# Best validation model loss on test set combined: 0.567800760269165
#
# Finished: experiment_run
# Saved to: results/experiment_run
# Evaluation: 100%|██████████████████████████████| 71/71 [00:00<00:00, 683.13it/s]
#
# ===== temperature =====
# error: 0.000534206
# loss: 0.6742949
# mean_absolute_error: 0.5572179
# mean_squared_error: 0.6742949
# r2: 0.99474925
# Saved to: results/experiment_run

# %%
np.sqrt(0.6742949)
# Out:
# 0.8211546139430747

# %%
# !ludwig visualize --visualization learning_curves \
  --output_feature_name temperature \
  --training_statistics results/experiment_run/training_statistics.json \
  --model_names Model1

# %% [markdown]
# ## Visualize Results

# %%
test = pd.read_csv('results/experiment_run/temperature_predictions.csv', header = None)

# %%
ludwig_df_plot = ludwig_df[ludwig_df['split'] == 2]
ludwig_df_plot['predicted'] = test.values
ludwig_df_plot
# Out:
#        temperature  split                                temperature_feature  \
# 36200        10.00      2  7.6299999999999955 7.650000000000034 7.6500000...
# 36201         8.32      2  7.650000000000034 7.650000000000034 7.33000000...
# 36202         7.33      2  7.650000000000034 7.330000000000041 6.98000000...
# 36203         6.65      2  7.330000000000041 6.980000000000018 6.62999999...
# 36204         5.63      2  6.980000000000018 6.6299999999999955 6.3000000...
# ...            ...    ...                                                ...
# 45247         1.98      2  1.580000000000041 1.8799999999999955 1.2000000...
# 45248         0.98      2  1.8799999999999955 1.2000000000000455 1.850000...
# 45249         0.33      2  1.2000000000000455 1.8500000000000227 2.550000...
# 45250        -0.67      2  1.8500000000000227 2.5500000000000114 3.230000...
# 45251        -1.35      2  2.5500000000000114 3.230000000000018 2.5700000...
#
#        predicted
# 36200   9.856126
# 36201   9.573146
# 36202   7.572208
# 36203   6.633433
# 36204   6.029730
# ...          ...
# 45247   3.008836
# 45248   1.331512
# 45249   0.388220
# 45250  -0.346160
# 45251  -1.185810
#
# [9052 rows x 4 columns]

# %%
#plot real against predicted values
ax = ludwig_df_plot['temperature'].plot(label='observed')
ludwig_df_plot['predicted'].plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(10, 5))

ax.set_xlabel('Date')
ax.set_ylabel('Temperature')
plt.legend()
plt.show()
