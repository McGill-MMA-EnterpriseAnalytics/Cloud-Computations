# %% [markdown]
# # INSY 695 - Base Models

# %%
import pandas as pd
import numpy as np
import os
import platform as pf
from IPython.display import display # Display data
pd.options.mode.chained_assignment = None  # default='warn'

#comment
#packages for time series
import warnings
import itertools    
import statsmodels.api as sm

#Richard was here
from datetime import timedelta
from dateutil.relativedelta import relativedelta
import matplotlib.pyplot as plt
import math
from scipy import stats

plt.style.use('fivethirtyeight')

# %% [markdown]
# ## 1. Load Data

# %%
df = pd.read_csv('montreal.csv')

#need to specify datetime[ns] or else the rest will not run 
df['datetime'] = df['datetime'].astype('datetime64[ns]')

# %%
weather_df = df[['datetime', 'Temperature']].set_index('datetime')
weather_df
# Out:
#                      Temperature
# datetime
# 2012-10-01 13:00:00   285.830000
# 2012-10-01 14:00:00   285.834650
# 2012-10-01 15:00:00   285.847790
# 2012-10-01 16:00:00   285.860929
# 2012-10-01 17:00:00   285.874069
# ...                          ...
# 2017-11-29 20:00:00   275.130000
# 2017-11-29 21:00:00   274.130000
# 2017-11-29 22:00:00   273.480000
# 2017-11-29 23:00:00   272.480000
# 2017-11-30 00:00:00   271.800000
#
# [45252 rows x 1 columns]

# %%
#plot current returns of part X resampled on a mean-returns month to month basis
weather_df.plot(figsize=(15, 6))
plt.show()

# %% [markdown]
# ## MODEL 1. Seasonal ARIMA
#
# Autoregressive Integrated Moving Average, or ARIMA, is one of the most widely used forecasting methods for univariate time series data forecasting.Although the method can handle data with a trend, it does not support time series with a seasonal component. An extension to ARIMA that supports the direct modeling of the seasonal component of the series is called SARIMA. It adds three new hyperparameters to specify the autoregression (AR), differencing (I) and moving average (MA) for the seasonal component of the series, as well as an additional parameter for the period of the seasonality.

# %% [markdown]
# **STEP 1: Decompose returns into trend, seasonal, and residual**
#
# Each time series can be decomposed into trend, seasonality, and noise
#
# We can see from the upward trend and annual seasonality that the time series may not be stationary. ARIMA must be stationary (no trends, cycles, random walk, etc.) to work, meaning mean, variance, correlation is constant over time -- if not stationary, transform into period-by-period differences instead.

# %%
from pylab import rcParams

#decompose observed returns into trend, seasonal, and noise 
rcParams['figure.figsize'] = 18, 8
decomposition = sm.tsa.seasonal_decompose(weather_df, model='additive')
fig = decomposition.plot()
plt.show()

# %% [markdown]
# **STEP 2: Run ADF (Augmented Dickey Fuller) Test to check for trend -- the null hypothesis is that the data is not stationary, so if p > 0.05, we can confirm the series is not stationary (there is a trend), and need to do first-order-differencing.**
#
# The data is stationary if its mean, variance, and covariance remain constant over time. For instance, if the trend is upwards over time or the seasonal fluctuations get larger over time, then stationarity would be violated.

# %%
from statsmodels.tsa.stattools import adfuller
def adf_test(timeseries):
    #Perform Dickey-Fuller test:
    print ('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
       dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)

print(adf_test(weather_df))
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -6.353630e+00
# p-value                        2.574529e-08
# #Lags Used                     5.600000e+01
# Number of Observations Used    4.519500e+04
# Critical Value (1%)           -3.430495e+00
# Critical Value (5%)           -2.861604e+00
# Critical Value (10%)          -2.566804e+00
# dtype: float64
# None

# %% [markdown]
# **STEP 3: Perform first order differencing**
#
# Rerunning the test again after performing first order differencing confirms that the trend is now stationary.

# %%
def differencing_func(y):
    #FIRST ORDER DIFFERENCING
    y_adj = y - y.shift(1)
    y_adj = y_adj.dropna()
    y_adj.plot()

    #SEASONAL DIFFERENCING 
    y_adj2 = y - y.shift(12)
    y_adj2 = y_adj2.dropna()
    y_adj2.plot()

    print(adf_test(y_adj))
    print(adf_test(y_adj2))
    
differencing_func(weather_df)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   -36.399538
# p-value                            0.000000
# #Lags Used                        55.000000
# Number of Observations Used    45195.000000
# Critical Value (1%)               -3.430495
# Critical Value (5%)               -2.861604
# Critical Value (10%)              -2.566804
# dtype: float64
# None
# Results of Dickey-Fuller Test:
# Test Statistic                   -39.010885
# p-value                            0.000000
# #Lags Used                        56.000000
# Number of Observations Used    45183.000000
# Critical Value (1%)               -3.430495
# Critical Value (5%)               -2.861604
# Critical Value (10%)              -2.566804
# dtype: float64
# None

# %% [markdown]
# **Step 4: Plot ACF and PACF**

# %%
fig, ax = plt.subplots(2,1)
fig = sm.graphics.tsa.plot_acf(weather_df, lags=12, ax=ax[0])
fig = sm.graphics.tsa.plot_pacf(weather_df, lags=12, ax=ax[1])
plt.show()

# %% [markdown]
# **STEP 5: Specify SARIMA(p,d,q)*(P,D,Q,s)**
# - **p and seasonal P** = number of AUTOREGRESSIVE terms (lags of the stationarized series). It allows us to incorporate the effect of past values into our model. Intuitively, this would be similar to stating that it is likely to be warm tomorrow if it has been warm the past 3 days.
# - **d and seasonal D**: DIFFERENCING that must be done to stationarize the series. This includes terms in the model that incorporate the amount of differencing (i.e. the number of past time points to subtract from the current value) to apply to the time series. Intuitively, this would be similar to stating that it is likely to be same temperature tomorrow if the difference in temperature in the last three days has been very small.
# - **q and seasonal Q**: indicate number of MOVING AVERAGE terms -- lags of the forecast errors. This allows us to set the error of our model as a linear combination of the error values observed at previous time points in the past.
# - **s**: seasonal length in the data
#
# - (p,q,d) are the non seasonal parameters and (P,Q,D) follow the same definition but are applied to the seasonal component.
#
# This process of gridsearch will let the model automatically find the best parameters to make the ARIMA stationary. We use gridsearch since we are unsure of the actual parameters!

# %%
#since we are doing a seasonal ARIMA, we must specify parameters for ARIMA and SARIMA

#create combinations of ARIMA parameters
p = d = q = range(0, 2)
s = (1,12)

#create combinations of non-seasonal parameters 
pdq = list(itertools.product(p, d, q))

#create combinations for seasonal parameters -- 12 for monthly data
seasonal_pdq = list(itertools.product(p,d,q,s))


#print out sample of results
print('Examples of parameter combinations for Seasonal ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))
# Out:
# Examples of parameter combinations for Seasonal ARIMA...
# SARIMAX: (0, 0, 1) x (0, 0, 0, 12)
# SARIMAX: (0, 0, 1) x (0, 0, 1, 1)
# SARIMAX: (0, 1, 0) x (0, 0, 1, 12)
# SARIMAX: (0, 1, 0) x (0, 1, 0, 1)

# %%
grid_search = pd.DataFrame(columns = ['param', 'param_seasonal', 'AIC'])

warnings.filterwarnings("ignore") # specify to ignore warning messages
#loop through parameters and seasonal parameters and perform a grid search
for param in pdq: 
    for param_seasonal in seasonal_pdq: 
        try:
            model = sm.tsa.statespace.SARIMAX(weather_df,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=True,
                                            enforce_invertibility=True)
            results = model.fit(max_iter = 50, method = 'powell') #optimizer method 
            print('SARIMAX{}x{} - AIC:{}'.format(param, param_seasonal, results.aic))
            
            #append results to grid search df 
            grid_search = grid_search.append({'param': param, 'param_seasonal': param_seasonal, 'AIC': results.aic}, ignore_index=True)
        
        except:
            continue
# Out:
# Optimization terminated successfully.
#          Current function value: 7.055861
#          Iterations: 1
#          Function evaluations: 19
# SARIMAX(0, 0, 0)x(0, 0, 0, 12) - AIC:638585.6069744178
# Optimization terminated successfully.
#          Current function value: 6.423050
#          Iterations: 2
#          Function evaluations: 53
# SARIMAX(0, 0, 0)x(0, 0, 1, 12) - AIC:581315.6948893664
# Optimization terminated successfully.
#          Current function value: 3.204125
#          Iterations: 1
#          Function evaluations: 12
# SARIMAX(0, 0, 0)x(0, 1, 0, 12) - AIC:289988.1705698968
# Optimization terminated successfully.
#          Current function value: 3.009884
#          Iterations: 2
#          Function evaluations: 47
# SARIMAX(0, 0, 0)x(0, 1, 1, 12) - AIC:272410.5551225958
# Optimization terminated successfully.
#          Current function value: 3.205940
#          Iterations: 1
#          Function evaluations: 25
# SARIMAX(0, 0, 0)x(1, 0, 0, 12) - AIC:290154.4098362204
# Optimization terminated successfully.
#          Current function value: 3.011749
#          Iterations: 3
#          Function evaluations: 146
# SARIMAX(0, 0, 0)x(1, 0, 1, 12) - AIC:272581.3002430875
# Optimization terminated successfully.
#          Current function value: 2.917259
#          Iterations: 1
#          Function evaluations: 26
# SARIMAX(0, 0, 0)x(1, 1, 0, 12) - AIC:264027.58118311566
# Optimization terminated successfully.
#          Current function value: 2.783409
#          Iterations: 6
#          Function evaluations: 225
# SARIMAX(0, 0, 0)x(1, 1, 1, 12) - AIC:251915.60477296004
# Optimization terminated successfully.
#          Current function value: 6.365977
#          Iterations: 2
#          Function evaluations: 58
# SARIMAX(0, 0, 1)x(0, 0, 0, 12) - AIC:576150.3815684171
# Optimization terminated successfully.
#          Current function value: 5.734105
#          Iterations: 2
#          Function evaluations: 91
# SARIMAX(0, 0, 1)x(0, 0, 1, 12) - AIC:518965.45407621504
# Optimization terminated successfully.
#          Current function value: 2.654483
#          Iterations: 2
#          Function evaluations: 53
# SARIMAX(0, 0, 1)x(0, 1, 0, 12) - AIC:240245.3207383595
# Optimization terminated successfully.
#          Current function value: 2.466108
#          Iterations: 3
#          Function evaluations: 110
# SARIMAX(0, 0, 1)x(0, 1, 1, 12) - AIC:223198.63702765407
# Optimization terminated successfully.
#          Current function value: 2.656098
#          Iterations: 4
#          Function evaluations: 185
# SARIMAX(0, 0, 1)x(1, 0, 0, 12) - AIC:240393.50480329635
# Optimization terminated successfully.
#          Current function value: 2.467801
#          Iterations: 4
#          Function evaluations: 239
# SARIMAX(0, 0, 1)x(1, 0, 1, 12) - AIC:223353.8794244181
# Optimization terminated successfully.
#          Current function value: 2.405005
#          Iterations: 2
#          Function evaluations: 76
# SARIMAX(0, 0, 1)x(1, 1, 0, 12) - AIC:217668.60256208671
# Optimization terminated successfully.
#          Current function value: 2.312959
#          Iterations: 7
#          Function evaluations: 346
# SARIMAX(0, 0, 1)x(1, 1, 1, 12) - AIC:209340.04010679663
# Optimization terminated successfully.
#          Current function value: 1.628620
#          Iterations: 1
#          Function evaluations: 14
# SARIMAX(0, 1, 0)x(0, 0, 0, 12) - AIC:147398.60225368128
# Optimization terminated successfully.
#          Current function value: 1.604401
#          Iterations: 2
#          Function evaluations: 50
# SARIMAX(0, 1, 0)x(0, 0, 1, 12) - AIC:145208.67023779626
# Optimization terminated successfully.
#          Current function value: 2.095527
#          Iterations: 1
#          Function evaluations: 18
# SARIMAX(0, 1, 0)x(0, 1, 0, 12) - AIC:189655.6041711552
# Optimization terminated successfully.
#          Current function value: 1.618657
#          Iterations: 2
#          Function evaluations: 53
# SARIMAX(0, 1, 0)x(0, 1, 1, 12) - AIC:146498.95206272305
# Optimization terminated successfully.
#          Current function value: 1.589816
#          Iterations: 1
#          Function evaluations: 27
# SARIMAX(0, 1, 0)x(1, 0, 0, 12) - AIC:143888.74316892994
# Optimization terminated successfully.
#          Current function value: 1.491269
#          Iterations: 5
#          Function evaluations: 190
# SARIMAX(0, 1, 0)x(1, 0, 1, 12) - AIC:134971.78790323206
# Optimization terminated successfully.
#          Current function value: 1.692494
#          Iterations: 1
#          Function evaluations: 27
# SARIMAX(0, 1, 0)x(1, 1, 0, 12) - AIC:153181.45457377605
# Optimization terminated successfully.
#          Current function value: 1.564344
#          Iterations: 4
#          Function evaluations: 163
# SARIMAX(0, 1, 0)x(1, 1, 1, 12) - AIC:141585.38421606435
# Optimization terminated successfully.
#          Current function value: 1.598894
#          Iterations: 1
#          Function evaluations: 25
# SARIMAX(0, 1, 1)x(0, 0, 0, 12) - AIC:144710.3019057418
# Optimization terminated successfully.
#          Current function value: 1.582728
#          Iterations: 2
#          Function evaluations: 72
# SARIMAX(0, 1, 1)x(0, 0, 1, 12) - AIC:143249.21994650585
# Optimization terminated successfully.
#          Current function value: 2.037364
#          Iterations: 2
#          Function evaluations: 51
# SARIMAX(0, 1, 1)x(0, 1, 0, 12) - AIC:184393.5861401271
# Optimization terminated successfully.
#          Current function value: 1.591132
#          Iterations: 2
#          Function evaluations: 76
# SARIMAX(0, 1, 1)x(0, 1, 1, 12) - AIC:144009.80329306412
# Optimization terminated successfully.
#          Current function value: 1.573921
#          Iterations: 2
#          Function evaluations: 74
# SARIMAX(0, 1, 1)x(1, 0, 0, 12) - AIC:142452.1424429007
# Optimization terminated successfully.
#          Current function value: 1.488283
#          Iterations: 7
#          Function evaluations: 357
# SARIMAX(0, 1, 1)x(1, 0, 1, 12) - AIC:134703.56233054394
# Optimization terminated successfully.
#          Current function value: 1.689295
#          Iterations: 2
#          Function evaluations: 74
# SARIMAX(0, 1, 1)x(1, 1, 0, 12) - AIC:152893.9844799534
# Optimization terminated successfully.
#          Current function value: 1.554353
#          Iterations: 4
#          Function evaluations: 200
# SARIMAX(0, 1, 1)x(1, 1, 1, 12) - AIC:140683.1260211406
# Optimization terminated successfully.
#          Current function value: 1.628773
#          Iterations: 1
#          Function evaluations: 27
# SARIMAX(1, 0, 0)x(0, 0, 0, 12) - AIC:147414.48332904294
# Optimization terminated successfully.
#          Current function value: 1.604555
#          Iterations: 3
#          Function evaluations: 143
# SARIMAX(1, 0, 0)x(0, 0, 1, 12) - AIC:145224.6325383489
# Optimization terminated successfully.
#          Current function value: 2.081800
#          Iterations: 1
#          Function evaluations: 33
# SARIMAX(1, 0, 0)x(0, 1, 0, 12) - AIC:188415.23344988638
# Optimization terminated successfully.
#          Current function value: 1.615869
#          Iterations: 3
#          Function evaluations: 119
# SARIMAX(1, 0, 0)x(0, 1, 1, 12) - AIC:146248.65141011614
# Optimization terminated successfully.
#          Current function value: 0.000578
#          Iterations: 2
#          Function evaluations: 274
# SARIMAX(1, 0, 0)x(1, 0, 0, 12) - AIC:58.35551959115605
# Optimization terminated successfully.
#          Current function value: 1.491548
#          Iterations: 6
#          Function evaluations: 364
# SARIMAX(1, 0, 0)x(1, 0, 1, 12) - AIC:134999.0566446868
# Optimization terminated successfully.
#          Current function value: 1.681774
#          Iterations: 2
#          Function evaluations: 74
# SARIMAX(1, 0, 0)x(1, 1, 0, 12) - AIC:152213.27699472572
# Optimization terminated successfully.
#          Current function value: 1.561102
#          Iterations: 5
#          Function evaluations: 241
# SARIMAX(1, 0, 0)x(1, 1, 1, 12) - AIC:141293.99675433175
# Optimization terminated successfully.
#          Current function value: 1.599046
#          Iterations: 2
#          Function evaluations: 73
# SARIMAX(1, 0, 1)x(0, 0, 0, 12) - AIC:144726.09756126584
# Optimization terminated successfully.
#          Current function value: 1.582882
#          Iterations: 3
#          Function evaluations: 167
# SARIMAX(1, 0, 1)x(0, 0, 1, 12) - AIC:143265.12722704
# Optimization terminated successfully.
#          Current function value: 2.016872
#          Iterations: 2
#          Function evaluations: 78
# SARIMAX(1, 0, 1)x(0, 1, 0, 12) - AIC:182540.94190400373
# Optimization terminated successfully.
#          Current function value: 1.586874
#          Iterations: 4
#          Function evaluations: 196
# SARIMAX(1, 0, 1)x(0, 1, 1, 12) - AIC:143626.47460590236
# Optimization terminated successfully.
#          Current function value: 2.016520
#          Iterations: 3
#          Function evaluations: 160
# SARIMAX(1, 0, 1)x(1, 0, 0, 12) - AIC:182511.15646206733
# Optimization terminated successfully.
#          Current function value: 1.598927
#          Iterations: 5
#          Function evaluations: 348
# SARIMAX(1, 0, 1)x(1, 0, 1, 12) - AIC:144719.3142059936
# Optimization terminated successfully.
#          Current function value: 1.676710
#          Iterations: 3
#          Function evaluations: 159
# SARIMAX(1, 0, 1)x(1, 1, 0, 12) - AIC:151756.98023017345
# Optimization terminated successfully.
#          Current function value: 1.550161
#          Iterations: 6
#          Function evaluations: 355
# SARIMAX(1, 0, 1)x(1, 1, 1, 12) - AIC:140305.72653399545
# Optimization terminated successfully.
#          Current function value: 1.588441
#          Iterations: 1
#          Function evaluations: 28
# SARIMAX(1, 1, 0)x(0, 0, 0, 12) - AIC:143764.28135629656
# Optimization terminated successfully.
#          Current function value: 1.575551
#          Iterations: 2
#          Function evaluations: 74
# SARIMAX(1, 1, 0)x(0, 0, 1, 12) - AIC:142599.62840084164
# Optimization terminated successfully.
#          Current function value: 2.012636
#          Iterations: 1
#          Function evaluations: 35
# SARIMAX(1, 1, 0)x(0, 1, 0, 12) - AIC:182155.60668916794
# Optimization terminated successfully.
#          Current function value: 1.581520
#          Iterations: 2
#          Function evaluations: 79
# SARIMAX(1, 1, 0)x(0, 1, 1, 12) - AIC:143139.84599989225
# Optimization terminated successfully.
#          Current function value: 1.568793
#          Iterations: 3
#          Function evaluations: 123
# SARIMAX(1, 1, 0)x(1, 0, 0, 12) - AIC:141988.01830829724
# Optimization terminated successfully.
#          Current function value: 1.487946
#          Iterations: 7
#          Function evaluations: 353
# SARIMAX(1, 1, 0)x(1, 0, 1, 12) - AIC:134673.07403686357
# Optimization terminated successfully.
#          Current function value: 1.688658
#          Iterations: 2
#          Function evaluations: 74
# SARIMAX(1, 1, 0)x(1, 1, 0, 12) - AIC:152836.33560256806
# Optimization terminated successfully.
#          Current function value: 1.551304
#          Iterations: 5
#          Function evaluations: 253
# SARIMAX(1, 1, 0)x(1, 1, 1, 12) - AIC:140407.17418088185
# Optimization terminated successfully.
#          Current function value: 1.571532
#          Iterations: 3
#          Function evaluations: 119
# SARIMAX(1, 1, 1)x(0, 0, 0, 12) - AIC:142235.88867203667
# Optimization terminated successfully.
#          Current function value: 1.562208
#          Iterations: 2
#          Function evaluations: 107
# SARIMAX(1, 1, 1)x(0, 0, 1, 12) - AIC:141394.07147798574
# Optimization terminated successfully.
#          Current function value: 1.985368
#          Iterations: 3
#          Function evaluations: 116
# SARIMAX(1, 1, 1)x(0, 1, 0, 12) - AIC:179689.7247521979
# Optimization terminated successfully.
#          Current function value: 1.563155
#          Iterations: 4
#          Function evaluations: 209
# SARIMAX(1, 1, 1)x(0, 1, 1, 12) - AIC:141479.77123946496
# Optimization terminated successfully.
#          Current function value: 1.557610
#          Iterations: 4
#          Function evaluations: 215
# SARIMAX(1, 1, 1)x(1, 0, 0, 12) - AIC:140977.93367762578
# Optimization terminated successfully.
#          Current function value: 1.491982
#          Iterations: 7
#          Function evaluations: 444
# SARIMAX(1, 1, 1)x(1, 0, 1, 12) - AIC:135040.38211609106
# Optimization terminated successfully.
#          Current function value: 1.682453
#          Iterations: 2
#          Function evaluations: 101
# SARIMAX(1, 1, 1)x(1, 1, 0, 12) - AIC:152276.75256099782
# Optimization terminated successfully.
#          Current function value: 1.540181
#          Iterations: 7
#          Function evaluations: 438
# SARIMAX(1, 1, 1)x(1, 1, 1, 12) - AIC:139402.56317134225

# %%
#extract the best parameters for model
best_param =  grid_search.sort_values(by = 'AIC').reset_index()['param'][0]
best_seasonal_param = grid_search.sort_values(by = 'AIC').reset_index()['param_seasonal'][0]
grid_search.sort_values(by = 'AIC').reset_index()
# Out:
#     index      param param_seasonal            AIC
# 0      36  (1, 0, 0)  (1, 0, 0, 12)      58.355520
# 1      53  (1, 1, 0)  (1, 0, 1, 12)  134673.074037
# 2      29  (0, 1, 1)  (1, 0, 1, 12)  134703.562331
# 3      21  (0, 1, 0)  (1, 0, 1, 12)  134971.787903
# 4      37  (1, 0, 0)  (1, 0, 1, 12)  134999.056645
# ..    ...        ...            ...            ...
# 59      4  (0, 0, 0)  (1, 0, 0, 12)  290154.409836
# 60      9  (0, 0, 1)  (0, 0, 1, 12)  518965.454076
# 61      8  (0, 0, 1)  (0, 0, 0, 12)  576150.381568
# 62      1  (0, 0, 0)  (0, 0, 1, 12)  581315.694889
# 63      0  (0, 0, 0)  (0, 0, 0, 12)  638585.606974
#
# [64 rows x 4 columns]

# %% [markdown]
# **STEP 6: Run SARIMAX**

# %%
#Lowest AIC Value: ARIMA(1, 1, 1)x(1, 1, 0, 12)12 - AIC:122.9976149247615
#this adds exogenous data such as seasonality to the ARIMA model 
model = sm.tsa.statespace.SARIMAX(y,
                                order= best_param,
                                seasonal_order=best_seasonal_param,
                                enforce_stationarity=False,    #defaults, but not necessary
                                enforce_invertibility=False)
results = model.fit()
print(results.summary().tables[1])

# %% [markdown]
# **Check Model Fit**
# - Residuals: should be uncorrelated with a mean of 0, if there are correlations, there is information in them that should be used in computing forecasting. We can see that there is no correlation and zero mean.
# - Correlogram: residuals have relatively low corerlation with lagged versions of itself

# %%
results.plot_diagnostics(figsize=(16, 12))
plt.show()

# %% [markdown]
# **STEP 7: Generate Predictions**
#
# - dynamic: True = uses data from predicted points to generate future forecasts; False = generates one step ahead forecasts, i.e. uses only past data that we have to generate predicted forecasts
#     - If we are only generating predictions for one month, then this should not matter

# %%
#user can set predicted values to when they want the prediction to start 
prediction_start_date = weather_df.iloc[int(len(weather_df)*0.80)].name
#predict to the end of the dataset 
prediction_end_date = pd.to_datetime(weather_df.index[-1])



#generate predicted results and store 
pred = results.get_prediction(start=prediction_start_date, end = prediction_end_date, dynamic=False)

#predicted vs truth for time period in question -- if the forecast is negative, change to 0 
predicted = pred.predicted_mean
predicted[predicted <0] = 0

observed = weather_df[prediction_start_date:]
#confidence interval
ci = pred.conf_int()
ci[ci <0] = 0

#plot real against predicted values
ax = weather_df.plot(label='observed')
predicted.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 7))

ax.fill_between(ci.index,
                ci.iloc[:, 0],
                ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date')
ax.set_ylabel('Returns')
plt.legend()
plt.show()

# %%
ts_results = pd.DataFrame({'Predicted': predicted.values, 'CI Lower': ci['lower Temperature'], 'CI Upper': ci['upper Temperature'], 'Observed': observed['Temperature'].values})

#get RMSE -- calculate afterwards due to zeroing
ts_results['RMSE'] = np.sqrt((ts_results['Predicted'] - ts_results['Observed'].values)**2)
        
#RMSE of the entire prediction period 
RMSE_total = ts_results['RMSE'].mean()
RMSE_total
# Out:
# 0.5732114105008564

# %%
ts_results.head(20).style.background_gradient(cmap='inferno')
# Out:
# <style  type="text/css" >
# #T_bf11a_row0_col0,#T_bf11a_row0_col1,#T_bf11a_row0_col2,#T_bf11a_row0_col3,#T_bf11a_row0_col4{
#             background-color:  #fcffa4;
#             color:  #000000;
#         }#T_bf11a_row1_col0,#T_bf11a_row1_col1,#T_bf11a_row1_col2{
#             background-color:  #fcb418;
#             color:  #000000;
#         }#T_bf11a_row1_col3{
#             background-color:  #f8cf3a;
#             color:  #000000;
#         }#T_bf11a_row1_col4{
#             background-color:  #7c1d6d;
#             color:  #f1f1f1;
#         }#T_bf11a_row2_col0,#T_bf11a_row2_col1,#T_bf11a_row2_col2{
#             background-color:  #f98b0b;
#             color:  #000000;
#         }#T_bf11a_row2_col3{
#             background-color:  #fca80d;
#             color:  #000000;
#         }#T_bf11a_row2_col4{
#             background-color:  #210c4a;
#             color:  #f1f1f1;
#         }#T_bf11a_row3_col0,#T_bf11a_row3_col1,#T_bf11a_row3_col2{
#             background-color:  #f8870e;
#             color:  #000000;
#         }#T_bf11a_row3_col3{
#             background-color:  #f1731d;
#             color:  #000000;
#         }#T_bf11a_row3_col4{
#             background-color:  #f1ed71;
#             color:  #000000;
#         }#T_bf11a_row4_col0,#T_bf11a_row4_col1,#T_bf11a_row4_col2,#T_bf11a_row19_col0,#T_bf11a_row19_col1,#T_bf11a_row19_col2{
#             background-color:  #e25734;
#             color:  #000000;
#         }#T_bf11a_row4_col3{
#             background-color:  #eb6429;
#             color:  #000000;
#         }#T_bf11a_row4_col4{
#             background-color:  #420a68;
#             color:  #f1f1f1;
#         }#T_bf11a_row5_col0,#T_bf11a_row5_col1,#T_bf11a_row5_col2,#T_bf11a_row18_col3{
#             background-color:  #d84c3e;
#             color:  #000000;
#         }#T_bf11a_row5_col3{
#             background-color:  #c83f4b;
#             color:  #f1f1f1;
#         }#T_bf11a_row5_col4{
#             background-color:  #f68013;
#             color:  #000000;
#         }#T_bf11a_row6_col0,#T_bf11a_row6_col1,#T_bf11a_row6_col2{
#             background-color:  #ab2f5e;
#             color:  #f1f1f1;
#         }#T_bf11a_row6_col3{
#             background-color:  #ad305d;
#             color:  #f1f1f1;
#         }#T_bf11a_row6_col4{
#             background-color:  #3d0965;
#             color:  #f1f1f1;
#         }#T_bf11a_row7_col0,#T_bf11a_row7_col1,#T_bf11a_row7_col2{
#             background-color:  #9b2964;
#             color:  #f1f1f1;
#         }#T_bf11a_row7_col3{
#             background-color:  #7d1e6d;
#             color:  #f1f1f1;
#         }#T_bf11a_row7_col4{
#             background-color:  #f1711f;
#             color:  #000000;
#         }#T_bf11a_row8_col0,#T_bf11a_row8_col1,#T_bf11a_row8_col2{
#             background-color:  #721a6e;
#             color:  #f1f1f1;
#         }#T_bf11a_row8_col3{
#             background-color:  #3e0966;
#             color:  #f1f1f1;
#         }#T_bf11a_row8_col4{
#             background-color:  #f3e35a;
#             color:  #000000;
#         }#T_bf11a_row9_col0,#T_bf11a_row9_col1,#T_bf11a_row9_col2{
#             background-color:  #310a5c;
#             color:  #f1f1f1;
#         }#T_bf11a_row9_col3{
#             background-color:  #2b0b57;
#             color:  #f1f1f1;
#         }#T_bf11a_row9_col4{
#             background-color:  #1f0c48;
#             color:  #f1f1f1;
#         }#T_bf11a_row10_col0,#T_bf11a_row10_col1,#T_bf11a_row10_col2{
#             background-color:  #290b55;
#             color:  #f1f1f1;
#         }#T_bf11a_row10_col3,#T_bf11a_row12_col4,#T_bf11a_row13_col0,#T_bf11a_row13_col1,#T_bf11a_row13_col2{
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }#T_bf11a_row10_col4,#T_bf11a_row17_col4{
#             background-color:  #fcae12;
#             color:  #000000;
#         }#T_bf11a_row11_col0,#T_bf11a_row11_col1,#T_bf11a_row11_col2,#T_bf11a_row12_col3{
#             background-color:  #010005;
#             color:  #f1f1f1;
#         }#T_bf11a_row11_col3{
#             background-color:  #060419;
#             color:  #f1f1f1;
#         }#T_bf11a_row11_col4{
#             background-color:  #fa9407;
#             color:  #000000;
#         }#T_bf11a_row12_col0,#T_bf11a_row12_col1,#T_bf11a_row12_col2{
#             background-color:  #09061f;
#             color:  #f1f1f1;
#         }#T_bf11a_row13_col3{
#             background-color:  #07051b;
#             color:  #f1f1f1;
#         }#T_bf11a_row13_col4{
#             background-color:  #fbb61a;
#             color:  #000000;
#         }#T_bf11a_row14_col0,#T_bf11a_row14_col1,#T_bf11a_row14_col2{
#             background-color:  #180c3c;
#             color:  #f1f1f1;
#         }#T_bf11a_row14_col3{
#             background-color:  #2f0a5b;
#             color:  #f1f1f1;
#         }#T_bf11a_row14_col4{
#             background-color:  #f78212;
#             color:  #000000;
#         }#T_bf11a_row15_col0,#T_bf11a_row15_col1,#T_bf11a_row15_col2{
#             background-color:  #540f6d;
#             color:  #f1f1f1;
#         }#T_bf11a_row15_col3{
#             background-color:  #400a67;
#             color:  #f1f1f1;
#         }#T_bf11a_row15_col4{
#             background-color:  #57106e;
#             color:  #f1f1f1;
#         }#T_bf11a_row16_col0,#T_bf11a_row16_col1,#T_bf11a_row16_col2{
#             background-color:  #5c126e;
#             color:  #f1f1f1;
#         }#T_bf11a_row16_col3{
#             background-color:  #5f136e;
#             color:  #f1f1f1;
#         }#T_bf11a_row16_col4{
#             background-color:  #230c4c;
#             color:  #f1f1f1;
#         }#T_bf11a_row17_col0,#T_bf11a_row17_col1,#T_bf11a_row17_col2{
#             background-color:  #7f1e6c;
#             color:  #f1f1f1;
#         }#T_bf11a_row17_col3{
#             background-color:  #ae305c;
#             color:  #f1f1f1;
#         }#T_bf11a_row18_col0,#T_bf11a_row18_col1,#T_bf11a_row18_col2{
#             background-color:  #c03a51;
#             color:  #f1f1f1;
#         }#T_bf11a_row18_col4{
#             background-color:  #440a68;
#             color:  #f1f1f1;
#         }#T_bf11a_row19_col3{
#             background-color:  #f2741c;
#             color:  #000000;
#         }#T_bf11a_row19_col4{
#             background-color:  #1e0c45;
#             color:  #f1f1f1;
#         }</style><table id="T_bf11a_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Predicted</th>        <th class="col_heading level0 col1" >CI Lower</th>        <th class="col_heading level0 col2" >CI Upper</th>        <th class="col_heading level0 col3" >Observed</th>        <th class="col_heading level0 col4" >RMSE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_bf11a_level0_row0" class="row_heading level0 row0" >2016-11-17 22:00:00</th>
#                         <td id="T_bf11a_row0_col0" class="data row0 col0" >282.646626</td>
#                         <td id="T_bf11a_row0_col1" class="data row0 col1" >280.434067</td>
#                         <td id="T_bf11a_row0_col2" class="data row0 col2" >284.859184</td>
#                         <td id="T_bf11a_row0_col3" class="data row0 col3" >281.470000</td>
#                         <td id="T_bf11a_row0_col4" class="data row0 col4" >1.176626</td>
#             </tr>
#             <tr>
#                         <th id="T_bf11a_level0_row1" class="row_heading level0 row1" >2016-11-17 23:00:00</th>
#                         <td id="T_bf11a_row1_col0" class="data row1 col0" >280.889199</td>
#                         <td id="T_bf11a_row1_col1" class="data row1 col1" >278.676640</td>
#                         <td id="T_bf11a_row1_col2" class="data row1 col2" >283.101757</td>
#                         <td id="T_bf11a_row1_col3" class="data row1 col3" >280.480000</td>
#                         <td id="T_bf11a_row1_col4" class="data row1 col4" >0.409199</td>
#             </tr>
#             <tr>
#                         <th id="T_bf11a_level0_row2" class="row_heading level0 row2" >2016-11-18 00:00:00</th>
#                         <td id="T_bf11a_row2_col0" class="data row2 col0" >279.961020</td>
#                         <td id="T_bf11a_row2_col1" class="data row2 col1" >277.748461</td>

# %% [markdown]
# ## MODEL 2. AutoARIMA
#
#
# AutoARIMA is the least-specific base ARIMA model to generate a baseline prediction.
#
# Usually, in the basic ARIMA model, we need to provide the p,d, and q values which are essential. We use statistical techniques to generate these values by performing the difference to eliminate the non-stationarity and plotting ACF and PACF graphs. In Auto ARIMA, the model itself will generate the optimal p, d, and q values which would be suitable for the data set to provide better forecasting.
#
# **NOTE: AUTOARIMA CRASHES DUE TO DATA SIZE -- NOT CONTINUED**

# %%
from pmdarima.utils import tsdisplay 
from pmdarima.arima import auto_arima
import pmdarima as pm

# %%
from pmdarima.utils import tsdisplay 
tsdisplay(weather_df)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pmdarima/utils/visualization.py:222: FutureWarning: the 'unbiased'' keyword is deprecated, use 'adjusted' instead
#   vlines_kwargs=vlines_kwargs, **kwargs)

# %% [markdown]
# ## MODEL 3. GAM using FbProphet
#
# Prophet is a procedure for forecasting time series data based on an additive model where non-linear trends are fit with yearly, weekly, and daily seasonality, plus holiday effects. It works best with time series that have strong seasonal effects and several seasons of historical data. Prophet is robust to missing data and shifts in the trend, and typically handles outliers well.
#
# According to FB's paper, FbProphet is a decomposable time-series with 3 main components: trend, seasonality, and holidays. FbProphet is specified similar to a generalized additive model (GAM) -- which are regression models with potential non-linear smoothers applied to the regressors. IT can decompose easily and accomodate new components when they are introduced -- i.e. if a new source of seasonality is identified. Since GAM frames the forecating problem as a curve fitting exercise, it is different from ARIMA that accounts for the temporal dependence structure in the data -- so it is inferentially weaker than a generative model such as ARIMA. However, it is more flexible (can accomodate seasonality with multiple periods), measurements do not need to be regularly spaced (so missing values do not need to be interpolated), and fitting is faster.
#
# https://peerj.com/preprints/3190/
# https://facebook.github.io/prophet/

# %%
from fbprophet import Prophet

# %%
#Reformat to FbProphet Format
y_prophet = pd.DataFrame({'ds': weather_df.index, 'y': weather_df['Temperature'].values}).reset_index().drop('index', axis = 1)
y_prophet
# Out:
#                        ds           y
# 0     2012-10-01 13:00:00  285.830000
# 1     2012-10-01 14:00:00  285.834650
# 2     2012-10-01 15:00:00  285.847790
# 3     2012-10-01 16:00:00  285.860929
# 4     2012-10-01 17:00:00  285.874069
# ...                   ...         ...
# 45247 2017-11-29 20:00:00  275.130000
# 45248 2017-11-29 21:00:00  274.130000
# 45249 2017-11-29 22:00:00  273.480000
# 45250 2017-11-29 23:00:00  272.480000
# 45251 2017-11-30 00:00:00  271.800000
#
# [45252 rows x 2 columns]

# %%
#split data 
def train_test_split(data, n_test):
    return data[:n_test], data[n_test:]

split_len = int(len(y_prophet)*0.80)
train, test = train_test_split(y_prophet, split_len)

# %%
model = Prophet(yearly_seasonality = True, interval_width=0.95)
model.fit(train)

#in prophet, if you pass in historical dates it will provide an in-sample fit
forecast = model.make_future_dataframe(periods = len(test), freq = 'H')

results_df = model.predict(forecast)

# %%
#filter results down to test-dataset only 
results_filtered = results_df[['ds','yhat','yhat_lower','yhat_upper']].iloc[split_len:]

# %%
ts_results = pd.DataFrame({'Predicted' : results_filtered['yhat'].values, 'CI Lower': results_filtered['yhat_lower'].values, 'CI Upper':results_filtered['yhat_upper'].values , 'Observed': test['y'].values}, index = test['ds'])
ts_results[ts_results <0] = 0

ts_results['RMSE'] = np.sqrt((ts_results['Predicted'] - ts_results['Observed'])**2)
RMSE_total = ts_results['RMSE'].mean()
RMSE_total
# Out:
# 4.683666564629104

# %%
#plot real against predicted values
ax = weather_df.plot(label='observed')
ts_results['Predicted'].plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 7))


ax.fill_between(ts_results.index,
                ts_results['CI Lower'],
                ts_results['CI Upper'], color='k', alpha=.2)

ax.set_xlabel('Date')
ax.set_ylabel('Temperature')
plt.legend()
plt.show()

# %%
ts_results.head(20).style.background_gradient(cmap='inferno')
# Out:
# <style  type="text/css" >
# #T_8a030_row0_col0,#T_8a030_row0_col1,#T_8a030_row0_col2,#T_8a030_row0_col3,#T_8a030_row0_col4{
#             background-color:  #fcffa4;
#             color:  #000000;
#         }#T_8a030_row1_col0{
#             background-color:  #f8cd37;
#             color:  #000000;
#         }#T_8a030_row1_col1{
#             background-color:  #fa9407;
#             color:  #000000;
#         }#T_8a030_row1_col2{
#             background-color:  #f57d15;
#             color:  #000000;
#         }#T_8a030_row1_col3{
#             background-color:  #f8cf3a;
#             color:  #000000;
#         }#T_8a030_row1_col4{
#             background-color:  #f5d949;
#             color:  #000000;
#         }#T_8a030_row2_col0,#T_8a030_row18_col0{
#             background-color:  #f98e09;
#             color:  #000000;
#         }#T_8a030_row2_col1{
#             background-color:  #fca50a;
#             color:  #000000;
#         }#T_8a030_row2_col2,#T_8a030_row3_col4{
#             background-color:  #fbba1f;
#             color:  #000000;
#         }#T_8a030_row2_col3,#T_8a030_row5_col4{
#             background-color:  #fca80d;
#             color:  #000000;
#         }#T_8a030_row2_col4{
#             background-color:  #f2e661;
#             color:  #000000;
#         }#T_8a030_row3_col0{
#             background-color:  #e35933;
#             color:  #000000;
#         }#T_8a030_row3_col1{
#             background-color:  #fb9d07;
#             color:  #000000;
#         }#T_8a030_row3_col2{
#             background-color:  #f68013;
#             color:  #000000;
#         }#T_8a030_row3_col3{
#             background-color:  #f1731d;
#             color:  #000000;
#         }#T_8a030_row4_col0{
#             background-color:  #bf3952;
#             color:  #f1f1f1;
#         }#T_8a030_row4_col1{
#             background-color:  #d04545;
#             color:  #f1f1f1;
#         }#T_8a030_row4_col2{
#             background-color:  #d34743;
#             color:  #f1f1f1;
#         }#T_8a030_row4_col3{
#             background-color:  #eb6429;
#             color:  #000000;
#         }#T_8a030_row4_col4{
#             background-color:  #f1ec6d;
#             color:  #000000;
#         }#T_8a030_row5_col0{
#             background-color:  #9a2865;
#             color:  #f1f1f1;
#         }#T_8a030_row5_col1{
#             background-color:  #8c2369;
#             color:  #f1f1f1;
#         }#T_8a030_row5_col2{
#             background-color:  #db503b;
#             color:  #000000;
#         }#T_8a030_row5_col3{
#             background-color:  #c83f4b;
#             color:  #f1f1f1;
#         }#T_8a030_row6_col0,#T_8a030_row8_col1{
#             background-color:  #771c6d;
#             color:  #f1f1f1;
#         }#T_8a030_row6_col1{
#             background-color:  #4d0d6c;
#             color:  #f1f1f1;
#         }#T_8a030_row6_col2,#T_8a030_row7_col2{
#             background-color:  #751b6e;
#             color:  #f1f1f1;
#         }#T_8a030_row6_col3,#T_8a030_row16_col1{
#             background-color:  #ad305d;
#             color:  #f1f1f1;
#         }#T_8a030_row6_col4{
#             background-color:  #f98c0a;
#             color:  #000000;
#         }#T_8a030_row7_col0{
#             background-color:  #5a116e;
#             color:  #f1f1f1;
#         }#T_8a030_row7_col1,#T_8a030_row8_col3{
#             background-color:  #3e0966;
#             color:  #f1f1f1;
#         }#T_8a030_row7_col3{
#             background-color:  #7d1e6d;
#             color:  #f1f1f1;
#         }#T_8a030_row7_col4{
#             background-color:  #d24644;
#             color:  #f1f1f1;
#         }#T_8a030_row8_col0,#T_8a030_row15_col3{
#             background-color:  #400a67;
#             color:  #f1f1f1;
#         }#T_8a030_row8_col2{
#             background-color:  #721a6e;
#             color:  #f1f1f1;
#         }#T_8a030_row8_col4{
#             background-color:  #57106e;
#             color:  #f1f1f1;
#         }#T_8a030_row9_col0{
#             background-color:  #240c4f;
#             color:  #f1f1f1;
#         }#T_8a030_row9_col1{
#             background-color:  #360961;
#             color:  #f1f1f1;
#         }#T_8a030_row9_col2,#T_8a030_row18_col4{
#             background-color:  #6d186e;
#             color:  #f1f1f1;
#         }#T_8a030_row9_col3{
#             background-color:  #2b0b57;
#             color:  #f1f1f1;
#         }#T_8a030_row9_col4{
#             background-color:  #540f6d;
#             color:  #f1f1f1;
#         }#T_8a030_row10_col0{
#             background-color:  #0d0829;
#             color:  #f1f1f1;
#         }#T_8a030_row10_col1,#T_8a030_row10_col3,#T_8a030_row10_col4,#T_8a030_row12_col0,#T_8a030_row13_col1,#T_8a030_row13_col2{
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }#T_8a030_row10_col2,#T_8a030_row11_col4{
#             background-color:  #340a5f;
#             color:  #f1f1f1;
#         }#T_8a030_row11_col0{
#             background-color:  #02020c;
#             color:  #f1f1f1;
#         }#T_8a030_row11_col1,#T_8a030_row16_col4{
#             background-color:  #010108;
#             color:  #f1f1f1;
#         }#T_8a030_row11_col2{
#             background-color:  #1b0c41;
#             color:  #f1f1f1;
#         }#T_8a030_row11_col3{
#             background-color:  #060419;
#             color:  #f1f1f1;
#         }#T_8a030_row12_col1{
#             background-color:  #050417;
#             color:  #f1f1f1;
#         }#T_8a030_row12_col2{
#             background-color:  #3d0965;
#             color:  #f1f1f1;
#         }#T_8a030_row12_col3{
#             background-color:  #010005;
#             color:  #f1f1f1;
#         }#T_8a030_row12_col4{
#             background-color:  #160b39;
#             color:  #f1f1f1;
#         }#T_8a030_row13_col0{
#             background-color:  #040312;
#             color:  #f1f1f1;
#         }#T_8a030_row13_col3{
#             background-color:  #07051b;
#             color:  #f1f1f1;
#         }#T_8a030_row13_col4,#T_8a030_row14_col1{
#             background-color:  #310a5c;
#             color:  #f1f1f1;
#         }#T_8a030_row14_col0{
#             background-color:  #210c4a;
#             color:  #f1f1f1;
#         }#T_8a030_row14_col2{
#             background-color:  #64156e;
#             color:  #f1f1f1;
#         }#T_8a030_row14_col3{
#             background-color:  #2f0a5b;
#             color:  #f1f1f1;
#         }#T_8a030_row14_col4{
#             background-color:  #65156e;
#             color:  #f1f1f1;
#         }#T_8a030_row15_col0,#T_8a030_row16_col3{
#             background-color:  #5f136e;
#             color:  #f1f1f1;
#         }#T_8a030_row15_col1{
#             background-color:  #9d2964;
#             color:  #f1f1f1;
#         }#T_8a030_row15_col2{
#             background-color:  #781c6d;
#             color:  #f1f1f1;
#         }#T_8a030_row15_col4{
#             background-color:  #1f0c48;
#             color:  #f1f1f1;
#         }#T_8a030_row16_col0{
#             background-color:  #a32c61;
#             color:  #f1f1f1;
#         }#T_8a030_row16_col2{
#             background-color:  #c63d4d;
#             color:  #f1f1f1;
#         }#T_8a030_row17_col0{
#             background-color:  #df5337;
#             color:  #000000;
#         }#T_8a030_row17_col1{
#             background-color:  #f06f20;
#             color:  #000000;
#         }#T_8a030_row17_col2{
#             background-color:  #eb6628;
#             color:  #000000;
#         }#T_8a030_row17_col3{
#             background-color:  #ae305c;
#             color:  #f1f1f1;
#         }#T_8a030_row17_col4{
#             background-color:  #550f6d;
#             color:  #f1f1f1;
#         }#T_8a030_row18_col1{
#             background-color:  #fbbc21;
#             color:  #000000;
#         }#T_8a030_row18_col2{
#             background-color:  #ec6726;
#             color:  #000000;
#         }#T_8a030_row18_col3{
#             background-color:  #d84c3e;
#             color:  #000000;
#         }#T_8a030_row19_col0{
#             background-color:  #fac62d;
#             color:  #000000;
#         }#T_8a030_row19_col1{
#             background-color:  #f9fc9d;
#             color:  #000000;
#         }#T_8a030_row19_col2{
#             background-color:  #f7d13d;
#             color:  #000000;
#         }#T_8a030_row19_col3{
#             background-color:  #f2741c;

# %% [markdown]
# ## 3. XGBOOST & RF
#
# Now, we will try to transform the time-series data into a supervised learning problem by testing a variety of tree-based models.

# %%
ml_df = pd.DataFrame({'Temperature': weather_df['Temperature']}, index = weather_df.index)

# %%
#CREATE LAGGED ATTRIBUTES 

ml_df['date'] = ml_df.index
ml_df['month'] = ml_df['date'].dt.day
ml_df['month'] = ml_df['date'].dt.month
ml_df['year'] = ml_df['date'].dt.year

ml_df['lag1'] = ml_df['Temperature'].shift(periods = 1, fill_value = 0)
ml_df['lag2'] = ml_df['Temperature'].shift(periods = 2, fill_value = 0)
ml_df['lag12'] = ml_df['Temperature'].shift(periods = 12, fill_value = 0)
ml_df['lag30'] = ml_df['Temperature'].shift(periods = 30, fill_value = 0)

ml_df['avg_returns'] = 0 
for i in range(1, len(ml_df)):
    ml_df['avg_returns'][i] = ml_df['lag1'][:i+1].mean()
    

ml_df.drop('date', axis = 1, inplace = True)

#we have to eliminate all those with 0s
ml_df = ml_df[ml_df['lag30'] != 0]

# %%
X = ml_df.iloc[:,1:]
y = ml_df[['Temperature']]

# %%
X
# Out:
#                      month  year    lag1    lag2       lag12       lag30  \
# datetime
# 2012-10-02 19:00:00     10  2012  288.94  288.69  286.058023  285.830000
# 2012-10-02 20:00:00     10  2012  288.94  288.94  286.071162  285.834650
# 2012-10-02 21:00:00     10  2012  288.69  288.94  286.084302  285.847790
# 2012-10-02 22:00:00     10  2012  288.55  288.69  286.097442  285.860929
# 2012-10-02 23:00:00     10  2012  288.22  288.55  286.110581  285.874069
# ...                    ...   ...     ...     ...         ...         ...
# 2017-11-29 20:00:00     11  2017  276.45  276.15  275.380000  265.120000
# 2017-11-29 21:00:00     11  2017  275.13  276.45  277.450000  266.120000
# 2017-11-29 22:00:00     11  2017  274.13  275.13  278.770000  268.100000
# 2017-11-29 23:00:00     11  2017  273.48  274.13  278.480000  269.770000
# 2017-11-30 00:00:00     11  2017  272.48  273.48  277.450000  271.770000
#
#                      avg_returns
# datetime
# 2012-10-02 19:00:00          277
# 2012-10-02 20:00:00          277
# 2012-10-02 21:00:00          277
# 2012-10-02 22:00:00          278
# 2012-10-02 23:00:00          278
# ...                          ...
# 2017-11-29 20:00:00          280
# 2017-11-29 21:00:00          280
# 2017-11-29 22:00:00          280
# 2017-11-29 23:00:00          280
# 2017-11-30 00:00:00          280
#
# [45222 rows x 7 columns]

# %%
def train_test_split(data, n_test):
    return data[:n_test], data[n_test:]

split_len = int(len(weather_df)*0.80)

X_train, X_test = train_test_split(X, split_len)
y_train, y_test = train_test_split(y, split_len)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_train = pd.DataFrame(X_train_scaled)

X_test_scaled = scaler.transform(X_test)
X_test = pd.DataFrame(X_test_scaled)

# %% [markdown]
# ### XGB Regressor

# %%
import xgboost as xgb

xgb_model = xgb.XGBRegressor(n_estimators=1000)
xgb_model.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        early_stopping_rounds=50,
       verbose=False) 

pred = xgb_model.predict(X_test)

# %%
ts_results = pd.DataFrame({'Predicted': pred, 'Observed': y_test['Temperature']})
ts_results[ts_results['Predicted'] <= 0] = 0
ts_results['RMSE'] = np.sqrt((ts_results['Predicted']-ts_results['Observed'])**2)
ts_results['RMSE'].mean()
# Out:
# 0.6215244417273079

# %%
#plot real against predicted values
ax = weather_df.plot(label='observed')
ts_results['Predicted'].plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(10, 5))

ax.set_xlabel('Date')
ax.set_ylabel('Temperature')
plt.legend()
plt.show()

# %%
ts_results.head(20).style.background_gradient(cmap='inferno')
# Out:
# <style  type="text/css" >
# #T_2b891_row0_col0{
#             background-color:  #741a6e;
#             color:  #f1f1f1;
#         }#T_2b891_row0_col1{
#             background-color:  #67166e;
#             color:  #f1f1f1;
#         }#T_2b891_row0_col2{
#             background-color:  #85216b;
#             color:  #f1f1f1;
#         }#T_2b891_row1_col0,#T_2b891_row1_col1{
#             background-color:  #440a68;
#             color:  #f1f1f1;
#         }#T_2b891_row1_col2{
#             background-color:  #390963;
#             color:  #f1f1f1;
#         }#T_2b891_row2_col0{
#             background-color:  #380962;
#             color:  #f1f1f1;
#         }#T_2b891_row2_col1{
#             background-color:  #1f0c48;
#             color:  #f1f1f1;
#         }#T_2b891_row2_col2{
#             background-color:  #ad305d;
#             color:  #f1f1f1;
#         }#T_2b891_row3_col0,#T_2b891_row5_col1,#T_2b891_row7_col1,#T_2b891_row8_col1{
#             background-color:  #040314;
#             color:  #f1f1f1;
#         }#T_2b891_row3_col1{
#             background-color:  #210c4a;
#             color:  #f1f1f1;
#         }#T_2b891_row3_col2{
#             background-color:  #62146e;
#             color:  #f1f1f1;
#         }#T_2b891_row4_col0{
#             background-color:  #0e092b;
#             color:  #f1f1f1;
#         }#T_2b891_row4_col1{
#             background-color:  #10092d;
#             color:  #f1f1f1;
#         }#T_2b891_row4_col2,#T_2b891_row11_col1{
#             background-color:  #310a5c;
#             color:  #f1f1f1;
#         }#T_2b891_row5_col0,#T_2b891_row5_col2,#T_2b891_row6_col0,#T_2b891_row6_col1{
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }#T_2b891_row6_col2{
#             background-color:  #290b55;
#             color:  #f1f1f1;
#         }#T_2b891_row7_col0{
#             background-color:  #02020c;
#             color:  #f1f1f1;
#         }#T_2b891_row7_col2{
#             background-color:  #0a0722;
#             color:  #f1f1f1;
#         }#T_2b891_row8_col0{
#             background-color:  #0c0826;
#             color:  #f1f1f1;
#         }#T_2b891_row8_col2{
#             background-color:  #751b6e;
#             color:  #f1f1f1;
#         }#T_2b891_row9_col0,#T_2b891_row9_col1{
#             background-color:  #050417;
#             color:  #f1f1f1;
#         }#T_2b891_row9_col2,#T_2b891_row12_col0{
#             background-color:  #2f0a5b;
#             color:  #f1f1f1;
#         }#T_2b891_row10_col0{
#             background-color:  #0b0724;
#             color:  #f1f1f1;
#         }#T_2b891_row10_col1{
#             background-color:  #040312;
#             color:  #f1f1f1;
#         }#T_2b891_row10_col2{
#             background-color:  #6a176e;
#             color:  #f1f1f1;
#         }#T_2b891_row11_col0{
#             background-color:  #02020e;
#             color:  #f1f1f1;
#         }#T_2b891_row11_col2{
#             background-color:  #b93556;
#             color:  #f1f1f1;
#         }#T_2b891_row12_col1,#T_2b891_row12_col2{
#             background-color:  #540f6d;
#             color:  #f1f1f1;
#         }#T_2b891_row13_col0{
#             background-color:  #61136e;
#             color:  #f1f1f1;
#         }#T_2b891_row13_col1{
#             background-color:  #8d2369;
#             color:  #f1f1f1;
#         }#T_2b891_row13_col2{
#             background-color:  #71196e;
#             color:  #f1f1f1;
#         }#T_2b891_row14_col0{
#             background-color:  #922568;
#             color:  #f1f1f1;
#         }#T_2b891_row14_col1{
#             background-color:  #cb4149;
#             color:  #f1f1f1;
#         }#T_2b891_row14_col2{
#             background-color:  #b1325a;
#             color:  #f1f1f1;
#         }#T_2b891_row15_col0{
#             background-color:  #cc4248;
#             color:  #f1f1f1;
#         }#T_2b891_row15_col1{
#             background-color:  #e45a31;
#             color:  #000000;
#         }#T_2b891_row15_col2{
#             background-color:  #110a30;
#             color:  #f1f1f1;
#         }#T_2b891_row16_col0{
#             background-color:  #eb6628;
#             color:  #000000;
#         }#T_2b891_row16_col1,#T_2b891_row18_col1{
#             background-color:  #f9c932;
#             color:  #000000;
#         }#T_2b891_row16_col2{
#             background-color:  #fb9606;
#             color:  #000000;
#         }#T_2b891_row17_col0{
#             background-color:  #fbb81d;
#             color:  #000000;
#         }#T_2b891_row17_col1,#T_2b891_row18_col0,#T_2b891_row18_col2{
#             background-color:  #fcffa4;
#             color:  #000000;
#         }#T_2b891_row17_col2{
#             background-color:  #a52c60;
#             color:  #f1f1f1;
#         }#T_2b891_row19_col0{
#             background-color:  #f57d15;
#             color:  #000000;
#         }#T_2b891_row19_col1{
#             background-color:  #f98b0b;
#             color:  #000000;
#         }#T_2b891_row19_col2{
#             background-color:  #2d0b59;
#             color:  #f1f1f1;
#         }</style><table id="T_2b891_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Predicted</th>        <th class="col_heading level0 col1" >Observed</th>        <th class="col_heading level0 col2" >RMSE</th>    </tr>    <tr>        <th class="index_name level0" >datetime</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2b891_level0_row0" class="row_heading level0 row0" >2016-11-19 04:00:00</th>
#                         <td id="T_2b891_row0_col0" class="data row0 col0" >277.750916</td>
#                         <td id="T_2b891_row0_col1" class="data row0 col1" >277.150000</td>
#                         <td id="T_2b891_row0_col2" class="data row0 col2" >0.600916</td>
#             </tr>
#             <tr>
#                         <th id="T_2b891_level0_row1" class="row_heading level0 row1" >2016-11-19 05:00:00</th>
#                         <td id="T_2b891_row1_col0" class="data row1 col0" >276.765594</td>
#                         <td id="T_2b891_row1_col1" class="data row1 col1" >276.460000</td>
#                         <td id="T_2b891_row1_col2" class="data row1 col2" >0.305594</td>
#             </tr>
#             <tr>
#                         <th id="T_2b891_level0_row2" class="row_heading level0 row2" >2016-11-19 06:00:00</th>
#                         <td id="T_2b891_row2_col0" class="data row2 col0" >276.556213</td>
#                         <td id="T_2b891_row2_col1" class="data row2 col1" >275.800000</td>
#                         <td id="T_2b891_row2_col2" class="data row2 col2" >0.756213</td>
#             </tr>
#             <tr>
#                         <th id="T_2b891_level0_row3" class="row_heading level0 row3" >2016-11-19 07:00:00</th>
#                         <td id="T_2b891_row3_col0" class="data row3 col0" >275.356995</td>
#                         <td id="T_2b891_row3_col1" class="data row3 col1" >275.820000</td>
#                         <td id="T_2b891_row3_col2" class="data row3 col2" >0.463005</td>
#             </tr>
#             <tr>
#                         <th id="T_2b891_level0_row4" class="row_heading level0 row4" >2016-11-19 08:00:00</th>
#                         <td id="T_2b891_row4_col0" class="data row4 col0" >275.710419</td>
#                         <td id="T_2b891_row4_col1" class="data row4 col1" >275.440000</td>
#                         <td id="T_2b891_row4_col2" class="data row4 col2" >0.270419</td>
#             </tr>
#             <tr>
#                         <th id="T_2b891_level0_row5" class="row_heading level0 row5" >2016-11-19 09:00:00</th>
#                         <td id="T_2b891_row5_col0" class="data row5 col0" >275.086945</td>
#                         <td id="T_2b891_row5_col1" class="data row5 col1" >275.100000</td>
#                         <td id="T_2b891_row5_col2" class="data row5 col2" >0.013055</td>
#             </tr>
#             <tr>
#                         <th id="T_2b891_level0_row6" class="row_heading level0 row6" >2016-11-19 10:00:00</th>
#                         <td id="T_2b891_row6_col0" class="data row6 col0" >275.057831</td>

# %%
plt.figure(figsize=(10,5))
xgb.plot_importance(reg, ax=plt.gca())
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='F score', ylabel='Features'>

# %% [markdown]
# ## Other Models

# %%
#Import models' packages
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error, mean_absolute_error


#Regression Models
regression_models = [['Linear Regression',LinearRegression()], 
                     ['RF regressor',RandomForestRegressor()], 
                     ['GBT',GradientBoostingRegressor()],
                     ['LASSO', Lasso()],
                     ['Ridge', Ridge()]]
                     

MSEs = []
MAEs = []
RMSEs = []
Models = ['Linear Regression', 'Random Forest Regressor', 'Gradient Boosting Regressor', 'Lasso', 'Ridge']

for name, model in regression_models: 
    print('Model = ', name)
    model.fit(X_train, y_train.values.ravel())
    y_test_pred = model.predict(X_test)
    
    MSE = mean_squared_error(y_test, y_test_pred)
    MAE = mean_absolute_error(y_test, y_test_pred)
    RMSE = np.sqrt(MSE)
    
    MSEs.append(MSE)
    MAEs.append(MAE)
    RMSEs.append(RMSE)
    print("MSE: ", MSE)
    print("RMSE: ", RMSE)
    print("MAE: ", MAE)
    print("-" * 19)
# Out:
# Model =  Linear Regression
# MSE:  0.7660246634626545
# RMSE:  0.87522834932528
# MAE:  0.6156175777960075
# -------------------
# Model =  RF regressor
# MSE:  0.7576237456846826
# RMSE:  0.8704158464117496
# MAE:  0.6125927846333263
# -------------------
# Model =  GBT
# MSE:  0.8457809512595101
# RMSE:  0.9196634989274665
# MAE:  0.6482448946186754
# -------------------
# Model =  LASSO
# MSE:  1.8725698878222663
# RMSE:  1.3684187545566109
# MAE:  1.0728763110733437
# -------------------
# Model =  Ridge
# MSE:  0.7675801400618167
# RMSE:  0.8761165105520022
# MAE:  0.6165062483437543
# -------------------
