# %% [markdown]
# # INSY 695 - AutoML using Ludwig

# %%
import pandas as pd
import numpy as np
import os
import platform as pf
from IPython.display import display # Display data
pd.options.mode.chained_assignment = None  # default='warn'

#comment
#packages for time series
import warnings
import itertools    
import statsmodels.api as sm

#Richard was here
from datetime import timedelta
from dateutil.relativedelta import relativedelta
import matplotlib.pyplot as plt
import math
from scipy import stats

plt.style.use('fivethirtyeight')

# %% [markdown]
# ## Import Data

# %%
#import helper file 
import helper
from helper import *

# %%
df = load_and_preprocess()

# %%
df
# Out:
#                   datetime       Description  Humidity  Wind Direction  \
# 1      2012-10-01 13:00:00      heavy clouds      93.0          1001.0
# 2      2012-10-01 14:00:00      sky is clear      91.0           986.0
# 3      2012-10-01 15:00:00      sky is clear      87.0           945.0
# 4      2012-10-01 16:00:00      sky is clear      84.0           904.0
# 5      2012-10-01 17:00:00      sky is clear      80.0           863.0
# ...                    ...               ...       ...             ...
# 45248  2017-11-29 20:00:00  moderate  clouds      64.0          1021.0
# 45249  2017-11-29 21:00:00  moderate  clouds      59.0          1023.0
# 45250  2017-11-29 22:00:00     light  clouds      66.0          1024.0
# 45251  2017-11-29 23:00:00     light  clouds      58.0          1026.0
# 45252  2017-11-30 00:00:00     light  clouds      58.0          1027.0
#
#        Temperature  Pressure  Wind Speed  clouds  rain  mist  snow  shower  \
# 1       285.830000     230.0         4.0       1     0     0     0       0
# 2       285.834650     230.0         4.0       0     0     0     0       0
# 3       285.847790     231.0         4.0       0     0     0     0       0
# 4       285.860929     233.0         4.0       0     0     0     0       0
# 5       285.874069     234.0         3.0       0     0     0     0       0
# ...            ...       ...         ...     ...   ...   ...   ...     ...
# 45248   275.130000     300.0        10.0       1     0     0     0       0
# 45249   274.130000     300.0         7.0       1     0     0     0       0
# 45250   273.480000     290.0         7.0       1     0     0     0       0
# 45251   272.480000     290.0         4.0       1     0     0     0       0
# 45252   271.800000     300.0         4.0       1     0     0     0       0
#
#        thunderstorm  fog  other  Intensity
# 1                 0    0      0        3.0
# 2                 0    0      0        0.0
# 3                 0    0      0        0.0
# 4                 0    0      0        0.0
# 5                 0    0      0        0.0
# ...             ...  ...    ...        ...
# 45248             0    0      0        2.0
# 45249             0    0      0        2.0
# 45250             0    0      0        1.0
# 45251             0    0      0        1.0
# 45252             0    0      0        1.0
#
# [45252 rows x 16 columns]

# %%
weather_df = df[['datetime', 'Temperature']].set_index('datetime')
weather_df = weather_df.reset_index()
weather_df
# Out:
#                   datetime  Temperature
# 0      2012-10-01 13:00:00   285.830000
# 1      2012-10-01 14:00:00   285.834650
# 2      2012-10-01 15:00:00   285.847790
# 3      2012-10-01 16:00:00   285.860929
# 4      2012-10-01 17:00:00   285.874069
# ...                    ...          ...
# 45247  2017-11-29 20:00:00   275.130000
# 45248  2017-11-29 21:00:00   274.130000
# 45249  2017-11-29 22:00:00   273.480000
# 45250  2017-11-29 23:00:00   272.480000
# 45251  2017-11-30 00:00:00   271.800000
#
# [45252 rows x 2 columns]

# %% [markdown]
# ## Format into Train and Test sets
#
# Format data for time-series prediction by specifying train, validation, and tests sets and generate a new csv to store the formatted data in.

# %%
import pandas as pd
from ludwig.utils.data_utils import add_sequence_feature_column

ludwig_df = (weather_df[['Temperature']]
).rename(
    columns={"Temperature": "temperature"}
).fillna(method='backfill').fillna(method='ffill')

# normalize
ludwig_df.temperature = ((ludwig_df.temperature-ludwig_df.temperature.mean()) /
                  ludwig_df.temperature.std())

train_size = int(0.6 * len(ludwig_df))
vali_size = int(0.2 * len(ludwig_df))

# train, validation, test split
ludwig_df['split'] = 0
ludwig_df.loc[
    (
        (df.index.values >= train_size) &
        (df.index.values < train_size + vali_size)
    ),
    ('split')
] = 1
ludwig_df.loc[
    df.index.values >= train_size + vali_size,
    ('split')
] = 2

# prepare timeseries input feature colum
# (here we are using 20 preceding values to predict the target)
add_sequence_feature_column(ludwig_df, 'temperature', 20)
ludwig_df.to_csv('temperature_ludwig.csv')

# %% [markdown]
# ## Time Series Forecast using Ludwig

# %%
! pip install pyyaml
# Out:
# Requirement already satisfied: pyyaml in /opt/anaconda3/lib/python3.7/site-packages (5.3.1)

# %% [markdown]
# **Generate YAML config file**
#
# First, we create a YAML file which stores the configurations neeeded to run the time-series data. We specify the inputs and outputs, and run an RNN analysis using Ludwig.

# %%
import yaml

with open('config.yaml') as file:
    # The FullLoader parameter handles the conversion from YAML
    # scalar values to Python the dictionary format
    config = yaml.load(file, Loader=yaml.FullLoader)

    print(config)
# Out:
# {'input_features': [{'name': 'temperature_feature', 'type': 'timeseries', 'encoder': 'rnn', 'embedding_size': 32, 'state_size': 32}], 'output_features': [{'name': 'temperature', 'type': 'numerical'}]}

# %% [markdown]
# **Run Ludwig experiment in command line**
#
# Specify the formatted time series dataframe as input as well as the config.yaml file to run the analysis. The train, validation, and test losses are recorded at each epoch. Early stopping of the training occurs due to lack of validation improvement once there has been 5 epochs since the last validation improvement, and the losses and R^2 score are recorded.
#
# The logs are stored which can be visualized.

# %%
# !ludwig experiment \
--dataset temperature_ludwig.csv \
--config_file config.yaml
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/typeguard/__init__.py:917: UserWarning: no type annotations present -- not typechecking tensorflow_addons.layers.max_unpooling_2d.MaxUnpooling2D.__init__
#   warn('no type annotations present -- not typechecking {}'.format(function_name(func)))
# ███████████████████████
# █ █ █ █  ▜█ █ █ █ █   █
# █ █ █ █ █ █ █ █ █ █ ███
# █ █   █ █ █ █ █ █ █ ▌ █
# █ █████ █ █ █ █ █ █ █ █
# █     █  ▟█     █ █   █
# ███████████████████████
# ludwig v0.3.3 - Experiment
#
# 2021-04-08 21:52:55.004941: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# Experiment name: experiment
# Model name: run
# Output directory: results/experiment_run
#
#
# ludwig_version: '0.3.3'
# command: ('/opt/anaconda3/bin/ludwig experiment --dataset temperature_ludwig.csv '
#  '--config_file config.yaml')
# commit_hash: '432035164631'
# random_seed: 42
# dataset: 'temperature_ludwig.csv'
# data_format: 'csv'
# config: {   'combiner': {'type': 'concat'},
#     'input_features': [   {   'column': 'temperature_feature',
#                               'embedding_size': 32,
#                               'encoder': 'rnn',
#                               'name': 'temperature_feature',
#                               'proc_column': 'temperature_feature_mZFLky',
#                               'state_size': 32,
#                               'tied': None,
#                               'type': 'timeseries'}],
#     'output_features': [   {   'clip': None,
#                                'column': 'temperature',
#                                'dependencies': [],
#                                'loss': {   'type': 'mean_squared_error',
#                                            'weight': 1},
#                                'name': 'temperature',
#                                'proc_column': 'temperature_mZFLky',
#                                'reduce_dependencies': 'sum',
#                                'reduce_input': 'sum',
#                                'type': 'numerical'}],
#     'preprocessing': {   'audio': {   'audio_feature': {'type': 'raw'},
#                                       'audio_file_length_limit_in_s': 7.5,
#                                       'in_memory': True,
#                                       'missing_value_strategy': 'backfill',
#                                       'norm': None,
#                                       'padding_value': 0},
#                          'bag': {   'fill_value': '<UNK>',
#                                     'lowercase': False,
#                                     'missing_value_strategy': 'fill_with_const',
#                                     'most_common': 10000,
#                                     'tokenizer': 'space'},
#                          'binary': {   'fill_value': 0,
#                                        'missing_value_strategy': 'fill_with_const'},
#                          'category': {   'fill_value': '<UNK>',
#                                          'lowercase': False,
#                                          'missing_value_strategy': 'fill_with_const',
#                                          'most_common': 10000},
#                          'date': {   'datetime_format': None,
#                                      'fill_value': '',
#                                      'missing_value_strategy': 'fill_with_const'},
#                          'force_split': False,
#                          'h3': {   'fill_value': 576495936675512319,
#                                    'missing_value_strategy': 'fill_with_const'},
#                          'image': {   'in_memory': True,
#                                       'missing_value_strategy': 'backfill',
#                                       'num_processes': 1,
#                                       'resize_method': 'interpolate',
#                                       'scaling': 'pixel_normalization'},
#                          'numerical': {   'fill_value': 0,
#                                           'missing_value_strategy': 'fill_with_const',
#                                           'normalization': None},
#                          'sequence': {   'fill_value': '<UNK>',
#                                          'lowercase': False,
#                                          'missing_value_strategy': 'fill_with_const',
#                                          'most_common': 20000,
#                                          'padding': 'right',
#                                          'padding_symbol': '<PAD>',
#                                          'sequence_length_limit': 256,
#                                          'tokenizer': 'space',
#                                          'unknown_symbol': '<UNK>',
#                                          'vocab_file': None},
#                          'set': {   'fill_value': '<UNK>',
#                                     'lowercase': False,
#                                     'missing_value_strategy': 'fill_with_const',
#                                     'most_common': 10000,
#                                     'tokenizer': 'space'},
#                          'split_probabilities': (0.7, 0.1, 0.2),
#                          'stratify': None,
#                          'text': {   'char_most_common': 70,
#                                      'char_sequence_length_limit': 1024,
#                                      'char_tokenizer': 'characters',
#                                      'char_vocab_file': None,
#                                      'fill_value': '<UNK>',
#                                      'lowercase': True,
#                                      'missing_value_strategy': 'fill_with_const',
#                                      'padding': 'right',
#                                      'padding_symbol': '<PAD>',
#                                      'pretrained_model_name_or_path': None,
#                                      'unknown_symbol': '<UNK>',
#                                      'word_most_common': 20000,
#                                      'word_sequence_length_limit': 256,
#                                      'word_tokenizer': 'space_punct',
#                                      'word_vocab_file': None},
#                          'timeseries': {   'fill_value': '',
#                                            'missing_value_strategy': 'fill_with_const',
#                                            'padding': 'right',
#                                            'padding_value': 0,
#                                            'timeseries_length_limit': 256,
#                                            'tokenizer': 'space'},
#                          'vector': {   'fill_value': '',
#                                        'missing_value_strategy': 'fill_with_const'}},
#     'training': {   'batch_size': 128,
#                     'bucketing_field': None,
#                     'decay': False,
#                     'decay_rate': 0.96,
#                     'decay_steps': 10000,
#                     'early_stop': 5,
#                     'epochs': 100,
#                     'eval_batch_size': 0,
#                     'gradient_clipping': None,
#                     'increase_batch_size_on_plateau': 0,
#                     'increase_batch_size_on_plateau_max': 512,
#                     'increase_batch_size_on_plateau_patience': 5,
#                     'increase_batch_size_on_plateau_rate': 2,
#                     'learning_rate': 0.001,
#                     'learning_rate_warmup_epochs': 1,
#                     'optimizer': {   'beta_1': 0.9,
#                                      'beta_2': 0.999,
#                                      'epsilon': 1e-08,
#                                      'type': 'adam'},
#                     'reduce_learning_rate_on_plateau': 0,
#                     'reduce_learning_rate_on_plateau_patience': 5,
#                     'reduce_learning_rate_on_plateau_rate': 0.5,
#                     'regularization_lambda': 0,
#                     'regularizer': 'l2',
#                     'staircase': False,
#                     'validation_field': 'combined',
#                     'validation_metric': 'loss'}}
# tf_version: '2.4.1'
#
#
# Using full raw csv, no hdf5 and json file with the same name have been found
# Building dataset (it may take a while)
# Writing preprocessed dataset cache
# Writing train set metadata
# Training set: 27150
# Validation set: 9050
# Test set: 9052
# 2021-04-08 21:52:58.184955: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
#
# ╒══════════╕
# │ TRAINING │
# ╘══════════╛
#
#
# Epoch   1
# Training:   0%|                                         | 0/213 [00:00<?, ?it/s]2021-04-08 21:53:00.403336: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# Training: 100%|███████████████████████████████| 213/213 [00:03<00:00, 61.00it/s]
# Evaluation train: 100%|██████████████████████| 213/213 [00:01<00:00, 164.86it/s]
# Evaluation vali : 100%|████████████████████████| 71/71 [00:00<00:00, 269.04it/s]
# Evaluation test : 100%|████████████████████████| 71/71 [00:00<00:00, 272.52it/s]
# Took 5.3879s
# ╒═══════════════╤════════╤═════════╤══════════════════════╤═══════════════════════╤════════╕
# │ temperature   │   loss │   error │   mean_squared_error │   mean_absolute_error │     r2 │
# ╞═══════════════╪════════╪═════════╪══════════════════════╪═══════════════════════╪════════╡
# │ train         │ 0.0482 │ -0.0059 │               0.0482 │                0.1490 │ 0.9551 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ vali          │ 0.0364 │  0.0061 │               0.0364 │                0.1450 │ 0.9579 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ test          │ 0.0303 │ -0.0017 │               0.0303 │                0.1328 │ 0.9663 │
# ╘═══════════════╧════════╧═════════╧══════════════════════╧═══════════════════════╧════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.0469 │
# ├────────────┼────────┤
# │ vali       │ 0.0350 │
# ├────────────┼────────┤
# │ test       │ 0.0284 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch   2
# Training: 100%|██████████████████████████████| 213/213 [00:00<00:00, 252.15it/s]
# Evaluation train: 100%|██████████████████████| 213/213 [00:00<00:00, 796.40it/s]
# Evaluation vali : 100%|████████████████████████| 71/71 [00:00<00:00, 790.02it/s]
# Evaluation test : 100%|████████████████████████| 71/71 [00:00<00:00, 660.29it/s]
# Took 1.3318s
# ╒═══════════════╤════════╤═════════╤══════════════════════╤═══════════════════════╤════════╕
# │ temperature   │   loss │   error │   mean_squared_error │   mean_absolute_error │     r2 │
# ╞═══════════════╪════════╪═════════╪══════════════════════╪═══════════════════════╪════════╡
# │ train         │ 0.0267 │ -0.0024 │               0.0267 │                0.1042 │ 0.9752 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ vali          │ 0.0180 │ -0.0008 │               0.0180 │                0.1005 │ 0.9792 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ test          │ 0.0152 │ -0.0011 │               0.0152 │                0.0923 │ 0.9831 │
# ╘═══════════════╧════════╧═════════╧══════════════════════╧═══════════════════════╧════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.0260 │
# ├────────────┼────────┤
# │ vali       │ 0.0166 │
# ├────────────┼────────┤
# │ test       │ 0.0137 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch   3
# Training: 100%|██████████████████████████████| 213/213 [00:00<00:00, 260.44it/s]
# Evaluation train: 100%|██████████████████████| 213/213 [00:00<00:00, 737.86it/s]
# Evaluation vali : 100%|████████████████████████| 71/71 [00:00<00:00, 662.09it/s]
# Evaluation test : 100%|████████████████████████| 71/71 [00:00<00:00, 806.65it/s]
# Took 1.3239s
# ╒═══════════════╤════════╤═════════╤══════════════════════╤═══════════════════════╤════════╕
# │ temperature   │   loss │   error │   mean_squared_error │   mean_absolute_error │     r2 │
# ╞═══════════════╪════════╪═════════╪══════════════════════╪═══════════════════════╪════════╡
# │ train         │ 0.0197 │ -0.0160 │               0.0197 │                0.0871 │ 0.9817 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ vali          │ 0.0126 │ -0.0154 │               0.0126 │                0.0835 │ 0.9854 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ test          │ 0.0106 │ -0.0148 │               0.0106 │                0.0761 │ 0.9883 │
# ╘═══════════════╧════════╧═════════╧══════════════════════╧═══════════════════════╧════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.0193 │
# ├────────────┼────────┤
# │ vali       │ 0.0113 │
# ├────────────┼────────┤
# │ test       │ 0.0094 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch   4
# Training: 100%|██████████████████████████████| 213/213 [00:00<00:00, 226.23it/s]
# Evaluation train: 100%|██████████████████████| 213/213 [00:00<00:00, 766.33it/s]
# Evaluation vali : 100%|████████████████████████| 71/71 [00:00<00:00, 779.74it/s]
# Evaluation test : 100%|████████████████████████| 71/71 [00:00<00:00, 795.92it/s]
# Took 1.4212s
# ╒═══════════════╤════════╤═════════╤══════════════════════╤═══════════════════════╤════════╕
# │ temperature   │   loss │   error │   mean_squared_error │   mean_absolute_error │     r2 │
# ╞═══════════════╪════════╪═════════╪══════════════════════╪═══════════════════════╪════════╡
# │ train         │ 0.0159 │  0.0144 │               0.0159 │                0.0762 │ 0.9852 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ vali          │ 0.0100 │  0.0156 │               0.0100 │                0.0722 │ 0.9885 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ test          │ 0.0083 │  0.0164 │               0.0083 │                0.0672 │ 0.9908 │
# ╘═══════════════╧════════╧═════════╧══════════════════════╧═══════════════════════╧════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.0157 │
# ├────────────┼────────┤
# │ vali       │ 0.0087 │
# ├────────────┼────────┤
# │ test       │ 0.0074 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch   5
# Training: 100%|██████████████████████████████| 213/213 [00:00<00:00, 265.44it/s]
# Evaluation train: 100%|██████████████████████| 213/213 [00:00<00:00, 765.01it/s]
# Evaluation vali : 100%|████████████████████████| 71/71 [00:00<00:00, 594.43it/s]
# Evaluation test : 100%|████████████████████████| 71/71 [00:00<00:00, 617.40it/s]
# Took 1.3391s
# ╒═══════════════╤════════╤═════════╤══════════════════════╤═══════════════════════╤════════╕
# │ temperature   │   loss │   error │   mean_squared_error │   mean_absolute_error │     r2 │
# ╞═══════════════╪════════╪═════════╪══════════════════════╪═══════════════════════╪════════╡
# │ train         │ 0.0139 │ -0.0143 │               0.0139 │                0.0705 │ 0.9871 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ vali          │ 0.0086 │ -0.0153 │               0.0086 │                0.0669 │ 0.9901 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ test          │ 0.0070 │ -0.0142 │               0.0070 │                0.0613 │ 0.9922 │
# ╘═══════════════╧════════╧═════════╧══════════════════════╧═══════════════════════╧════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.0137 │
# ├────────────┼────────┤
# │ vali       │ 0.0075 │
# ├────────────┼────────┤
# │ test       │ 0.0063 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch   6
# Training: 100%|██████████████████████████████| 213/213 [00:00<00:00, 254.26it/s]
# Evaluation train: 100%|██████████████████████| 213/213 [00:00<00:00, 751.23it/s]
# Evaluation vali : 100%|████████████████████████| 71/71 [00:00<00:00, 672.69it/s]
# Evaluation test : 100%|████████████████████████| 71/71 [00:00<00:00, 778.93it/s]
# Took 1.3399s
# ╒═══════════════╤════════╤═════════╤══════════════════════╤═══════════════════════╤════════╕
# │ temperature   │   loss │   error │   mean_squared_error │   mean_absolute_error │     r2 │
# ╞═══════════════╪════════╪═════════╪══════════════════════╪═══════════════════════╪════════╡
# │ train         │ 0.0129 │  0.0193 │               0.0129 │                0.0669 │ 0.9880 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ vali          │ 0.0080 │  0.0194 │               0.0080 │                0.0625 │ 0.9908 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ test          │ 0.0065 │  0.0206 │               0.0065 │                0.0591 │ 0.9927 │
# ╘═══════════════╧════════╧═════════╧══════════════════════╧═══════════════════════╧════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.0128 │
# ├────────────┼────────┤
# │ vali       │ 0.0070 │
# ├────────────┼────────┤
# │ test       │ 0.0060 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch   7
# Training: 100%|██████████████████████████████| 213/213 [00:00<00:00, 260.56it/s]
# Evaluation train: 100%|██████████████████████| 213/213 [00:00<00:00, 719.24it/s]
# Evaluation vali : 100%|████████████████████████| 71/71 [00:00<00:00, 761.59it/s]
# Evaluation test : 100%|████████████████████████| 71/71 [00:00<00:00, 756.09it/s]
# Took 1.3212s
# ╒═══════════════╤════════╤═════════╤══════════════════════╤═══════════════════════╤════════╕
# │ temperature   │   loss │   error │   mean_squared_error │   mean_absolute_error │     r2 │
# ╞═══════════════╪════════╪═════════╪══════════════════════╪═══════════════════════╪════════╡
# │ train         │ 0.0116 │  0.0135 │               0.0116 │                0.0623 │ 0.9892 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ vali          │ 0.0070 │  0.0147 │               0.0070 │                0.0579 │ 0.9919 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ test          │ 0.0056 │  0.0151 │               0.0056 │                0.0540 │ 0.9938 │
# ╘═══════════════╧════════╧═════════╧══════════════════════╧═══════════════════════╧════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.0115 │
# ├────────────┼────────┤
# │ vali       │ 0.0059 │
# ├────────────┼────────┤
# │ test       │ 0.0049 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch   8
# Training: 100%|██████████████████████████████| 213/213 [00:00<00:00, 264.80it/s]
# Evaluation train: 100%|██████████████████████| 213/213 [00:00<00:00, 705.31it/s]
# Evaluation vali : 100%|████████████████████████| 71/71 [00:00<00:00, 712.59it/s]
# Evaluation test : 100%|████████████████████████| 71/71 [00:00<00:00, 672.99it/s]
# Took 1.3343s
# ╒═══════════════╤════════╤═════════╤══════════════════════╤═══════════════════════╤════════╕
# │ temperature   │   loss │   error │   mean_squared_error │   mean_absolute_error │     r2 │
# ╞═══════════════╪════════╪═════════╪══════════════════════╪═══════════════════════╪════════╡
# │ train         │ 0.0109 │  0.0055 │               0.0109 │                0.0584 │ 0.9898 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ vali          │ 0.0065 │  0.0056 │               0.0065 │                0.0539 │ 0.9925 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ test          │ 0.0051 │  0.0061 │               0.0051 │                0.0500 │ 0.9944 │
# ╘═══════════════╧════════╧═════════╧══════════════════════╧═══════════════════════╧════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.0108 │
# ├────────────┼────────┤
# │ vali       │ 0.0054 │
# ├────────────┼────────┤
# │ test       │ 0.0044 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch   9
# Training: 100%|██████████████████████████████| 213/213 [00:00<00:00, 223.61it/s]
# Evaluation train: 100%|██████████████████████| 213/213 [00:00<00:00, 653.25it/s]
# Evaluation vali : 100%|████████████████████████| 71/71 [00:00<00:00, 625.85it/s]
# Evaluation test : 100%|████████████████████████| 71/71 [00:00<00:00, 644.82it/s]
# Took 1.5341s
# ╒═══════════════╤════════╤═════════╤══════════════════════╤═══════════════════════╤════════╕
# │ temperature   │   loss │   error │   mean_squared_error │   mean_absolute_error │     r2 │
# ╞═══════════════╪════════╪═════════╪══════════════════════╪═══════════════════════╪════════╡
# │ train         │ 0.0126 │  0.0445 │               0.0126 │                0.0711 │ 0.9883 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ vali          │ 0.0084 │  0.0463 │               0.0084 │                0.0678 │ 0.9902 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ test          │ 0.0070 │  0.0466 │               0.0070 │                0.0646 │ 0.9922 │
# ╘═══════════════╧════════╧═════════╧══════════════════════╧═══════════════════════╧════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.0126 │
# ├────────────┼────────┤
# │ vali       │ 0.0075 │
# ├────────────┼────────┤
# │ test       │ 0.0065 │
# ╘════════════╧════════╛
# Last improvement of combined validation loss happened 1 epoch ago
#
#
# Epoch  10
# Training: 100%|██████████████████████████████| 213/213 [00:00<00:00, 228.29it/s]
# Evaluation train: 100%|██████████████████████| 213/213 [00:00<00:00, 701.11it/s]
# Evaluation vali : 100%|████████████████████████| 71/71 [00:00<00:00, 679.15it/s]
# Evaluation test : 100%|████████████████████████| 71/71 [00:00<00:00, 742.71it/s]
# Took 1.4580s
# ╒═══════════════╤════════╤═════════╤══════════════════════╤═══════════════════════╤════════╕
# │ temperature   │   loss │   error │   mean_squared_error │   mean_absolute_error │     r2 │
# ╞═══════════════╪════════╪═════════╪══════════════════════╪═══════════════════════╪════════╡
# │ train         │ 0.0105 │ -0.0042 │               0.0105 │                0.0571 │ 0.9902 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ vali          │ 0.0062 │ -0.0032 │               0.0062 │                0.0525 │ 0.9928 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ test          │ 0.0047 │ -0.0036 │               0.0047 │                0.0481 │ 0.9947 │
# ╘═══════════════╧════════╧═════════╧══════════════════════╧═══════════════════════╧════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.0104 │
# ├────────────┼────────┤
# │ vali       │ 0.0052 │
# ├────────────┼────────┤
# │ test       │ 0.0042 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  11
# Training: 100%|██████████████████████████████| 213/213 [00:01<00:00, 211.68it/s]
# Evaluation train: 100%|██████████████████████| 213/213 [00:00<00:00, 576.56it/s]
# Evaluation vali : 100%|████████████████████████| 71/71 [00:00<00:00, 766.68it/s]
# Evaluation test : 100%|████████████████████████| 71/71 [00:00<00:00, 629.69it/s]
# Took 1.6051s
# ╒═══════════════╤════════╤═════════╤══════════════════════╤═══════════════════════╤════════╕
# │ temperature   │   loss │   error │   mean_squared_error │   mean_absolute_error │     r2 │
# ╞═══════════════╪════════╪═════════╪══════════════════════╪═══════════════════════╪════════╡
# │ train         │ 0.0121 │  0.0410 │               0.0121 │                0.0685 │ 0.9888 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ vali          │ 0.0081 │  0.0437 │               0.0081 │                0.0656 │ 0.9907 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ test          │ 0.0065 │  0.0433 │               0.0065 │                0.0616 │ 0.9928 │
# ╘═══════════════╧════════╧═════════╧══════════════════════╧═══════════════════════╧════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.0120 │
# ├────────────┼────────┤
# │ vali       │ 0.0070 │
# ├────────────┼────────┤
# │ test       │ 0.0058 │
# ╘════════════╧════════╛
# Last improvement of combined validation loss happened 1 epoch ago
#
#
# Epoch  12
# Training: 100%|██████████████████████████████| 213/213 [00:01<00:00, 187.34it/s]
# Evaluation train: 100%|██████████████████████| 213/213 [00:00<00:00, 509.52it/s]
# Evaluation vali : 100%|████████████████████████| 71/71 [00:00<00:00, 642.69it/s]
# Evaluation test : 100%|████████████████████████| 71/71 [00:00<00:00, 647.56it/s]
# Took 1.8251s
# ╒═══════════════╤════════╤═════════╤══════════════════════╤═══════════════════════╤════════╕
# │ temperature   │   loss │   error │   mean_squared_error │   mean_absolute_error │     r2 │
# ╞═══════════════╪════════╪═════════╪══════════════════════╪═══════════════════════╪════════╡
# │ train         │ 0.0145 │  0.0648 │               0.0145 │                0.0834 │ 0.9865 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ vali          │ 0.0107 │  0.0671 │               0.0107 │                0.0811 │ 0.9877 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ test          │ 0.0091 │  0.0672 │               0.0091 │                0.0779 │ 0.9898 │
# ╘═══════════════╧════════╧═════════╧══════════════════════╧═══════════════════════╧════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.0145 │
# ├────────────┼────────┤
# │ vali       │ 0.0098 │
# ├────────────┼────────┤
# │ test       │ 0.0087 │
# ╘════════════╧════════╛
# Last improvement of combined validation loss happened 2 epochs ago
#
#
# Epoch  13
# Training: 100%|██████████████████████████████| 213/213 [00:01<00:00, 176.49it/s]
# Evaluation train: 100%|██████████████████████| 213/213 [00:00<00:00, 660.62it/s]
# Evaluation vali : 100%|████████████████████████| 71/71 [00:00<00:00, 789.98it/s]
# Evaluation test : 100%|████████████████████████| 71/71 [00:00<00:00, 760.23it/s]
# Took 1.7345s
# ╒═══════════════╤════════╤═════════╤══════════════════════╤═══════════════════════╤════════╕
# │ temperature   │   loss │   error │   mean_squared_error │   mean_absolute_error │     r2 │
# ╞═══════════════╪════════╪═════════╪══════════════════════╪═══════════════════════╪════════╡
# │ train         │ 0.0103 │  0.0019 │               0.0103 │                0.0557 │ 0.9904 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ vali          │ 0.0062 │  0.0021 │               0.0062 │                0.0519 │ 0.9928 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ test          │ 0.0046 │  0.0024 │               0.0046 │                0.0474 │ 0.9949 │
# ╘═══════════════╧════════╧═════════╧══════════════════════╧═══════════════════════╧════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.0102 │
# ├────────────┼────────┤
# │ vali       │ 0.0052 │
# ├────────────┼────────┤
# │ test       │ 0.0041 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  14
# Training: 100%|██████████████████████████████| 213/213 [00:00<00:00, 241.56it/s]
# Evaluation train: 100%|██████████████████████| 213/213 [00:00<00:00, 707.50it/s]
# Evaluation vali : 100%|████████████████████████| 71/71 [00:00<00:00, 611.14it/s]
# Evaluation test : 100%|████████████████████████| 71/71 [00:00<00:00, 593.57it/s]
# Took 1.4418s
# ╒═══════════════╤════════╤═════════╤══════════════════════╤═══════════════════════╤════════╕
# │ temperature   │   loss │   error │   mean_squared_error │   mean_absolute_error │     r2 │
# ╞═══════════════╪════════╪═════════╪══════════════════════╪═══════════════════════╪════════╡
# │ train         │ 0.0103 │ -0.0105 │               0.0103 │                0.0572 │ 0.9904 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ vali          │ 0.0062 │ -0.0093 │               0.0062 │                0.0533 │ 0.9928 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ test          │ 0.0046 │ -0.0098 │               0.0046 │                0.0481 │ 0.9948 │
# ╘═══════════════╧════════╧═════════╧══════════════════════╧═══════════════════════╧════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.0103 │
# ├────────────┼────────┤
# │ vali       │ 0.0054 │
# ├────────────┼────────┤
# │ test       │ 0.0042 │
# ╘════════════╧════════╛
# Last improvement of combined validation loss happened 1 epoch ago
#
#
# Epoch  15
# Training: 100%|██████████████████████████████| 213/213 [00:00<00:00, 226.40it/s]
# Evaluation train: 100%|██████████████████████| 213/213 [00:00<00:00, 725.59it/s]
# Evaluation vali : 100%|████████████████████████| 71/71 [00:00<00:00, 790.21it/s]
# Evaluation test : 100%|████████████████████████| 71/71 [00:00<00:00, 770.02it/s]
# Took 1.4373s
# ╒═══════════════╤════════╤═════════╤══════════════════════╤═══════════════════════╤════════╕
# │ temperature   │   loss │   error │   mean_squared_error │   mean_absolute_error │     r2 │
# ╞═══════════════╪════════╪═════════╪══════════════════════╪═══════════════════════╪════════╡
# │ train         │ 0.0101 │  0.0056 │               0.0101 │                0.0555 │ 0.9906 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ vali          │ 0.0061 │  0.0068 │               0.0061 │                0.0518 │ 0.9929 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ test          │ 0.0045 │  0.0065 │               0.0045 │                0.0469 │ 0.9950 │
# ╘═══════════════╧════════╧═════════╧══════════════════════╧═══════════════════════╧════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.0100 │
# ├────────────┼────────┤
# │ vali       │ 0.0052 │
# ├────────────┼────────┤
# │ test       │ 0.0040 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  16
# Training: 100%|██████████████████████████████| 213/213 [00:00<00:00, 259.25it/s]
# Evaluation train: 100%|██████████████████████| 213/213 [00:00<00:00, 681.00it/s]
# Evaluation vali : 100%|████████████████████████| 71/71 [00:00<00:00, 708.26it/s]
# Evaluation test : 100%|████████████████████████| 71/71 [00:00<00:00, 698.78it/s]
# Took 1.3593s
# ╒═══════════════╤════════╤═════════╤══════════════════════╤═══════════════════════╤════════╕
# │ temperature   │   loss │   error │   mean_squared_error │   mean_absolute_error │     r2 │
# ╞═══════════════╪════════╪═════════╪══════════════════════╪═══════════════════════╪════════╡
# │ train         │ 0.0101 │ -0.0024 │               0.0101 │                0.0548 │ 0.9906 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ vali          │ 0.0062 │ -0.0016 │               0.0062 │                0.0512 │ 0.9929 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ test          │ 0.0046 │ -0.0014 │               0.0046 │                0.0465 │ 0.9949 │
# ╘═══════════════╧════════╧═════════╧══════════════════════╧═══════════════════════╧════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.0100 │
# ├────────────┼────────┤
# │ vali       │ 0.0052 │
# ├────────────┼────────┤
# │ test       │ 0.0039 │
# ╘════════════╧════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  17
# Training: 100%|██████████████████████████████| 213/213 [00:00<00:00, 251.15it/s]
# Evaluation train: 100%|██████████████████████| 213/213 [00:00<00:00, 724.15it/s]
# Evaluation vali : 100%|████████████████████████| 71/71 [00:00<00:00, 650.83it/s]
# Evaluation test : 100%|████████████████████████| 71/71 [00:00<00:00, 631.95it/s]
# Took 1.3864s
# ╒═══════════════╤════════╤═════════╤══════════════════════╤═══════════════════════╤════════╕
# │ temperature   │   loss │   error │   mean_squared_error │   mean_absolute_error │     r2 │
# ╞═══════════════╪════════╪═════════╪══════════════════════╪═══════════════════════╪════════╡
# │ train         │ 0.0102 │  0.0036 │               0.0102 │                0.0571 │ 0.9905 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ vali          │ 0.0062 │  0.0054 │               0.0062 │                0.0531 │ 0.9928 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ test          │ 0.0047 │  0.0047 │               0.0047 │                0.0480 │ 0.9948 │
# ╘═══════════════╧════════╧═════════╧══════════════════════╧═══════════════════════╧════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.0101 │
# ├────────────┼────────┤
# │ vali       │ 0.0052 │
# ├────────────┼────────┤
# │ test       │ 0.0041 │
# ╘════════════╧════════╛
# Last improvement of combined validation loss happened 1 epoch ago
#
#
# Epoch  18
# Training: 100%|██████████████████████████████| 213/213 [00:00<00:00, 257.00it/s]
# Evaluation train: 100%|██████████████████████| 213/213 [00:00<00:00, 793.48it/s]
# Evaluation vali : 100%|████████████████████████| 71/71 [00:00<00:00, 825.91it/s]
# Evaluation test : 100%|████████████████████████| 71/71 [00:00<00:00, 717.53it/s]
# Took 1.3038s
# ╒═══════════════╤════════╤═════════╤══════════════════════╤═══════════════════════╤════════╕
# │ temperature   │   loss │   error │   mean_squared_error │   mean_absolute_error │     r2 │
# ╞═══════════════╪════════╪═════════╪══════════════════════╪═══════════════════════╪════════╡
# │ train         │ 0.0102 │ -0.0123 │               0.0102 │                0.0565 │ 0.9905 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ vali          │ 0.0063 │ -0.0125 │               0.0063 │                0.0530 │ 0.9927 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ test          │ 0.0047 │ -0.0123 │               0.0047 │                0.0478 │ 0.9948 │
# ╘═══════════════╧════════╧═════════╧══════════════════════╧═══════════════════════╧════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.0101 │
# ├────────────┼────────┤
# │ vali       │ 0.0053 │
# ├────────────┼────────┤
# │ test       │ 0.0041 │
# ╘════════════╧════════╛
# Last improvement of combined validation loss happened 2 epochs ago
#
#
# Epoch  19
# Training: 100%|██████████████████████████████| 213/213 [00:00<00:00, 268.72it/s]
# Evaluation train: 100%|██████████████████████| 213/213 [00:00<00:00, 700.10it/s]
# Evaluation vali : 100%|████████████████████████| 71/71 [00:00<00:00, 751.84it/s]
# Evaluation test : 100%|████████████████████████| 71/71 [00:00<00:00, 680.00it/s]
# Took 1.3187s
# ╒═══════════════╤════════╤═════════╤══════════════════════╤═══════════════════════╤════════╕
# │ temperature   │   loss │   error │   mean_squared_error │   mean_absolute_error │     r2 │
# ╞═══════════════╪════════╪═════════╪══════════════════════╪═══════════════════════╪════════╡
# │ train         │ 0.0100 │ -0.0105 │               0.0100 │                0.0555 │ 0.9907 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ vali          │ 0.0061 │ -0.0106 │               0.0061 │                0.0520 │ 0.9929 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ test          │ 0.0046 │ -0.0106 │               0.0046 │                0.0471 │ 0.9949 │
# ╘═══════════════╧════════╧═════════╧══════════════════════╧═══════════════════════╧════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.0100 │
# ├────────────┼────────┤
# │ vali       │ 0.0052 │
# ├────────────┼────────┤
# │ test       │ 0.0040 │
# ╘════════════╧════════╛
# Last improvement of combined validation loss happened 3 epochs ago
#
#
# Epoch  20
# Training: 100%|██████████████████████████████| 213/213 [00:00<00:00, 269.15it/s]
# Evaluation train: 100%|██████████████████████| 213/213 [00:00<00:00, 689.92it/s]
# Evaluation vali : 100%|████████████████████████| 71/71 [00:00<00:00, 647.10it/s]
# Evaluation test : 100%|████████████████████████| 71/71 [00:00<00:00, 716.43it/s]
# Took 1.3300s
# ╒═══════════════╤════════╤═════════╤══════════════════════╤═══════════════════════╤════════╕
# │ temperature   │   loss │   error │   mean_squared_error │   mean_absolute_error │     r2 │
# ╞═══════════════╪════════╪═════════╪══════════════════════╪═══════════════════════╪════════╡
# │ train         │ 0.0101 │  0.0169 │               0.0101 │                0.0573 │ 0.9906 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ vali          │ 0.0063 │  0.0170 │               0.0063 │                0.0537 │ 0.9927 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ test          │ 0.0048 │  0.0170 │               0.0048 │                0.0490 │ 0.9947 │
# ╘═══════════════╧════════╧═════════╧══════════════════════╧═══════════════════════╧════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.0101 │
# ├────────────┼────────┤
# │ vali       │ 0.0053 │
# ├────────────┼────────┤
# │ test       │ 0.0041 │
# ╘════════════╧════════╛
# Last improvement of combined validation loss happened 4 epochs ago
#
#
# Epoch  21
# Training: 100%|██████████████████████████████| 213/213 [00:00<00:00, 273.34it/s]
# Evaluation train: 100%|██████████████████████| 213/213 [00:00<00:00, 729.48it/s]
# Evaluation vali : 100%|████████████████████████| 71/71 [00:00<00:00, 761.80it/s]
# Evaluation test : 100%|████████████████████████| 71/71 [00:00<00:00, 634.38it/s]
# Took 1.2986s
# ╒═══════════════╤════════╤═════════╤══════════════════════╤═══════════════════════╤════════╕
# │ temperature   │   loss │   error │   mean_squared_error │   mean_absolute_error │     r2 │
# ╞═══════════════╪════════╪═════════╪══════════════════════╪═══════════════════════╪════════╡
# │ train         │ 0.0106 │ -0.0270 │               0.0106 │                0.0604 │ 0.9901 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ vali          │ 0.0069 │ -0.0285 │               0.0069 │                0.0575 │ 0.9921 │
# ├───────────────┼────────┼─────────┼──────────────────────┼───────────────────────┼────────┤
# │ test          │ 0.0053 │ -0.0280 │               0.0053 │                0.0524 │ 0.9941 │
# ╘═══════════════╧════════╧═════════╧══════════════════════╧═══════════════════════╧════════╛
# ╒════════════╤════════╕
# │ combined   │   loss │
# ╞════════════╪════════╡
# │ train      │ 0.0105 │
# ├────────────┼────────┤
# │ vali       │ 0.0059 │
# ├────────────┼────────┤
# │ test       │ 0.0046 │
# ╘════════════╧════════╛
# Last improvement of combined validation loss happened 5 epochs ago
#
# EARLY STOPPING due to lack of validation improvement, it has been 5 epochs since last validation improvement
#
# Best validation model epoch: 16
# Best validation model loss on validation set combined: 0.005158797837793827
# Best validation model loss on test set combined: 0.0039470018818974495
#
# Finished: experiment_run
# Saved to: results/experiment_run
# Evaluation: 100%|██████████████████████████████| 71/71 [00:00<00:00, 617.72it/s]
#
# ===== temperature =====
# error: -0.0013750335
# loss: 0.0045610433
# mean_absolute_error: 0.046483014
# mean_squared_error: 0.0045610443
# r2: 0.9949301
# Saved to: results/experiment_run

# %%
# !ludwig visualize --visualization learning_curves \
  --output_feature_name temperature \
  --training_statistics results/experiment_run/training_statistics.json \
  --model_names Model1
