# %%
from pprint import pprint
import requests
import os
API_KEY=os.getenv('WEATHER_API')
r = requests.get('http://api.openweathermap.org/data/2.5/weather?q=Montreal&APPID=484925ef3995e2026aa4d24818ac18b1')
pprint(r.json())
#https://openweathermap.org/api/one-call-api#history
# Out:
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 45.5088, 'lon': -73.5878},
#  'dt': 1616101580,
#  'id': 6077243,
#  'main': {'feels_like': 273.09,
#           'humidity': 42,
#           'pressure': 1016,
#           'temp': 279.05,
#           'temp_max': 279.15,
#           'temp_min': 278.71},
#  'name': 'Montreal',
#  'sys': {'country': 'CA',
#          'id': 498,
#          'sunrise': 1616065248,
#          'sunset': 1616108632,
#          'type': 1},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 10, 'gust': 7.72, 'speed': 4.63}}

# %%
from pandas import json_normalize 

response=json.loads(r.text)
response_cols=response.keys()
data=json_normalize(json.loads(r.text))
weather=json_normalize(json.loads(r.text),record_path=['weather'])
weather.columns='weather.'+weather.columns
weather
# Out:
#    weather.id weather.main weather.description weather.icon
# 0         804       Clouds     overcast clouds          04d

# %%
pd.set_option('max_columns', None)

# json.loads(r.text).keys()
pd.concat([data[data.columns[1:len(data.columns)]],weather],axis=1)
# Out:
#        base  visibility          dt  timezone       id      name  cod  \
# 0  stations       10000  1616101580    -14400  6077243  Montreal  200
#
#    coord.lon  coord.lat  main.temp  main.feels_like  main.temp_min  \
# 0   -73.5878    45.5088     279.05           273.09         278.71
#
#    main.temp_max  main.pressure  main.humidity  wind.speed  wind.deg  \
# 0         279.15           1016             42        4.63        10
#
#    wind.gust  clouds.all  sys.type  sys.id sys.country  sys.sunrise  \
# 0       7.72         100         1     498          CA   1616065248
#
#    sys.sunset  weather.id weather.main weather.description weather.icon
# 0  1616108632         804       Clouds     overcast clouds          04d
