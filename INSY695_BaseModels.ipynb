# %% [markdown]
# # INSY 695 - Base Models

# %%
import pandas as pd
import numpy as np
import os
import platform as pf
from IPython.display import display # Display data
pd.options.mode.chained_assignment = None  # default='warn'

#comment
#packages for time series
import warnings
import itertools    
import statsmodels.api as sm

#Richard was here
from datetime import timedelta
from dateutil.relativedelta import relativedelta
import matplotlib.pyplot as plt
import math
from scipy import stats

plt.style.use('fivethirtyeight')

# %% [markdown]
# ## 1. Load Data

# %%
cwd = os.getcwd()
os_type = pf.system()


if os_type == 'Windows':
    df = pd.read_csv(cwd + r'\montreal.csv', sep=',\s,', delimiter=',', skipinitialspace=True)
else:
    df = pd.read_csv(cwd + '/montreal.csv', sep=',\s,', delimiter=',', skipinitialspace=True)
    

#need to specify datetime[ns] or else the rest will not run 
df['datetime'] = df['datetime'].astype('datetime64[ns]')

# %%
weather_df = df[['datetime', 'Temperature']].set_index('datetime')

#Convert temp to Celsius
weather_df['Temperature'] = weather_df['Temperature']- 273.15

weather_df
# Out:
#                      Temperature
# datetime
# 2012-10-01 13:00:00    12.680000
# 2012-10-01 14:00:00    12.684650
# 2012-10-01 15:00:00    12.697790
# 2012-10-01 16:00:00    12.710929
# 2012-10-01 17:00:00    12.724069
# ...                          ...
# 2017-11-29 20:00:00     1.980000
# 2017-11-29 21:00:00     0.980000
# 2017-11-29 22:00:00     0.330000
# 2017-11-29 23:00:00    -0.670000
# 2017-11-30 00:00:00    -1.350000
#
# [45252 rows x 1 columns]

# %%
#plot current returns of part X resampled on a mean-returns month to month basis
weather_df.plot(figsize=(15, 6))
plt.show()

# %% [markdown]
# ## MODEL 1. Seasonal ARIMA
#
# Autoregressive Integrated Moving Average, or ARIMA, is one of the most widely used forecasting methods for univariate time series data forecasting.Although the method can handle data with a trend, it does not support time series with a seasonal component. An extension to ARIMA that supports the direct modeling of the seasonal component of the series is called SARIMA. It adds three new hyperparameters to specify the autoregression (AR), differencing (I) and moving average (MA) for the seasonal component of the series, as well as an additional parameter for the period of the seasonality.

# %% [markdown]
# **STEP 1: Decompose returns into trend, seasonal, and residual**
#
# Each time series can be decomposed into trend, seasonality, and noise
#
# We can see from the upward trend and annual seasonality that the time series may not be stationary. ARIMA must be stationary (no trends, cycles, random walk, etc.) to work, meaning mean, variance, correlation is constant over time -- if not stationary, transform into period-by-period differences instead.

# %%
from pylab import rcParams

#decompose observed returns into trend, seasonal, and noise 
rcParams['figure.figsize'] = 18, 8
decomposition = sm.tsa.seasonal_decompose(weather_df, model='additive')
fig = decomposition.plot()
plt.show()

# %% [markdown]
# **STEP 2: Run ADF (Augmented Dickey Fuller) Test to check for trend -- the null hypothesis is that the data is not stationary, so if p > 0.05, we can confirm the series is not stationary (there is a trend), and need to do first-order-differencing.**
#
# The data is stationary if its mean, variance, and covariance remain constant over time. For instance, if the trend is upwards over time or the seasonal fluctuations get larger over time, then stationarity would be violated.

# %%
from statsmodels.tsa.stattools import adfuller
def adf_test(timeseries):
    #Perform Dickey-Fuller test:
    print ('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
       dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)

print(adf_test(weather_df))
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -6.353630e+00
# p-value                        2.574529e-08
# #Lags Used                     5.600000e+01
# Number of Observations Used    4.519500e+04
# Critical Value (1%)           -3.430495e+00
# Critical Value (5%)           -2.861604e+00
# Critical Value (10%)          -2.566804e+00
# dtype: float64
# None

# %% [markdown]
# **STEP 3: Perform first order differencing**
#
# Rerunning the test again after performing first order differencing confirms that the trend is now stationary.

# %%
def differencing_func(y):
    #FIRST ORDER DIFFERENCING
    y_adj = y - y.shift(1)
    y_adj = y_adj.dropna()
    y_adj.plot()

    #SEASONAL DIFFERENCING 
    y_adj2 = y - y.shift(12)
    y_adj2 = y_adj2.dropna()
    y_adj2.plot()

    print(adf_test(y_adj))
    print(adf_test(y_adj2))
    
differencing_func(weather_df)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   -36.399538
# p-value                            0.000000
# #Lags Used                        55.000000
# Number of Observations Used    45195.000000
# Critical Value (1%)               -3.430495
# Critical Value (5%)               -2.861604
# Critical Value (10%)              -2.566804
# dtype: float64
# None
# Results of Dickey-Fuller Test:
# Test Statistic                   -39.010885
# p-value                            0.000000
# #Lags Used                        56.000000
# Number of Observations Used    45183.000000
# Critical Value (1%)               -3.430495
# Critical Value (5%)               -2.861604
# Critical Value (10%)              -2.566804
# dtype: float64
# None

# %% [markdown]
# **Step 4: Plot ACF and PACF**

# %%
fig, ax = plt.subplots(2,1)
fig = sm.graphics.tsa.plot_acf(weather_df, lags=12, ax=ax[0])
fig = sm.graphics.tsa.plot_pacf(weather_df, lags=12, ax=ax[1])
plt.show()

# %% [markdown]
# **STEP 5: Specify SARIMA(p,d,q)*(P,D,Q,s)**
# - **p and seasonal P** = number of AUTOREGRESSIVE terms (lags of the stationarized series). It allows us to incorporate the effect of past values into our model. Intuitively, this would be similar to stating that it is likely to be warm tomorrow if it has been warm the past 3 days.
# - **d and seasonal D**: DIFFERENCING that must be done to stationarize the series. This includes terms in the model that incorporate the amount of differencing (i.e. the number of past time points to subtract from the current value) to apply to the time series. Intuitively, this would be similar to stating that it is likely to be same temperature tomorrow if the difference in temperature in the last three days has been very small.
# - **q and seasonal Q**: indicate number of MOVING AVERAGE terms -- lags of the forecast errors. This allows us to set the error of our model as a linear combination of the error values observed at previous time points in the past.
# - **s**: seasonal length in the data
#
# - (p,q,d) are the non seasonal parameters and (P,Q,D) follow the same definition but are applied to the seasonal component.
#
# This process of gridsearch will let the model automatically find the best parameters to make the ARIMA stationary. We use gridsearch since we are unsure of the actual parameters!

# %%
#since we are doing a seasonal ARIMA, we must specify parameters for ARIMA and SARIMA

#create combinations of ARIMA parameters
p = d = q = range(0, 2)
s = (1,12)

#create combinations of non-seasonal parameters 
pdq = list(itertools.product(p, d, q))

#create combinations for seasonal parameters -- 12 for monthly data
seasonal_pdq = list(itertools.product(p,d,q,s))


#print out sample of results
print('Examples of parameter combinations for Seasonal ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))
# Out:
# Examples of parameter combinations for Seasonal ARIMA...
# SARIMAX: (0, 0, 1) x (0, 0, 0, 12)
# SARIMAX: (0, 0, 1) x (0, 0, 1, 1)
# SARIMAX: (0, 1, 0) x (0, 0, 1, 12)
# SARIMAX: (0, 1, 0) x (0, 1, 0, 1)

# %%
grid_search = pd.DataFrame(columns = ['param', 'param_seasonal', 'AIC'])

warnings.filterwarnings("ignore") # specify to ignore warning messages
#loop through parameters and seasonal parameters and perform a grid search
for param in pdq: 
    for param_seasonal in seasonal_pdq: 
        try:
            model = sm.tsa.statespace.SARIMAX(weather_df,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=True,
                                            enforce_invertibility=True)
            results = model.fit(max_iter = 50, method = 'powell') #optimizer method 
            print('SARIMAX{}x{} - AIC:{}'.format(param, param_seasonal, results.aic))
            
            #append results to grid search df 
            grid_search = grid_search.append({'param': param, 'param_seasonal': param_seasonal, 'AIC': results.aic}, ignore_index=True)
        
        except:
            continue
# Out:
# Optimization terminated successfully.
#          Current function value: 4.054461
#          Iterations: 1
#          Function evaluations: 21
# SARIMAX(0, 0, 0)x(0, 0, 0, 12) - AIC:366946.91070880514
# Optimization terminated successfully.
#          Current function value: 3.770259
#          Iterations: 2
#          Function evaluations: 43
# SARIMAX(0, 0, 0)x(0, 0, 1, 12) - AIC:341227.50604362803
# Optimization terminated successfully.
#          Current function value: 3.204125
#          Iterations: 1
#          Function evaluations: 12
# SARIMAX(0, 0, 0)x(0, 1, 0, 12) - AIC:289988.1705698968
# Optimization terminated successfully.
#          Current function value: 3.009884
#          Iterations: 2
#          Function evaluations: 47
# SARIMAX(0, 0, 0)x(0, 1, 1, 12) - AIC:272410.5515570489
# Optimization terminated successfully.
#          Current function value: 3.181738
#          Iterations: 1
#          Function evaluations: 26
# SARIMAX(0, 0, 0)x(1, 0, 0, 12) - AIC:287964.03857881785
# Optimization terminated successfully.
#          Current function value: 3.008490
#          Iterations: 4
#          Function evaluations: 150
# SARIMAX(0, 0, 0)x(1, 0, 1, 12) - AIC:272286.3563941609
# Optimization terminated successfully.
#          Current function value: 2.917259
#          Iterations: 1
#          Function evaluations: 26
# SARIMAX(0, 0, 0)x(1, 1, 0, 12) - AIC:264027.58048803033
# Optimization terminated successfully.
#          Current function value: 2.783409
#          Iterations: 6
#          Function evaluations: 225
# SARIMAX(0, 0, 0)x(1, 1, 1, 12) - AIC:251915.6205754624
# Optimization terminated successfully.
#          Current function value: 3.412994
#          Iterations: 2
#          Function evaluations: 50
# SARIMAX(0, 0, 1)x(0, 0, 0, 12) - AIC:308893.60622070625
# Optimization terminated successfully.
#          Current function value: 3.138915
#          Iterations: 3
#          Function evaluations: 104
# SARIMAX(0, 0, 1)x(0, 0, 1, 12) - AIC:284090.32845976565
# Optimization terminated successfully.
#          Current function value: 2.654483
#          Iterations: 2
#          Function evaluations: 53
# SARIMAX(0, 0, 1)x(0, 1, 0, 12) - AIC:240245.3208813585
# Optimization terminated successfully.
#          Current function value: 2.466108
#          Iterations: 3
#          Function evaluations: 110
# SARIMAX(0, 0, 1)x(0, 1, 1, 12) - AIC:223198.63341861457
# Optimization terminated successfully.
#          Current function value: 2.627220
#          Iterations: 2
#          Function evaluations: 90
# SARIMAX(0, 0, 1)x(1, 0, 0, 12) - AIC:237779.89876015988
# Optimization terminated successfully.
#          Current function value: 2.464307
#          Iterations: 5
#          Function evaluations: 271
# SARIMAX(0, 0, 1)x(1, 0, 1, 12) - AIC:223037.63961903175
# Optimization terminated successfully.
#          Current function value: 2.405005
#          Iterations: 2
#          Function evaluations: 76
# SARIMAX(0, 0, 1)x(1, 1, 0, 12) - AIC:217668.60211956507
# Optimization terminated successfully.
#          Current function value: 2.312959
#          Iterations: 7
#          Function evaluations: 346
# SARIMAX(0, 0, 1)x(1, 1, 1, 12) - AIC:209340.05490954348
# Optimization terminated successfully.
#          Current function value: 1.628620
#          Iterations: 1
#          Function evaluations: 14
# SARIMAX(0, 1, 0)x(0, 0, 0, 12) - AIC:147398.60225368128
# Optimization terminated successfully.
#          Current function value: 1.604401
#          Iterations: 2
#          Function evaluations: 50
# SARIMAX(0, 1, 0)x(0, 0, 1, 12) - AIC:145208.6702368139
# Optimization terminated successfully.
#          Current function value: 2.095527
#          Iterations: 1
#          Function evaluations: 13
# SARIMAX(0, 1, 0)x(0, 1, 0, 12) - AIC:189655.604170638
# Optimization terminated successfully.
#          Current function value: 1.618657
#          Iterations: 2
#          Function evaluations: 53
# SARIMAX(0, 1, 0)x(0, 1, 1, 12) - AIC:146498.95215056982
# Optimization terminated successfully.
#          Current function value: 1.589816
#          Iterations: 1
#          Function evaluations: 27
# SARIMAX(0, 1, 0)x(1, 0, 0, 12) - AIC:143888.74316695926
# Optimization terminated successfully.
#          Current function value: 1.491269
#          Iterations: 5
#          Function evaluations: 190
# SARIMAX(0, 1, 0)x(1, 0, 1, 12) - AIC:134971.78816711679
# Optimization terminated successfully.
#          Current function value: 1.692494
#          Iterations: 1
#          Function evaluations: 27
# SARIMAX(0, 1, 0)x(1, 1, 0, 12) - AIC:153181.45457345815
# Optimization terminated successfully.
#          Current function value: 1.564344
#          Iterations: 4
#          Function evaluations: 163
# SARIMAX(0, 1, 0)x(1, 1, 1, 12) - AIC:141585.38434885122
# Optimization terminated successfully.
#          Current function value: 1.598894
#          Iterations: 1
#          Function evaluations: 25
# SARIMAX(0, 1, 1)x(0, 0, 0, 12) - AIC:144710.3019060093
# Optimization terminated successfully.
#          Current function value: 1.582728
#          Iterations: 2
#          Function evaluations: 72
# SARIMAX(0, 1, 1)x(0, 0, 1, 12) - AIC:143249.21994500677
# Optimization terminated successfully.
#          Current function value: 2.037364
#          Iterations: 2
#          Function evaluations: 51
# SARIMAX(0, 1, 1)x(0, 1, 0, 12) - AIC:184393.5861387223
# Optimization terminated successfully.
#          Current function value: 1.591132
#          Iterations: 2
#          Function evaluations: 76
# SARIMAX(0, 1, 1)x(0, 1, 1, 12) - AIC:144009.80336737417
# Optimization terminated successfully.
#          Current function value: 1.573921
#          Iterations: 2
#          Function evaluations: 74
# SARIMAX(0, 1, 1)x(1, 0, 0, 12) - AIC:142452.142441739
# Optimization terminated successfully.
#          Current function value: 1.488283
#          Iterations: 7
#          Function evaluations: 357
# SARIMAX(0, 1, 1)x(1, 0, 1, 12) - AIC:134703.56256567047
# Optimization terminated successfully.
#          Current function value: 1.689295
#          Iterations: 2
#          Function evaluations: 74
# SARIMAX(0, 1, 1)x(1, 1, 0, 12) - AIC:152893.98448254014
# Optimization terminated successfully.
#          Current function value: 1.554353
#          Iterations: 4
#          Function evaluations: 200
# SARIMAX(0, 1, 1)x(1, 1, 1, 12) - AIC:140683.12613638665
# Optimization terminated successfully.
#          Current function value: 1.627725
#          Iterations: 1
#          Function evaluations: 26
# SARIMAX(1, 0, 0)x(0, 0, 0, 12) - AIC:147319.62460862467
# Optimization terminated successfully.
#          Current function value: 1.603871
#          Iterations: 3
#          Function evaluations: 121
# SARIMAX(1, 0, 0)x(0, 0, 1, 12) - AIC:145162.70140932317
# Optimization terminated successfully.
#          Current function value: 2.081800
#          Iterations: 1
#          Function evaluations: 29
# SARIMAX(1, 0, 0)x(0, 1, 0, 12) - AIC:188415.23393163603
# Optimization terminated successfully.
#          Current function value: 1.615869
#          Iterations: 3
#          Function evaluations: 119
# SARIMAX(1, 0, 0)x(0, 1, 1, 12) - AIC:146248.6508093864
# Optimization terminated successfully.
#          Current function value: 1.589323
#          Iterations: 4
#          Function evaluations: 173
# SARIMAX(1, 0, 0)x(1, 0, 0, 12) - AIC:143846.12503680898
# Optimization terminated successfully.
#          Current function value: 1.493167
#          Iterations: 9
#          Function evaluations: 509
# SARIMAX(1, 0, 0)x(1, 0, 1, 12) - AIC:135145.58510184186
# Optimization terminated successfully.
#          Current function value: 1.681774
#          Iterations: 2
#          Function evaluations: 74
# SARIMAX(1, 0, 0)x(1, 1, 0, 12) - AIC:152213.2775055234
# Optimization terminated successfully.
#          Current function value: 1.561102
#          Iterations: 5
#          Function evaluations: 241
# SARIMAX(1, 0, 0)x(1, 1, 1, 12) - AIC:141293.99296077457
# Optimization terminated successfully.
#          Current function value: 1.597619
#          Iterations: 2
#          Function evaluations: 73
# SARIMAX(1, 0, 1)x(0, 0, 0, 12) - AIC:144596.91228340537
# Optimization terminated successfully.
#          Current function value: 1.581881
#          Iterations: 4
#          Function evaluations: 207
# SARIMAX(1, 0, 1)x(0, 0, 1, 12) - AIC:143174.54497742018
# Optimization terminated successfully.
#          Current function value: 2.016872
#          Iterations: 2
#          Function evaluations: 78
# SARIMAX(1, 0, 1)x(0, 1, 0, 12) - AIC:182540.94233010535
# Optimization terminated successfully.
#          Current function value: 1.586874
#          Iterations: 4
#          Function evaluations: 196
# SARIMAX(1, 0, 1)x(0, 1, 1, 12) - AIC:143626.47486627515
# Optimization terminated successfully.
#          Current function value: 1.573192
#          Iterations: 4
#          Function evaluations: 198
# SARIMAX(1, 0, 1)x(1, 0, 0, 12) - AIC:142388.1730197667
# Optimization terminated successfully.
#          Current function value: 1.487493
#          Iterations: 11
#          Function evaluations: 682
# SARIMAX(1, 0, 1)x(1, 0, 1, 12) - AIC:134634.0463018685
# Optimization terminated successfully.
#          Current function value: 1.676710
#          Iterations: 3
#          Function evaluations: 159
# SARIMAX(1, 0, 1)x(1, 1, 0, 12) - AIC:151756.98072750907
# Optimization terminated successfully.
#          Current function value: 1.550160
#          Iterations: 6
#          Function evaluations: 355
# SARIMAX(1, 0, 1)x(1, 1, 1, 12) - AIC:140305.72344103822
# Optimization terminated successfully.
#          Current function value: 1.588441
#          Iterations: 1
#          Function evaluations: 28
# SARIMAX(1, 1, 0)x(0, 0, 0, 12) - AIC:143764.28135699278
# Optimization terminated successfully.
#          Current function value: 1.575551
#          Iterations: 2
#          Function evaluations: 74
# SARIMAX(1, 1, 0)x(0, 0, 1, 12) - AIC:142599.62840037936
# Optimization terminated successfully.
#          Current function value: 2.012636
#          Iterations: 1
#          Function evaluations: 49
# SARIMAX(1, 1, 0)x(0, 1, 0, 12) - AIC:182155.6066868203
# Optimization terminated successfully.
#          Current function value: 1.581520
#          Iterations: 2
#          Function evaluations: 79
# SARIMAX(1, 1, 0)x(0, 1, 1, 12) - AIC:143139.84606067045
# Optimization terminated successfully.
#          Current function value: 1.568793
#          Iterations: 3
#          Function evaluations: 123
# SARIMAX(1, 1, 0)x(1, 0, 0, 12) - AIC:141988.01830766274
# Optimization terminated successfully.
#          Current function value: 1.487946
#          Iterations: 7
#          Function evaluations: 353
# SARIMAX(1, 1, 0)x(1, 0, 1, 12) - AIC:134673.07426626643
# Optimization terminated successfully.
#          Current function value: 1.688658
#          Iterations: 2
#          Function evaluations: 74
# SARIMAX(1, 1, 0)x(1, 1, 0, 12) - AIC:152836.33560219948
# Optimization terminated successfully.
#          Current function value: 1.551304
#          Iterations: 5
#          Function evaluations: 253
# SARIMAX(1, 1, 0)x(1, 1, 1, 12) - AIC:140407.17428347678
# Optimization terminated successfully.
#          Current function value: 1.571532
#          Iterations: 3
#          Function evaluations: 119
# SARIMAX(1, 1, 1)x(0, 0, 0, 12) - AIC:142235.8886741375
# Optimization terminated successfully.
#          Current function value: 1.562208
#          Iterations: 2
#          Function evaluations: 107
# SARIMAX(1, 1, 1)x(0, 0, 1, 12) - AIC:141394.0714805411
# Optimization terminated successfully.
#          Current function value: 1.985368
#          Iterations: 3
#          Function evaluations: 116
# SARIMAX(1, 1, 1)x(0, 1, 0, 12) - AIC:179689.72475063673
# Optimization terminated successfully.
#          Current function value: 1.563155
#          Iterations: 4
#          Function evaluations: 209
# SARIMAX(1, 1, 1)x(0, 1, 1, 12) - AIC:141479.771273506
# Optimization terminated successfully.
#          Current function value: 1.557610
#          Iterations: 4
#          Function evaluations: 215
# SARIMAX(1, 1, 1)x(1, 0, 0, 12) - AIC:140977.93367861016
# Optimization terminated successfully.
#          Current function value: 1.491982
#          Iterations: 7
#          Function evaluations: 444
# SARIMAX(1, 1, 1)x(1, 0, 1, 12) - AIC:135040.3823336358
# Optimization terminated successfully.
#          Current function value: 1.682453
#          Iterations: 2
#          Function evaluations: 101
# SARIMAX(1, 1, 1)x(1, 1, 0, 12) - AIC:152276.7525116841
# Optimization terminated successfully.
#          Current function value: 1.540181
#          Iterations: 7
#          Function evaluations: 438
# SARIMAX(1, 1, 1)x(1, 1, 1, 12) - AIC:139402.5632313373

# %%
#extract the best parameters for model
best_param =  grid_search.sort_values(by = 'AIC').reset_index()['param'][0]
best_seasonal_param = grid_search.sort_values(by = 'AIC').reset_index()['param_seasonal'][0]
grid_search.sort_values(by = 'AIC').reset_index()
# Out:
#     index      param param_seasonal            AIC
# 0      45  (1, 0, 1)  (1, 0, 1, 12)  134634.046302
# 1      53  (1, 1, 0)  (1, 0, 1, 12)  134673.074266
# 2      29  (0, 1, 1)  (1, 0, 1, 12)  134703.562566
# 3      21  (0, 1, 0)  (1, 0, 1, 12)  134971.788167
# 4      61  (1, 1, 1)  (1, 0, 1, 12)  135040.382334
# ..    ...        ...            ...            ...
# 59      4  (0, 0, 0)  (1, 0, 0, 12)  287964.038579
# 60      2  (0, 0, 0)  (0, 1, 0, 12)  289988.170570
# 61      8  (0, 0, 1)  (0, 0, 0, 12)  308893.606221
# 62      1  (0, 0, 0)  (0, 0, 1, 12)  341227.506044
# 63      0  (0, 0, 0)  (0, 0, 0, 12)  366946.910709
#
# [64 rows x 4 columns]

# %% [markdown]
# **STEP 6: Run SARIMAX**

# %%
#Lowest AIC Value: ARIMA(1, 1, 1)x(1, 1, 0, 12)12 - AIC:122.9976149247615
model = sm.tsa.statespace.SARIMAX(weather_df,
                                order= best_param,
                                seasonal_order=best_seasonal_param,
                                enforce_stationarity=False,    #defaults, but not necessary
                                enforce_invertibility=False)
results = model.fit()
print(results.summary().tables[1])
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9967      0.000   2356.693      0.000       0.996       0.997
# ma.L1          0.0740      0.001     59.337      0.000       0.072       0.076
# ar.S.L12      -0.9955      0.001  -1977.055      0.000      -0.997      -0.995
# ma.S.L12       0.9459      0.001    993.712      0.000       0.944       0.948
# sigma2         1.1465      0.001   1123.803      0.000       1.145       1.149
# ==============================================================================

# %% [markdown]
# **Check Model Fit**
# - Residuals: should be uncorrelated with a mean of 0, if there are correlations, there is information in them that should be used in computing forecasting. We can see that there is no correlation and zero mean.
# - Correlogram: residuals have relatively low corerlation with lagged versions of itself

# %%
results.plot_diagnostics(figsize=(16, 12))
plt.show()

# %% [markdown]
# **STEP 7: Generate Predictions**
#
# - dynamic: True = uses data from predicted points to generate future forecasts; False = generates one step ahead forecasts, i.e. uses only past data that we have to generate predicted forecasts
#     - If we are only generating predictions for one month, then this should not matter

# %%
#user can set predicted values to when they want the prediction to start 
prediction_start_date = weather_df.iloc[int(len(weather_df)*0.80)].name
#predict to the end of the dataset 
prediction_end_date = pd.to_datetime(weather_df.index[-1])



#generate predicted results and store 
pred = results.get_prediction(start=prediction_start_date, end = prediction_end_date, dynamic=False)

#predicted vs truth for time period in question -- if the forecast is negative, change to 0 
predicted = pred.predicted_mean

observed = weather_df[prediction_start_date:]
#confidence interval
ci = pred.conf_int()

#plot real against predicted values
ax = weather_df.plot(label='observed')
predicted.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 7))

ax.fill_between(ci.index,
                ci.iloc[:, 0],
                ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date')
ax.set_ylabel('Returns')
plt.legend()
plt.show()

# %%
ts_results = pd.DataFrame({'Predicted': predicted.values, 'CI Lower': ci['lower Temperature'], 'CI Upper': ci['upper Temperature'], 'Observed': observed['Temperature'].values})

#get RMSE -- calculate afterwards due to zeroing
ts_results['RMSE'] = np.sqrt((ts_results['Predicted'] - ts_results['Observed'].values)**2)
        
#RMSE of the entire prediction period 
RMSE_total = ts_results['RMSE'].mean()
RMSE_total
# Out:
# 0.5540631888423898

# %%
ts_results.head(20).style.background_gradient(cmap='inferno')
# Out:
# <style  type="text/css" >
# #T_3485f3fc_98de_11eb_8198_acde48001122row0_col0,#T_3485f3fc_98de_11eb_8198_acde48001122row0_col1,#T_3485f3fc_98de_11eb_8198_acde48001122row0_col2,#T_3485f3fc_98de_11eb_8198_acde48001122row0_col3,#T_3485f3fc_98de_11eb_8198_acde48001122row0_col4{
#             background-color:  #fcffa4;
#             color:  #000000;
#         }#T_3485f3fc_98de_11eb_8198_acde48001122row1_col0,#T_3485f3fc_98de_11eb_8198_acde48001122row1_col1,#T_3485f3fc_98de_11eb_8198_acde48001122row1_col2{
#             background-color:  #fcae12;
#             color:  #000000;
#         }#T_3485f3fc_98de_11eb_8198_acde48001122row1_col3{
#             background-color:  #f8cf3a;
#             color:  #000000;
#         }#T_3485f3fc_98de_11eb_8198_acde48001122row1_col4{
#             background-color:  #87216b;
#             color:  #f1f1f1;
#         }#T_3485f3fc_98de_11eb_8198_acde48001122row2_col0,#T_3485f3fc_98de_11eb_8198_acde48001122row2_col1,#T_3485f3fc_98de_11eb_8198_acde48001122row2_col2{
#             background-color:  #f8870e;
#             color:  #000000;
#         }#T_3485f3fc_98de_11eb_8198_acde48001122row2_col3{
#             background-color:  #fca80d;
#             color:  #000000;
#         }#T_3485f3fc_98de_11eb_8198_acde48001122row2_col4,#T_3485f3fc_98de_11eb_8198_acde48001122row16_col0,#T_3485f3fc_98de_11eb_8198_acde48001122row16_col1,#T_3485f3fc_98de_11eb_8198_acde48001122row16_col2{
#             background-color:  #520e6d;
#             color:  #f1f1f1;
#         }#T_3485f3fc_98de_11eb_8198_acde48001122row3_col0,#T_3485f3fc_98de_11eb_8198_acde48001122row3_col1,#T_3485f3fc_98de_11eb_8198_acde48001122row3_col2{
#             background-color:  #ef6c23;
#             color:  #000000;
#         }#T_3485f3fc_98de_11eb_8198_acde48001122row3_col3{
#             background-color:  #f1731d;
#             color:  #000000;
#         }#T_3485f3fc_98de_11eb_8198_acde48001122row3_col4,#T_3485f3fc_98de_11eb_8198_acde48001122row5_col0,#T_3485f3fc_98de_11eb_8198_acde48001122row5_col1,#T_3485f3fc_98de_11eb_8198_acde48001122row5_col2{
#             background-color:  #c63d4d;
#             color:  #f1f1f1;
#         }#T_3485f3fc_98de_11eb_8198_acde48001122row4_col0,#T_3485f3fc_98de_11eb_8198_acde48001122row4_col1,#T_3485f3fc_98de_11eb_8198_acde48001122row4_col2,#T_3485f3fc_98de_11eb_8198_acde48001122row5_col3{
#             background-color:  #c83f4b;
#             color:  #f1f1f1;
#         }#T_3485f3fc_98de_11eb_8198_acde48001122row4_col3{
#             background-color:  #eb6429;
#             color:  #000000;
#         }#T_3485f3fc_98de_11eb_8198_acde48001122row4_col4{
#             background-color:  #490b6a;
#             color:  #f1f1f1;
#         }#T_3485f3fc_98de_11eb_8198_acde48001122row5_col4{
#             background-color:  #902568;
#             color:  #f1f1f1;
#         }#T_3485f3fc_98de_11eb_8198_acde48001122row6_col0,#T_3485f3fc_98de_11eb_8198_acde48001122row6_col1,#T_3485f3fc_98de_11eb_8198_acde48001122row6_col2{
#             background-color:  #982766;
#             color:  #f1f1f1;
#         }#T_3485f3fc_98de_11eb_8198_acde48001122row6_col3{
#             background-color:  #ad305d;
#             color:  #f1f1f1;
#         }#T_3485f3fc_98de_11eb_8198_acde48001122row6_col4,#T_3485f3fc_98de_11eb_8198_acde48001122row10_col3,#T_3485f3fc_98de_11eb_8198_acde48001122row11_col0,#T_3485f3fc_98de_11eb_8198_acde48001122row11_col1,#T_3485f3fc_98de_11eb_8198_acde48001122row11_col2{
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }#T_3485f3fc_98de_11eb_8198_acde48001122row7_col0,#T_3485f3fc_98de_11eb_8198_acde48001122row7_col1,#T_3485f3fc_98de_11eb_8198_acde48001122row7_col2,#T_3485f3fc_98de_11eb_8198_acde48001122row7_col3{
#             background-color:  #7d1e6d;
#             color:  #f1f1f1;
#         }#T_3485f3fc_98de_11eb_8198_acde48001122row7_col4{
#             background-color:  #4f0d6c;
#             color:  #f1f1f1;
#         }#T_3485f3fc_98de_11eb_8198_acde48001122row8_col0,#T_3485f3fc_98de_11eb_8198_acde48001122row8_col1,#T_3485f3fc_98de_11eb_8198_acde48001122row8_col2{
#             background-color:  #5d126e;
#             color:  #f1f1f1;
#         }#T_3485f3fc_98de_11eb_8198_acde48001122row8_col3{
#             background-color:  #3e0966;
#             color:  #f1f1f1;
#         }#T_3485f3fc_98de_11eb_8198_acde48001122row8_col4{
#             background-color:  #d94d3d;
#             color:  #000000;
#         }#T_3485f3fc_98de_11eb_8198_acde48001122row9_col0,#T_3485f3fc_98de_11eb_8198_acde48001122row9_col1,#T_3485f3fc_98de_11eb_8198_acde48001122row9_col2{
#             background-color:  #280b53;
#             color:  #f1f1f1;
#         }#T_3485f3fc_98de_11eb_8198_acde48001122row9_col3{
#             background-color:  #2b0b57;
#             color:  #f1f1f1;
#         }#T_3485f3fc_98de_11eb_8198_acde48001122row9_col4,#T_3485f3fc_98de_11eb_8198_acde48001122row15_col4{
#             background-color:  #02010a;
#             color:  #f1f1f1;
#         }#T_3485f3fc_98de_11eb_8198_acde48001122row10_col0,#T_3485f3fc_98de_11eb_8198_acde48001122row10_col1,#T_3485f3fc_98de_11eb_8198_acde48001122row10_col2{
#             background-color:  #240c4f;
#             color:  #f1f1f1;
#         }#T_3485f3fc_98de_11eb_8198_acde48001122row10_col4{
#             background-color:  #fca309;
#             color:  #000000;
#         }#T_3485f3fc_98de_11eb_8198_acde48001122row11_col3,#T_3485f3fc_98de_11eb_8198_acde48001122row13_col4,#T_3485f3fc_98de_11eb_8198_acde48001122row16_col4{
#             background-color:  #060419;
#             color:  #f1f1f1;
#         }#T_3485f3fc_98de_11eb_8198_acde48001122row11_col4{
#             background-color:  #9d2964;
#             color:  #f1f1f1;
#         }#T_3485f3fc_98de_11eb_8198_acde48001122row12_col0,#T_3485f3fc_98de_11eb_8198_acde48001122row12_col1,#T_3485f3fc_98de_11eb_8198_acde48001122row12_col2,#T_3485f3fc_98de_11eb_8198_acde48001122row14_col0,#T_3485f3fc_98de_11eb_8198_acde48001122row14_col1,#T_3485f3fc_98de_11eb_8198_acde48001122row14_col2{
#             background-color:  #140b34;
#             color:  #f1f1f1;
#         }#T_3485f3fc_98de_11eb_8198_acde48001122row12_col3{
#             background-color:  #010005;
#             color:  #f1f1f1;
#         }#T_3485f3fc_98de_11eb_8198_acde48001122row12_col4{
#             background-color:  #a62d60;
#             color:  #f1f1f1;
#         }#T_3485f3fc_98de_11eb_8198_acde48001122row13_col0,#T_3485f3fc_98de_11eb_8198_acde48001122row13_col1,#T_3485f3fc_98de_11eb_8198_acde48001122row13_col2{
#             background-color:  #09061f;
#             color:  #f1f1f1;
#         }#T_3485f3fc_98de_11eb_8198_acde48001122row13_col3{
#             background-color:  #07051b;
#             color:  #f1f1f1;
#         }#T_3485f3fc_98de_11eb_8198_acde48001122row14_col3{
#             background-color:  #2f0a5b;
#             color:  #f1f1f1;
#         }#T_3485f3fc_98de_11eb_8198_acde48001122row14_col4{
#             background-color:  #a82e5f;
#             color:  #f1f1f1;
#         }#T_3485f3fc_98de_11eb_8198_acde48001122row15_col0,#T_3485f3fc_98de_11eb_8198_acde48001122row15_col1,#T_3485f3fc_98de_11eb_8198_acde48001122row15_col2{
#             background-color:  #390963;
#             color:  #f1f1f1;
#         }#T_3485f3fc_98de_11eb_8198_acde48001122row15_col3{
#             background-color:  #400a67;
#             color:  #f1f1f1;
#         }#T_3485f3fc_98de_11eb_8198_acde48001122row16_col3{
#             background-color:  #5f136e;
#             color:  #f1f1f1;
#         }#T_3485f3fc_98de_11eb_8198_acde48001122row17_col0,#T_3485f3fc_98de_11eb_8198_acde48001122row17_col1,#T_3485f3fc_98de_11eb_8198_acde48001122row17_col2{
#             background-color:  #67166e;
#             color:  #f1f1f1;
#         }#T_3485f3fc_98de_11eb_8198_acde48001122row17_col3{
#             background-color:  #ae305c;
#             color:  #f1f1f1;
#         }#T_3485f3fc_98de_11eb_8198_acde48001122row17_col4{
#             background-color:  #fac62d;
#             color:  #000000;
#         }#T_3485f3fc_98de_11eb_8198_acde48001122row18_col0,#T_3485f3fc_98de_11eb_8198_acde48001122row18_col1,#T_3485f3fc_98de_11eb_8198_acde48001122row18_col2{
#             background-color:  #b3325a;
#             col

# %% [markdown]
# ## MODEL 2. AutoARIMA
#
#
# AutoARIMA is the least-specific base ARIMA model to generate a baseline prediction.
#
# Usually, in the basic ARIMA model, we need to provide the p,d, and q values which are essential. We use statistical techniques to generate these values by performing the difference to eliminate the non-stationarity and plotting ACF and PACF graphs. In Auto ARIMA, the model itself will generate the optimal p, d, and q values which would be suitable for the data set to provide better forecasting.
#
# **NOTE: AUTOARIMA CRASHES DUE TO DATA SIZE -- NOT CONTINUED**

# %%
from pmdarima.utils import tsdisplay 
from pmdarima.arima import auto_arima
import pmdarima as pm

# %%
from pmdarima.utils import tsdisplay 
tsdisplay(weather_df)

# %% [markdown]
# ## MODEL 3. GAM using FbProphet
#
# Prophet is a procedure for forecasting time series data based on an additive model where non-linear trends are fit with yearly, weekly, and daily seasonality, plus holiday effects. It works best with time series that have strong seasonal effects and several seasons of historical data. Prophet is robust to missing data and shifts in the trend, and typically handles outliers well.
#
# According to FB's paper, FbProphet is a decomposable time-series with 3 main components: trend, seasonality, and holidays. FbProphet is specified similar to a generalized additive model (GAM) -- which are regression models with potential non-linear smoothers applied to the regressors. IT can decompose easily and accomodate new components when they are introduced -- i.e. if a new source of seasonality is identified. Since GAM frames the forecating problem as a curve fitting exercise, it is different from ARIMA that accounts for the temporal dependence structure in the data -- so it is inferentially weaker than a generative model such as ARIMA. However, it is more flexible (can accomodate seasonality with multiple periods), measurements do not need to be regularly spaced (so missing values do not need to be interpolated), and fitting is faster.
#
# https://peerj.com/preprints/3190/
# https://facebook.github.io/prophet/

# %%
from fbprophet import Prophet

# %%
#Reformat to FbProphet Format
y_prophet = pd.DataFrame({'ds': weather_df.index, 'y': weather_df['Temperature'].values}).reset_index().drop('index', axis = 1)
y_prophet
# Out:
#                        ds          y
# 0     2012-10-01 13:00:00  12.680000
# 1     2012-10-01 14:00:00  12.684650
# 2     2012-10-01 15:00:00  12.697790
# 3     2012-10-01 16:00:00  12.710929
# 4     2012-10-01 17:00:00  12.724069
# ...                   ...        ...
# 45247 2017-11-29 20:00:00   1.980000
# 45248 2017-11-29 21:00:00   0.980000
# 45249 2017-11-29 22:00:00   0.330000
# 45250 2017-11-29 23:00:00  -0.670000
# 45251 2017-11-30 00:00:00  -1.350000
#
# [45252 rows x 2 columns]

# %%
#split data 
def train_test_split(data, n_test):
    return data[:n_test], data[n_test:]

split_len = int(len(y_prophet)*0.80)
train, test = train_test_split(y_prophet, split_len)

# %%
model = Prophet(yearly_seasonality = True, interval_width=0.95)
model.fit(train)

#in prophet, if you pass in historical dates it will provide an in-sample fit
forecast = model.make_future_dataframe(periods = len(test), freq = 'H')

results_df = model.predict(forecast)

# %%
#filter results down to test-dataset only 
results_filtered = results_df[['ds','yhat','yhat_lower','yhat_upper']].iloc[split_len:]

# %%
ts_results = pd.DataFrame({'Predicted' : results_filtered['yhat'].values, 'CI Lower': results_filtered['yhat_lower'].values, 'CI Upper':results_filtered['yhat_upper'].values , 'Observed': test['y'].values}, index = test['ds'])

ts_results['RMSE'] = np.sqrt((ts_results['Predicted'] - ts_results['Observed'])**2)
RMSE_total = ts_results['RMSE'].mean()
RMSE_total
# Out:
# 4.341318457923584

# %%
#plot real against predicted values
ax = weather_df.plot(label='observed')
ts_results['Predicted'].plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 7))


ax.fill_between(ts_results.index,
                ts_results['CI Lower'],
                ts_results['CI Upper'], color='k', alpha=.2)

ax.set_xlabel('Date')
ax.set_ylabel('Temperature')
plt.legend()
plt.show()

# %%
ts_results.head(20).style.background_gradient(cmap='inferno')
# Out:
# <style  type="text/css" >
# #T_5f9e6d08_98de_11eb_8198_acde48001122row0_col0,#T_5f9e6d08_98de_11eb_8198_acde48001122row0_col1,#T_5f9e6d08_98de_11eb_8198_acde48001122row0_col2,#T_5f9e6d08_98de_11eb_8198_acde48001122row0_col3,#T_5f9e6d08_98de_11eb_8198_acde48001122row0_col4{
#             background-color:  #fcffa4;
#             color:  #000000;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row1_col0{
#             background-color:  #f8cd37;
#             color:  #000000;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row1_col1{
#             background-color:  #f4df53;
#             color:  #000000;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row1_col2{
#             background-color:  #f4dd4f;
#             color:  #000000;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row1_col3{
#             background-color:  #f8cf3a;
#             color:  #000000;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row1_col4{
#             background-color:  #f5db4c;
#             color:  #000000;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row2_col0{
#             background-color:  #f98e09;
#             color:  #000000;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row2_col1{
#             background-color:  #f78410;
#             color:  #000000;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row2_col2{
#             background-color:  #f06f20;
#             color:  #000000;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row2_col3{
#             background-color:  #fca80d;
#             color:  #000000;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row2_col4{
#             background-color:  #f2e865;
#             color:  #000000;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row3_col0,#T_5f9e6d08_98de_11eb_8198_acde48001122row18_col1{
#             background-color:  #e35933;
#             color:  #000000;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row3_col1{
#             background-color:  #f1711f;
#             color:  #000000;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row3_col2{
#             background-color:  #e55c30;
#             color:  #000000;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row3_col3,#T_5f9e6d08_98de_11eb_8198_acde48001122row17_col1{
#             background-color:  #f1731d;
#             color:  #000000;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row3_col4{
#             background-color:  #fbbe23;
#             color:  #000000;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row4_col0{
#             background-color:  #bf3952;
#             color:  #f1f1f1;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row4_col1{
#             background-color:  #bd3853;
#             color:  #f1f1f1;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row4_col2{
#             background-color:  #9b2964;
#             color:  #f1f1f1;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row4_col3{
#             background-color:  #eb6429;
#             color:  #000000;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row4_col4{
#             background-color:  #f1ed71;
#             color:  #000000;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row5_col0{
#             background-color:  #9a2865;
#             color:  #f1f1f1;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row5_col1{
#             background-color:  #b93556;
#             color:  #f1f1f1;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row5_col2,#T_5f9e6d08_98de_11eb_8198_acde48001122row6_col2{
#             background-color:  #771c6d;
#             color:  #f1f1f1;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row5_col3{
#             background-color:  #c83f4b;
#             color:  #f1f1f1;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row5_col4{
#             background-color:  #fcac11;
#             color:  #000000;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row6_col0{
#             background-color:  #781c6d;
#             color:  #f1f1f1;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row6_col1{
#             background-color:  #490b6a;
#             color:  #f1f1f1;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row6_col3{
#             background-color:  #ad305d;
#             color:  #f1f1f1;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row6_col4{
#             background-color:  #fa9207;
#             color:  #000000;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row7_col0,#T_5f9e6d08_98de_11eb_8198_acde48001122row15_col2{
#             background-color:  #5a116e;
#             color:  #f1f1f1;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row7_col1{
#             background-color:  #801f6c;
#             color:  #f1f1f1;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row7_col2{
#             background-color:  #751b6e;
#             color:  #f1f1f1;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row7_col3{
#             background-color:  #7d1e6d;
#             color:  #f1f1f1;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row7_col4,#T_5f9e6d08_98de_11eb_8198_acde48001122row18_col3{
#             background-color:  #d84c3e;
#             color:  #000000;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row8_col0,#T_5f9e6d08_98de_11eb_8198_acde48001122row15_col3{
#             background-color:  #400a67;
#             color:  #f1f1f1;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row8_col1{
#             background-color:  #1e0c45;
#             color:  #f1f1f1;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row8_col2,#T_5f9e6d08_98de_11eb_8198_acde48001122row12_col4{
#             background-color:  #280b53;
#             color:  #f1f1f1;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row8_col3{
#             background-color:  #3e0966;
#             color:  #f1f1f1;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row8_col4{
#             background-color:  #67166e;
#             color:  #f1f1f1;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row9_col0{
#             background-color:  #240c4f;
#             color:  #f1f1f1;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row9_col1,#T_5f9e6d08_98de_11eb_8198_acde48001122row10_col3,#T_5f9e6d08_98de_11eb_8198_acde48001122row10_col4,#T_5f9e6d08_98de_11eb_8198_acde48001122row11_col2,#T_5f9e6d08_98de_11eb_8198_acde48001122row12_col0{
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row9_col2{
#             background-color:  #57106e;
#             color:  #f1f1f1;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row9_col3{
#             background-color:  #2b0b57;
#             color:  #f1f1f1;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row9_col4{
#             background-color:  #64156e;
#             color:  #f1f1f1;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row10_col0{
#             background-color:  #0d0829;
#             color:  #f1f1f1;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row10_col1{
#             background-color:  #08051d;
#             color:  #f1f1f1;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row10_col2{
#             background-color:  #02020e;
#             color:  #f1f1f1;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row11_col0{
#             background-color:  #02020c;
#             color:  #f1f1f1;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row11_col1,#T_5f9e6d08_98de_11eb_8198_acde48001122row13_col1{
#             background-color:  #0c0826;
#             color:  #f1f1f1;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row11_col3{
#             background-color:  #060419;
#             color:  #f1f1f1;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row11_col4{
#             background-color:  #450a69;
#             color:  #f1f1f1;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row12_col1,#T_5f9e6d08_98de_11eb_8198_acde48001122row14_col1{
#             background-color:  #120a32;
#             color:  #f1f1f1;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row12_col2,#T_5f9e6d08_98de_11eb_8198_acde48001122row13_col0{
#             background-color:  #040312;
#             color:  #f1f1f1;
#         }#T_5f9e6d08_98de_11eb_8198_acde48001122row12_col3{
#             background-color:  #010005;
#             color:  #f1f1f1;
#         }#T_5f9e6d08_98de_11eb_8198_ac

# %% [markdown]
# ## 3. XGBOOST & RF
#
# Now, we will try to transform the time-series data into a supervised learning problem by testing a variety of tree-based models.

# %%
ml_df = pd.DataFrame({'Temperature': weather_df['Temperature']}, index = weather_df.index)

# %%
#CREATE LAGGED ATTRIBUTES 

ml_df['date'] = ml_df.index
ml_df['month'] = ml_df['date'].dt.day
ml_df['month'] = ml_df['date'].dt.month
ml_df['year'] = ml_df['date'].dt.year

ml_df['lag1'] = ml_df['Temperature'].shift(periods = 1, fill_value = 0)
ml_df['lag2'] = ml_df['Temperature'].shift(periods = 2, fill_value = 0)
ml_df['lag12'] = ml_df['Temperature'].shift(periods = 12, fill_value = 0)
ml_df['lag24'] = ml_df['Temperature'].shift(periods = 24, fill_value = 0)

ml_df['avg_returns'] = 0 
for i in range(1, len(ml_df)):
    ml_df['avg_returns'][i] = ml_df['lag1'][:i+1].mean()
    

ml_df.drop('date', axis = 1, inplace = True)

#we have to eliminate all those with 0s
ml_df = ml_df[ml_df['lag24'] != 0]

# %%
X = ml_df.iloc[:,1:]
y = ml_df[['Temperature']]

# %%
X
# Out:
#                      month  year       lag1       lag2      lag12      lag24  \
# datetime
# 2012-10-02 13:00:00     10  2012  12.973721  12.960581  12.829185  12.680000
# 2012-10-02 14:00:00     10  2012  12.986860  12.973721  12.842325  12.684650
# 2012-10-02 15:00:00     10  2012  13.000000  12.986860  12.855465  12.697790
# 2012-10-02 16:00:00     10  2012  14.400000  13.000000  12.868604  12.710929
# 2012-10-02 17:00:00     10  2012  14.990000  14.400000  12.881744  12.724069
# ...                    ...   ...        ...        ...        ...        ...
# 2017-11-29 20:00:00     11  2017   3.300000   3.000000   2.230000   0.600000
# 2017-11-29 21:00:00     11  2017   1.980000   3.300000   4.300000   0.900000
# 2017-11-29 22:00:00     11  2017   0.980000   1.980000   5.620000   0.900000
# 2017-11-29 23:00:00     11  2017   0.330000   0.980000   5.330000   5.907000
# 2017-11-30 00:00:00     11  2017  -0.670000   0.330000   4.300000   1.580000
#
#                      avg_returns
# datetime
# 2012-10-02 13:00:00           12
# 2012-10-02 14:00:00           12
# 2012-10-02 15:00:00           12
# 2012-10-02 16:00:00           12
# 2012-10-02 17:00:00           12
# ...                          ...
# 2017-11-29 20:00:00            7
# 2017-11-29 21:00:00            7
# 2017-11-29 22:00:00            7
# 2017-11-29 23:00:00            7
# 2017-11-30 00:00:00            7
#
# [45162 rows x 7 columns]

# %%
def train_test_split(data, n_test):
    return data[:n_test], data[n_test:]

split_len = int(len(weather_df)*0.80)

X_train, X_test = train_test_split(X, split_len)
y_train, y_test = train_test_split(y, split_len)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_train = pd.DataFrame(X_train_scaled)

X_test_scaled = scaler.transform(X_test)
X_test = pd.DataFrame(X_test_scaled)

# %% [markdown]
# ### XGB Regressor

# %%
import xgboost as xgb

xgb_model = xgb.XGBRegressor(n_estimators=1000)
xgb_model.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        early_stopping_rounds=50,
       verbose=False) 

pred = xgb_model.predict(X_test)

# %%
ts_results = pd.DataFrame({'Predicted': pred, 'Observed': y_test['Temperature']})
ts_results['RMSE'] = np.sqrt((ts_results['Predicted']-ts_results['Observed'])**2)
ts_results['RMSE'].mean()
# Out:
# 0.5993115228095

# %%
#plot real against predicted values
ax = weather_df.plot(label='observed')
ts_results['Predicted'].plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(10, 5))

ax.set_xlabel('Date')
ax.set_ylabel('Temperature')
plt.legend()
plt.show()

# %%
ts_results.head(20).style.background_gradient(cmap='inferno')
# Out:
# <style  type="text/css" >
# #T_9a0a475a_98de_11eb_8198_acde48001122row0_col0{
#             background-color:  #cb4149;
#             color:  #f1f1f1;
#         }#T_9a0a475a_98de_11eb_8198_acde48001122row0_col1{
#             background-color:  #db503b;
#             color:  #000000;
#         }#T_9a0a475a_98de_11eb_8198_acde48001122row0_col2,#T_9a0a475a_98de_11eb_8198_acde48001122row14_col0,#T_9a0a475a_98de_11eb_8198_acde48001122row19_col1{
#             background-color:  #010106;
#             color:  #f1f1f1;
#         }#T_9a0a475a_98de_11eb_8198_acde48001122row1_col0{
#             background-color:  #c13a50;
#             color:  #f1f1f1;
#         }#T_9a0a475a_98de_11eb_8198_acde48001122row1_col1{
#             background-color:  #fafda1;
#             color:  #000000;
#         }#T_9a0a475a_98de_11eb_8198_acde48001122row1_col2,#T_9a0a475a_98de_11eb_8198_acde48001122row2_col0,#T_9a0a475a_98de_11eb_8198_acde48001122row3_col1{
#             background-color:  #fcffa4;
#             color:  #000000;
#         }#T_9a0a475a_98de_11eb_8198_acde48001122row2_col1{
#             background-color:  #fac42a;
#             color:  #000000;
#         }#T_9a0a475a_98de_11eb_8198_acde48001122row2_col2{
#             background-color:  #e35933;
#             color:  #000000;
#         }#T_9a0a475a_98de_11eb_8198_acde48001122row3_col0{
#             background-color:  #f57b17;
#             color:  #000000;
#         }#T_9a0a475a_98de_11eb_8198_acde48001122row3_col2{
#             background-color:  #b73557;
#             color:  #f1f1f1;
#         }#T_9a0a475a_98de_11eb_8198_acde48001122row4_col0{
#             background-color:  #f2f27d;
#             color:  #000000;
#         }#T_9a0a475a_98de_11eb_8198_acde48001122row4_col1{
#             background-color:  #f9c72f;
#             color:  #000000;
#         }#T_9a0a475a_98de_11eb_8198_acde48001122row4_col2{
#             background-color:  #b43359;
#             color:  #f1f1f1;
#         }#T_9a0a475a_98de_11eb_8198_acde48001122row5_col0{
#             background-color:  #fa9008;
#             color:  #000000;
#         }#T_9a0a475a_98de_11eb_8198_acde48001122row5_col1{
#             background-color:  #f8870e;
#             color:  #000000;
#         }#T_9a0a475a_98de_11eb_8198_acde48001122row5_col2{
#             background-color:  #540f6d;
#             color:  #f1f1f1;
#         }#T_9a0a475a_98de_11eb_8198_acde48001122row6_col0{
#             background-color:  #d84c3e;
#             color:  #000000;
#         }#T_9a0a475a_98de_11eb_8198_acde48001122row6_col1{
#             background-color:  #ee6a24;
#             color:  #000000;
#         }#T_9a0a475a_98de_11eb_8198_acde48001122row6_col2{
#             background-color:  #08051d;
#             color:  #f1f1f1;
#         }#T_9a0a475a_98de_11eb_8198_acde48001122row7_col0{
#             background-color:  #ce4347;
#             color:  #f1f1f1;
#         }#T_9a0a475a_98de_11eb_8198_acde48001122row7_col1{
#             background-color:  #b3325a;
#             color:  #f1f1f1;
#         }#T_9a0a475a_98de_11eb_8198_acde48001122row7_col2,#T_9a0a475a_98de_11eb_8198_acde48001122row9_col0{
#             background-color:  #6d186e;
#             color:  #f1f1f1;
#         }#T_9a0a475a_98de_11eb_8198_acde48001122row8_col0{
#             background-color:  #982766;
#             color:  #f1f1f1;
#         }#T_9a0a475a_98de_11eb_8198_acde48001122row8_col1{
#             background-color:  #932667;
#             color:  #f1f1f1;
#         }#T_9a0a475a_98de_11eb_8198_acde48001122row8_col2{
#             background-color:  #190c3e;
#             color:  #f1f1f1;
#         }#T_9a0a475a_98de_11eb_8198_acde48001122row9_col1,#T_9a0a475a_98de_11eb_8198_acde48001122row11_col0{
#             background-color:  #440a68;
#             color:  #f1f1f1;
#         }#T_9a0a475a_98de_11eb_8198_acde48001122row9_col2{
#             background-color:  #64156e;
#             color:  #f1f1f1;
#         }#T_9a0a475a_98de_11eb_8198_acde48001122row10_col0{
#             background-color:  #380962;
#             color:  #f1f1f1;
#         }#T_9a0a475a_98de_11eb_8198_acde48001122row10_col1{
#             background-color:  #420a68;
#             color:  #f1f1f1;
#         }#T_9a0a475a_98de_11eb_8198_acde48001122row10_col2{
#             background-color:  #060419;
#             color:  #f1f1f1;
#         }#T_9a0a475a_98de_11eb_8198_acde48001122row11_col1,#T_9a0a475a_98de_11eb_8198_acde48001122row19_col0{
#             background-color:  #0c0826;
#             color:  #f1f1f1;
#         }#T_9a0a475a_98de_11eb_8198_acde48001122row11_col2{
#             background-color:  #721a6e;
#             color:  #f1f1f1;
#         }#T_9a0a475a_98de_11eb_8198_acde48001122row12_col0{
#             background-color:  #110a30;
#             color:  #f1f1f1;
#         }#T_9a0a475a_98de_11eb_8198_acde48001122row12_col1{
#             background-color:  #0b0724;
#             color:  #f1f1f1;
#         }#T_9a0a475a_98de_11eb_8198_acde48001122row12_col2,#T_9a0a475a_98de_11eb_8198_acde48001122row13_col1,#T_9a0a475a_98de_11eb_8198_acde48001122row14_col1,#T_9a0a475a_98de_11eb_8198_acde48001122row18_col0,#T_9a0a475a_98de_11eb_8198_acde48001122row18_col1{
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }#T_9a0a475a_98de_11eb_8198_acde48001122row13_col0,#T_9a0a475a_98de_11eb_8198_acde48001122row16_col1{
#             background-color:  #0d0829;
#             color:  #f1f1f1;
#         }#T_9a0a475a_98de_11eb_8198_acde48001122row13_col2{
#             background-color:  #1f0c48;
#             color:  #f1f1f1;
#         }#T_9a0a475a_98de_11eb_8198_acde48001122row14_col2{
#             background-color:  #040312;
#             color:  #f1f1f1;
#         }#T_9a0a475a_98de_11eb_8198_acde48001122row15_col0{
#             background-color:  #02020c;
#             color:  #f1f1f1;
#         }#T_9a0a475a_98de_11eb_8198_acde48001122row15_col1{
#             background-color:  #260c51;
#             color:  #f1f1f1;
#         }#T_9a0a475a_98de_11eb_8198_acde48001122row15_col2{
#             background-color:  #781c6d;
#             color:  #f1f1f1;
#         }#T_9a0a475a_98de_11eb_8198_acde48001122row16_col0{
#             background-color:  #450a69;
#             color:  #f1f1f1;
#         }#T_9a0a475a_98de_11eb_8198_acde48001122row16_col2{
#             background-color:  #741a6e;
#             color:  #f1f1f1;
#         }#T_9a0a475a_98de_11eb_8198_acde48001122row17_col0{
#             background-color:  #160b39;
#             color:  #f1f1f1;
#         }#T_9a0a475a_98de_11eb_8198_acde48001122row17_col1{
#             background-color:  #010108;
#             color:  #f1f1f1;
#         }#T_9a0a475a_98de_11eb_8198_acde48001122row17_col2{
#             background-color:  #2f0a5b;
#             color:  #f1f1f1;
#         }#T_9a0a475a_98de_11eb_8198_acde48001122row18_col2{
#             background-color:  #0a0722;
#             color:  #f1f1f1;
#         }#T_9a0a475a_98de_11eb_8198_acde48001122row19_col2{
#             background-color:  #140b34;
#             color:  #f1f1f1;
#         }</style><table id="T_9a0a475a_98de_11eb_8198_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Predicted</th>        <th class="col_heading level0 col1" >Observed</th>        <th class="col_heading level0 col2" >RMSE</th>    </tr>    <tr>        <th class="index_name level0" >datetime</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9a0a475a_98de_11eb_8198_acde48001122level0_row0" class="row_heading level0 row0" >2016-11-20 02:00:00</th>
#                         <td id="T_9a0a475a_98de_11eb_8198_acde48001122row0_col0" class="data row0 col0" >5.653259</td>
#                         <td id="T_9a0a475a_98de_11eb_8198_acde48001122row0_col1" class="data row0 col1" >5.620000</td>
#                         <td id="T_9a0a475a_98de_11eb_8198_acde48001122row0_col2" class="data row0 col2" >0.033259</td>
#             </tr>
#             <tr>
#                         <th id="T_9a0a475a_98de_11eb_8198_acde48001122level0_row1" class="row_heading level0 row1" >2016-11-20 03:00:00</th>
#                         <td id="T_9a0a475a

# %%
plt.figure(figsize=(10,5))
xgb.plot_importance(xgb_model, ax=plt.gca())
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='F score', ylabel='Features'>

# %% [markdown]
# ## Other Models

# %%
#Import models' packages
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error, mean_absolute_error


#Regression Models
regression_models = [['Linear Regression',LinearRegression()], 
                     ['RF regressor',RandomForestRegressor()], 
                     ['GBT',GradientBoostingRegressor()],
                     ['LASSO', Lasso()],
                     ['Ridge', Ridge()]]
                     

MSEs = []
MAEs = []
RMSEs = []
Models = ['Linear Regression', 'Random Forest Regressor', 'Gradient Boosting Regressor', 'Lasso', 'Ridge']

for name, model in regression_models: 
    print('Model = ', name)
    model.fit(X_train, y_train.values.ravel())
    y_test_pred = model.predict(X_test)
    
    MSE = mean_squared_error(y_test, y_test_pred)
    MAE = mean_absolute_error(y_test, y_test_pred)
    RMSE = np.sqrt(MSE)
    
    MSEs.append(MSE)
    MAEs.append(MAE)
    RMSEs.append(RMSE)
    print("MSE: ", MSE)
    print("RMSE: ", RMSE)
    print("MAE: ", MAE)
    print("-" * 19)
# Out:
# Model =  Linear Regression
# MSE:  0.7840314435972143
# RMSE:  0.8854555006307286
# MAE:  0.6240789918857792
# -------------------
# Model =  RF regressor
# MSE:  0.7575326087451212
# RMSE:  0.870363492309461
# MAE:  0.6112619330457543
# -------------------
# Model =  GBT
# MSE:  0.8731605992426144
# RMSE:  0.9344306283735644
# MAE:  0.6659353477002773
# -------------------
# Model =  LASSO
# MSE:  1.8801042449843246
# RMSE:  1.3711689337876367
# MAE:  1.0751309614548197
# -------------------
# Model =  Ridge
# MSE:  0.7857347409845423
# RMSE:  0.8864167986813778
# MAE:  0.6250133117380647
# -------------------
